# %%
import pandas as pd
import pyarrow.parquet as pq

# Read only a sample of rows
parquet_file = pq.ParquetFile('posts.parquet')
# Get first row group and convert to pandas
first_row_group = parquet_file.read_row_group(0)
sample_df = first_row_group.to_pandas()
sample_df.head(10)
# Out:
#      did_id           rkey                       created_at languages labels  \
# 0  31955122  3k7jw676psl25 2023-09-16 19:36:58.558000+00:00    ["sv"]   None
# 1  31955122  3layrwsjukc2b 2024-11-15 16:22:35.542000+00:00    ["sv"]   None
# 2  31955122  3lb3rwnpmvk2q 2024-11-16 21:00:29.703000+00:00    ["sv"]   None
# 3  31955122  3lbkt2sup2k2l 2024-11-22 20:30:39.146000+00:00    ["sv"]   None
# 4  31955122  3ld7gefr74k2d 2024-12-13 18:34:28.434000+00:00    ["sv"]   None
# 5  31955122  3ldfprccwks2m 2024-12-16 06:38:43.136000+00:00    ["sv"]   None
# 6  31955122  3ldfpz7xtrk2m 2024-12-16 06:43:09.111000+00:00    ["sv"]   None
# 7   6484551  3l2v2gva6xk2t 2024-08-29 20:12:56.510000+00:00    ["pt"]   None
# 8   6484551  3l2vheux35s2l 2024-08-30 00:04:27.725000+00:00    ["pt"]   None
# 9   6484551  3l33ldduevf2b 2024-09-01 10:31:09.436000+00:00    ["pt"]   None
#
#    tags embed_type embed_record embed_external_uri embed_images embed_media  \
# 0  None       None         None               None         None        None
# 1  None       None         None               None         None        None
# 2  None       None         None               None         None        None
# 3  None       None         None               None         None        None
# 4  None       None         None               None         None        None
# 5  None       None         None               None         None        None
# 6  None       None         None               None         None        None
# 7  None       None         None               None         None        None
# 8  None       None         None               None         None        None
# 9  None       None         None               None         None        None
#
#   embed_video                                              reply
# 0        None  {'root': {'did_id': 31955122, 'collection': 'a...
# 1        None  {'root': {'did_id': 32952056, 'collection': 'a...
# 2        None  {'root': {'did_id': 31955122, 'collection': 'a...
# 3        None  {'root': {'did_id': 18267824, 'collection': 'a...
# 4        None  {'root': {'did_id': 4158074, 'collection': 'ap...
# 5        None  {'root': {'did_id': 31955122, 'collection': 'a...
# 6        None  {'root': {'did_id': 31955122, 'collection': 'a...
# 7        None  {'root': {'did_id': 23788900, 'collection': 'a...
# 8        None  {'root': {'did_id': 16097489, 'collection': 'a...
# 9        None  {'root': {'did_id': 3731865, 'collection': 'ap...
