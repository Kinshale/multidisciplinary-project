# %%
import pandas as pd
import pyarrow.parquet as pq

# Read only a sample of rows
parquet_file = pq.ParquetFile('follows.parquet')
# Get first row group and convert to pandas
first_row_group = parquet_file.read_row_group(0)
sample_df = first_row_group.to_pandas()
print(sample_df.head(10))
sample_df.info()
# Out:
#    did_id created_date  subject_did_id
# 0   10650   2024-10-18        26184778
# 1   10650   2024-10-18        14961686
# 2   10650   2024-10-18        23686987
# 3   10650   2024-10-18        13296481
# 4   10650   2024-10-18        15736573
# 5   10650   2024-10-18         6307308
# 6   10650   2024-10-18        25946464
# 7   10650   2024-10-18         5277447
# 8   10650   2024-10-18        33649447
# 9   10650   2024-11-07        33759460
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122880 entries, 0 to 122879
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   did_id          122880 non-null  int64
#  1   created_date    122880 non-null  object
#  2   subject_did_id  122880 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 2.8+ MB
