# %%
import pandas as pd
import pyarrow.parquet as pq

# Read only a sample of rows
parquet_file = pq.ParquetFile('profiles/profilesFiltered2.parquet')
# Get first row group and convert to pandas
first_row_group = parquet_file.read_row_group(0)
sample_df = first_row_group.to_pandas()
print(sample_df.head(10))
sample_df.info()
# Out:
#    did_id created_date                                             labels
# 0  392385   2024-10-17                                               None
# 1  392400   2024-05-01                                               None
# 2  392412   2024-11-26                                               None
# 3  392446   2024-08-29                                               None
# 4  392503   2024-12-24                                               None
# 5  392514   2025-01-06                                               None
# 6  392521   2024-04-19                                               None
# 7  392531   2024-09-01                                               None
# 8  392550   2025-02-03                                               None
# 9  392566   2024-11-19  {"$type":"com.atproto.label.defs#selfLabels","...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122982 entries, 0 to 122981
# Data columns (total 3 columns):
#  #   Column        Non-Null Count   Dtype
# ...
