# %%
import pandas as pd
import pyarrow.parquet as pq

# Read only a sample of rows
parquet_file = pq.ParquetFile('likesFilteredChunks.parquet')
# Get first row group and convert to pandas
first_row_group = parquet_file.read_row_group(0)
sample_df = first_row_group.to_pandas()
print(sample_df.head(10))
sample_df.info()
# Out:
#    did_id created_date subject_did_id  subject_collection
# 0      12   2024-10-27       24305113  app.bsky.feed.post
# 1      12   2024-10-27       24305113  app.bsky.feed.post
# 2      12   2024-10-27        3568540  app.bsky.feed.post
# 3      12   2024-10-27       26483698  app.bsky.feed.post
# 4      12   2024-10-27       24305113  app.bsky.feed.post
# 5      12   2024-10-27       23118886  app.bsky.feed.post
# 6      12   2024-10-27       30396493  app.bsky.feed.post
# 7      12   2024-10-27       17995234  app.bsky.feed.post
# 8      12   2024-10-27       32000613  app.bsky.feed.post
# 9      12   2024-10-27        3237491  app.bsky.feed.post
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123278 entries, 0 to 123277
# Data columns (total 4 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   did_id              123278 non-null  int64
#  1   created_date        123278 non-null  object
#  2   subject_did_id      123278 non-null  object
#  3   subject_collection  123278 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 3.8+ MB
