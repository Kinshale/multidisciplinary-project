# %%
import pandas as pd
import pyarrow.parquet as pq

# Read only a sample of rows
parquet_file = pq.ParquetFile('follows.parquet')
# Get first row group and convert to pandas
first_row_group = parquet_file.read_row_group(0)
sample_df = first_row_group.to_pandas()
print(sample_df.head(10))
sample_df.info()
# Out:
#    did_id           rkey                       created_at  subject_id
# 0       1  3laxsqgevg324 2024-11-15 07:04:15.472000+00:00    32919732
# 1       1  3laykpiwyfy25 2024-11-15 14:13:14.331000+00:00    10541982
# 2       1  3lbsl5ra5zc23 2024-11-25 22:30:25.945000+00:00    21894245
# 3       1  3lbsl66ze4s2v 2024-11-25 22:30:40.392000+00:00    26881587
# 4       1  3lbtgjh5suq2z 2024-11-26 06:40:09.105000+00:00     7205853
# 5       1  3let66bjfvp2z 2025-01-03 08:26:18.897000+00:00     2607739
# 6       1  3lf52jx7fzz2o 2025-01-07 06:47:53.250000+00:00    19674894
# 7       2  3lbx66j4lkd23 2024-11-27 18:21:31.157000+00:00    32919732
# 8       2  3lbx6dvchbc24 2024-11-27 18:24:31.633000+00:00     5377118
# 9       2  3lbx6efnfsm2j 2024-11-27 18:24:48.746000+00:00     9877561
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122880 entries, 0 to 122879
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   did_id      122880 non-null  int64
#  1   rkey        122880 non-null  object
#  2   created_at  122880 non-null  datetime64[us, UTC]
#  3   subject_id  122880 non-null  int64
# dtypes: datetime64[us, UTC](1), int64(2), object(1)
# memory usage: 3.8+ MB
