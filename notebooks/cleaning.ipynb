# %%
# Imports and setup
import fsspec
import pyarrow.parquet as pq
import pyarrow as pa
import pyarrow.compute as pc

import os
import time
from datetime import datetime

print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!

# %% [markdown]
# # Remote Schema Exploration

# %%
URLS = {
    "Blocks": "https://bsky-data.leobalduf.com/blocks.parquet",
    "Follows": "https://bsky-data.leobalduf.com/follows.parquet",
    "Likes": "https://bsky-data.leobalduf.com/likes.parquet",
    "Posts": "https://bsky-data.leobalduf.com/posts.parquet",
    "Profiles": "https://bsky-data.leobalduf.com/profiles.parquet"
}

# %%
for name, url in URLS.items():
    with fsspec.open(url, "rb") as f:
        parquet_file = pq.ParquetFile(f)
        print(f"{name} Database")
        print("Columns:", parquet_file.schema.names)
        print("Number of rows:", parquet_file.metadata.num_rows)
        print("Number of row groups:", parquet_file.metadata.num_row_groups)
# Out:
# Blocks Database
# Columns: ['did_id', 'rkey', 'created_at', 'subject_id']
# Number of rows: 120088510
# Number of row groups: 978
# Follows Database
# Columns: ['did_id', 'rkey', 'created_at', 'subject_id']
# Number of rows: 2156778700
# Number of row groups: 17551
# Likes Database
# Columns: ['did_id', 'rkey', 'created_at', 'did_id', 'collection', 'rkey']
# Number of rows: 6938743344
# Number of row groups: 56461
# Posts Database
# Columns: ['did_id', 'rkey', 'created_at', 'languages', 'labels', 'tags', 'embed_type', 'did_id', 'collection', 'rkey', 'embed_external_uri', 'embed_images', 'embed_media', 'embed_video', 'did_id', 'collection', 'rkey', 'did_id', 'collection', 'rkey']
# Number of rows: 1290686413
# Number of row groups: 10495
# Profiles Database
# Columns: ['did_id', 'rkey', 'created_at', 'description', 'labels', '/', 'size', 'mimeType', '/', 'size', 'mimeType', 'joined_via_starter_pack', 'additional_fields']
# Number of rows: 32170299
# Number of row groups: 262

# %%
def get_column_metadata(URL, column_names=None, detailed=False):
    
    with fsspec.open(URL, "rb") as f:
        parquet_file = pq.ParquetFile(f)
        metadata = parquet_file.metadata
        schema = parquet_file.schema_arrow
        
        # Handle column selection
        if column_names is None:
            column_names = schema.names
        elif isinstance(column_names, str):
            column_names = [column_names]
        
        # Validate columns exist
        valid_columns = []
        for col_name in column_names:
            if col_name in schema.names:
                valid_columns.append(col_name)
            else:
                print(f"Warning: Column '{col_name}' not found in schema. Available columns: {schema.names}")
        
        if not valid_columns:
            print("No valid columns to analyze")
            return
        
        mode = "DETAILED" if detailed else "OVERVIEW"
        print(f"=== {mode} FOR {len(valid_columns)} COLUMN(S) ===")
        
        # Process each column
        for column_name in valid_columns:
            col_idx = schema.names.index(column_name)
            col_type = schema.field(column_name).type
            
            if detailed:
                print(f"\n{'='*50}")
                print(f"DETAILED METADATA FOR '{column_name}'")
                print(f"{'='*50}")
            else:
                print(f"\n{column_name}: {col_type}")
            
            # Initialize aggregators
            total_nulls = 0
            total_values = 0
            has_min_max = False
            global_min = None
            global_max = None
            has_distinct_count = False
            distinct_count = None
            
            # Aggregate across all row groups
            for rg_idx in range(metadata.num_row_groups):
                rg_metadata = metadata.row_group(rg_idx)
                col_metadata = rg_metadata.column(col_idx)
                rg_num_rows = rg_metadata.num_rows
                
                if col_metadata.statistics:
                    stats = col_metadata.statistics
                    
                    # Aggregate null count
                    if stats.has_null_count:
                        total_nulls += stats.null_count
                    
                    # Aggregate min/max values
                    if stats.has_min_max:
                        has_min_max = True
                        try:
                            current_min = stats.min
                            current_max = stats.max
                            
                            # Handle different data types for comparison
                            if pa.types.is_timestamp(col_type):
                                current_min = pa.scalar(current_min).cast(col_type).as_py()
                                current_max = pa.scalar(current_max).cast(col_type).as_py()
                            
                            # Update global min/max
                            if global_min is None or current_min < global_min:
                                global_min = current_min
                            if global_max is None or current_max > global_max:
                                global_max = current_max
                                
                        except (OverflowError, Exception):
                            # If we can't compare, just take the first available values
                            if global_min is None:
                                global_min = stats.min
                                global_max = stats.max
                    
                    # Handle distinct count (take max across row groups as approximation)
                    if stats.has_distinct_count:
                        has_distinct_count = True
                        if distinct_count is None or stats.distinct_count > distinct_count:
                            distinct_count = stats.distinct_count
                
                total_values += rg_num_rows
            
            # Calculate percentages
            null_percentage = (total_nulls / total_values) * 100 if total_values > 0 else 0
            non_null_count = total_values - total_nulls
            
            # Display results based on detail level
            if detailed:
                print(f"Data type: {col_type}")
                print(f"Total rows: {total_values:,}")
                print(f"Null count: {total_nulls:,} ({null_percentage:.2f}%)")
                print(f"Non-null count: {non_null_count:,}")
                
                if has_min_max:
                    print(f"\nValue Range:")
                    try:
                        if pa.types.is_timestamp(col_type):
                            print(f"  Min: {global_min}")
                            print(f"  Max: {global_max}")
                        elif pa.types.is_string(col_type) or pa.types.is_large_string(col_type):
                            min_str = str(global_min)
                            max_str = str(global_max)
                            if len(min_str) > 50:
                                min_str = min_str[:47] + "..."
                            if len(max_str) > 50:
                                max_str = max_str[:47] + "..."
                            print(f"  Min: {min_str}")
                            print(f"  Max: {max_str}")
                        else:
                            print(f"  Min: {global_min}")
                            print(f"  Max: {global_max}")
                    except Exception as e:
                        print(f"  Min: <error displaying: {e}>")
                        print(f"  Max: <error displaying: {e}>")
                else:
                    print(f"\nValue Range: No min/max statistics available")
                
                if has_distinct_count:
                    print(f"Distinct values: {distinct_count:,}")
                else:
                    print(f"Distinct values: No distinct count statistics available")
                    
            else:
                # Quick overview mode
                print(f"  Total rows: {total_values:,}")
                print(f"  Null count: {total_nulls:,} ({null_percentage:.1f}%)")
                print(f"  Non-null: {non_null_count:,}")
                
                if has_min_max:
                    try:
                        if pa.types.is_timestamp(col_type):
                            print(f"  Value range: {global_min} to {global_max}")
                        elif pa.types.is_string(col_type) or pa.types.is_large_string(col_type):
                            min_str = str(global_min)[:20] + "..." if len(str(global_min)) > 20 else str(global_min)
                            max_str = str(global_max)[:20] + "..." if len(str(global_max)) > 20 else str(global_max)
                            print(f"  Value range: '{min_str}' to '{max_str}'")
                        else:
                            print(f"  Value range: {global_min} to {global_max}")
                    except Exception:
                        print(f"  Value range: Available (display error)")
                else:
                    print(f"  Value range: No statistics available")

# %%
get_column_metadata(URLS["Posts"], ["labels", "languages"], detailed=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 get_column_metadata(URLS["Posts"], ["labels", "languages"], detailed=True)
#
# NameError: name 'get_column_metadata' is not defined

# %%
get_column_metadata(URLS["Blocks"], ["subject_id"], detailed=True)
# Out:
# === DETAILED FOR 1 COLUMN(S) ===
#
# ==================================================
# DETAILED METADATA FOR 'subject_id'
# ==================================================
# Data type: int64
# Total rows: 120,088,510
# Null count: 0 (0.00%)
# Non-null count: 120,088,510
#
# Value Range:
#   Min: 3
#   Max: 34251851
# Distinct values: No distinct count statistics available

# %% [markdown]
# # Cleaning

# %%
MAX_DATE = '2025-05-14'
MIN_DATE = '2025-01-01'
# Define cleaning rules per databas Follows.
# NOTE: If the columns in the dictionary aren't sorted, my Kernel crashes ahaha.
CLEANING_RULES = {
    # Keep: did_id, subject.did_id, created_at.
    'blocks': {
        'did_id': {
            'remove_null': True,
        },
        'created_at': {
            'remove_null': True,
            'max_date': MAX_DATE,
            'min_date': MIN_DATE
        },
        'subject_id': {
            'remove_null': True,
        },
    },
    # Keep: did_id, subject_id, created_at.
    'follows': {
        'did_id': {
            'remove_null': True,
        },
        'created_at': {
            'remove_null': True,
            'max_date': MAX_DATE,
            'min_date': MIN_DATE
        },
        'subject_id': {
            'remove_null': True,
        },
    },
    # Keep: did_id, subject.did_id, subject.collection, created_at.
    'likes': {
        'did_id': {
            'remove_null': True,
            'remove_empty_strings': True
        },
        'created_at': {
            'remove_null': True,
            'max_date': MAX_DATE,
            'min_date': MIN_DATE
        },
        'subject.did_id': {
            'remove_null': True,
        },
        'subject.collection': {
            'remove_null': False,
        },
    },
    # Keep: did_id, created_at, langueages, labels.
    'posts': {
        'did_id': {
            'remove_null': True,
            'remove_empty_strings': True
        },
        'created_at': {
            'remove_null': True,
            'max_date': MAX_DATE,
            'min_date': MIN_DATE
        },
        'languages': {
            'remove_null': False,
        },
        'labels': {
            'remove_null': False,
        },
    },
    # Keep: did_id, created_at, subject.did_id, subject.collection.
    'reposts': {
        'did_id': {
            'remove_null': True,
            'remove_empty_strings': True
        },
        'created_at': {
            'remove_null': True,
            'max_date': MAX_DATE,
            'min_date': MIN_DATE
        },
        'subject.did_id': {
            'remove_null': True,
        },
        'subject.collection': {
            'remove_null': False,
        },

    },
    # Keep did_id, created_at, labels
    'profiles': {
        'did_id': {
            'remove_null': True,
            'remove_empty_strings': True
        },
        'created_at': {
            'remove_null': True,
            'max_date': MAX_DATE,
            'min_date':  '2021-01-01' # It would be interesting when someone joined
        },
        'labels':{
            'remove_null': False,
        },
    },
}

# %%
def clean_table_with_rules(table, rules, table_type='default'):

    current_table = table
    applied_rules = []
    
    rule_set = rules.get(table_type, {})
    
    for column_name, column_rules in rule_set.items():
        if column_name not in current_table.column_names:
            continue
            
        temp_table = current_table
        
        if column_rules.get('remove_null'):
            mask = pc.is_valid(temp_table[column_name])
            temp_table = temp_table.filter(mask)
            applied_rules.append(f"removed_null_{column_name}")
            if temp_table.num_rows == 0:
                break  # No rows left, stop processing
        
        # Remove empty strings (May be expensive)
        if column_rules.get('remove_empty_strings') and pa.types.is_string(temp_table[column_name].type):
            mask = pc.not_equal(temp_table[column_name], "")
            temp_table = temp_table.filter(mask)
            applied_rules.append(f"removed_empty_{column_name}")
            if temp_table.num_rows == 0:
                break
        
        if column_rules.get('max_date') and pa.types.is_timestamp(temp_table[column_name].type):
            max_date = datetime.strptime(column_rules['max_date'], '%Y-%m-%d')
            max_date_scalar = pa.scalar(max_date, type=temp_table[column_name].type)
            mask = pc.less_equal(temp_table[column_name], max_date_scalar)
            temp_table = temp_table.filter(mask)
            applied_rules.append(f"max_date_{column_name}")
            if temp_table.num_rows == 0:
                break
            
        if column_rules.get('min_date') and pa.types.is_timestamp(temp_table[column_name].type):
            min_date = datetime.strptime(column_rules['min_date'], '%Y-%m-%d')
            min_date_scalar = pa.scalar(min_date, type=temp_table[column_name].type)
            mask = pc.greater_equal(temp_table[column_name], min_date_scalar)
            temp_table = temp_table.filter(mask)
            applied_rules.append(f"min_date_{column_name}")
            if temp_table.num_rows == 0:
                break
        
        current_table = temp_table
    
    return current_table, applied_rules, []

# %%
def clean_parquet_by_row_groups(input_path, output_path, rules, table_type='default'):
    """Clean Parquet file by processing row groups - most efficient approach"""
    
    print(f"Cleaning by row groups...")
    original_size = os.path.getsize(input_path)
    print(f"Input file: {original_size / (1024**3):.2f} GB")
    
    # Open Parquet file
    pf = pq.ParquetFile(input_path)
    
    # Get ALL available columns (including nested paths)
    def get_all_columns(schema):
        """Recursively get all column paths, including nested fields"""
        all_columns = []
        for field in schema:
            if pa.types.is_struct(field.type):
                # For struct fields, get all nested paths
                for nested_field in field.type:
                    nested_path = f"{field.name}.{nested_field.name}"
                    all_columns.append(nested_path)
            else:
                # Regular top-level column
                all_columns.append(field.name)
        return all_columns

    available_columns = set(get_all_columns(pf.schema_arrow))
    rule_columns = set(rules.get(table_type, {}).keys())
    columns_to_read = list(rule_columns.intersection(available_columns))

    missing_columns = rule_columns - available_columns
    if missing_columns:
        print(f"Warning: Columns not found: {missing_columns}")
    
    # Set up Parquet writer
    writer = None
    total_rows_processed = 0
    total_rows_kept = 0
    applied_rules = None
    
    # Process each row group
    for i in range(pf.num_row_groups):
        print(f"Processing row group {i+1}/{pf.num_row_groups}...", end=" ")
        
        # Read only the columns we need from this row group
        row_group_table = pf.read_row_group(i, columns=columns_to_read)
        total_rows_processed += row_group_table.num_rows
        
        # Apply cleaning rules
        cleaned_table, current_applied_rules, removal_log = clean_table_with_rules(
            row_group_table, rules, table_type
        )
        
        total_rows_kept += cleaned_table.num_rows
        
        # Store applied rules from first row group
        if applied_rules is None:
            applied_rules = current_applied_rules
            print(f"Applied rules: {applied_rules}")
        
        # Initialize writer with first cleaned table schema
        if writer is None:
            writer = pq.ParquetWriter(
                output_path,
                cleaned_table.schema,
                compression='zstd',
                use_dictionary=True,
                write_statistics=True
            )
        
        # Write cleaned row group
        if cleaned_table.num_rows > 0:
            writer.write_table(cleaned_table)
            print(f"✅ {row_group_table.num_rows} → {cleaned_table.num_rows} rows")
        else:
            print(f"❌ entire row group removed")
    
    if writer:
        writer.close()
    
    # Calculate and print summary
    final_size = os.path.getsize(output_path)
    size_reduction = original_size - final_size
    size_reduction_percent = (size_reduction / original_size * 100) if original_size > 0 else 0
    retention_rate = (total_rows_kept / total_rows_processed * 100) if total_rows_processed > 0 else 0
    
    print("\n" + "="*60)
    print("ROW GROUP CLEANING SUMMARY:")
    print("="*60)
    print(f"Row groups: {pf.num_row_groups} processed")
    print(f"Rows:       {total_rows_processed:,} → {total_rows_kept:,} ({retention_rate:.1f}% kept)")
    print(f"File size:  {original_size / (1024**3):.2f} GB → {final_size / (1024**3):.2f} GB")
    print(f"Reduction:  {size_reduction / (1024**3):.2f} GB ({size_reduction_percent:.1f}%)")
    print(f"Columns:    {len(pf.schema_arrow.names)} → {len(columns_to_read)}")
    print("="*60)
    
    return {
        'original_rows': total_rows_processed,
        'final_rows': total_rows_kept,
        'original_size': original_size,
        'final_size': final_size,
        'row_groups_processed': pf.num_row_groups
    }

# %%
import concurrent.futures

def clean_parquet_parallel(input_path, output_path, rules, table_type='default', max_workers=4):
    """Clean Parquet file by processing row groups in parallel"""
    
    print(f"Cleaning in parallel with {max_workers} workers...")
    
    pf = pq.ParquetFile(input_path)
    available_columns = set(pf.schema_arrow.names)
    rule_columns = set(rules.get(table_type, {}).keys())
    columns_to_read = list(rule_columns.intersection(available_columns))
    
    print(f"Processing {len(columns_to_read)} columns across {pf.num_row_groups} row groups")
    
    # Process first row group to get schema
    first_rg = pf.read_row_group(0, columns=columns_to_read)
    first_cleaned, applied_rules, _ = clean_table_with_rules(first_rg, rules, table_type)
    
    print(f"Applied rules: {applied_rules}")
    
    # Set up writer
    writer = pq.ParquetWriter(
        output_path,
        first_cleaned.schema,
        compression='zstd',
        use_dictionary=True,
        write_statistics=True
    )
    writer.write_table(first_cleaned)
    
    total_rows_processed = first_rg.num_rows
    total_rows_kept = first_cleaned.num_rows
    
    # Process remaining row groups in parallel
    def process_row_group(rg_index):
        rg_table = pf.read_row_group(rg_index, columns=columns_to_read)
        cleaned_table, _, _ = clean_table_with_rules(rg_table, rules, table_type)
        return cleaned_table, rg_table.num_rows, cleaned_table.num_rows
    
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Skip first row group (already processed)
        future_to_rg = {
            executor.submit(process_row_group, i): i 
            for i in range(1, pf.num_row_groups)
        }
        
        for future in concurrent.futures.as_completed(future_to_rg):
            rg_index = future_to_rg[future]
            try:
                cleaned_table, original_rows, kept_rows = future.result()
                total_rows_processed += original_rows
                total_rows_kept += kept_rows
                
                if cleaned_table.num_rows > 0:
                    writer.write_table(cleaned_table)
                
                print(f"Row group {rg_index}: {original_rows} → {kept_rows} rows")
                
            except Exception as e:
                print(f"Row group {rg_index} failed: {e}")
    
    writer.close()
    
    # Print summary
    original_size = os.path.getsize(input_path)
    final_size = os.path.getsize(output_path)
    
    print(f"\nParallel processing complete: {total_rows_processed:,} → {total_rows_kept:,} rows")
    print(f"File size: {original_size / (1024**3):.2f} GB → {final_size / (1024**3):.2f} GB")

# %% [markdown]
# ## Blocks

# %%
i_file = "/home/ale/Documents/uni/mp/data/raw/blocks.parquet"
o_file = "/home/ale/Documents/uni/mp/data/cleaned/blocks.parquet"
clean_parquet_by_row_groups(i_file, o_file, CLEANING_RULES, table_type="blocks")
# Out:
# Cleaning by row groups...
# Input file: 1.49 GB
# Processing row group 1/978... Applied rules: ['removed_null_did_id', 'removed_null_created_at', 'max_date_created_at', 'min_date_created_at', 'removed_null_subject_id']
# ✅ 122880 → 48478 rows
# Processing row group 2/978... ✅ 122880 → 52394 rows
# Processing row group 3/978... ✅ 122880 → 54286 rows
# Processing row group 4/978... ✅ 122880 → 51458 rows
# Processing row group 5/978... ✅ 122880 → 68535 rows
# Processing row group 6/978... ✅ 122880 → 57533 rows
# Processing row group 7/978... ✅ 122880 → 54511 rows
# Processing row group 8/978... ✅ 122880 → 41068 rows
# Processing row group 9/978... ✅ 122880 → 48115 rows
# Processing row group 10/978... ✅ 122880 → 45942 rows
# Processing row group 11/978... ✅ 122880 → 51595 rows
# Processing row group 12/978... ✅ 122880 → 52311 rows
# Processing row group 13/978... ✅ 122880 → 48304 rows
# Processing row group 14/978... ✅ 122880 → 47306 rows
# Processing row group 15/978... ✅ 122880 → 59587 rows
# Processing row group 16/978... ✅ 122880 → 53759 rows
# Processing row group 17/978... ✅ 122880 → 51955 rows
# Processing row group 18/978... ✅ 123380 → 56284 rows
# Processing row group 19/978... ✅ 122880 → 51599 rows
# Processing row group 20/978... ✅ 122880 → 50330 rows
# Processing row group 21/978... ✅ 122880 → 47073 rows
# Processing row group 22/978... ✅ 122880 → 52688 rows
# Processing row group 23/978... ✅ 122880 → 45981 rows
# Processing row group 24/978... ✅ 122880 → 43735 rows
# Processing row group 25/978... ✅ 122880 → 49918 rows
# Processing row group 26/978... ✅ 122880 → 51457 rows
# Processing row group 27/978... ✅ 122880 → 48215 rows
# Processing row group 28/978... ✅ 122880 → 47749 rows
# Processing row group 29/978... ✅ 122880 → 47426 rows
# Processing row group 30/978... ✅ 122880 → 48459 rows
# Processing row group 31/978... ✅ 122880 → 51104 rows
# Processing row group 32/978... ✅ 122880 → 60228 rows
# Processing row group 33/978... ✅ 122880 → 53950 rows
# Processing row group 34/978... ✅ 122880 → 51440 rows
# Processing row group 35/978... ✅ 123380 → 45662 rows
# Processing row group 36/978... ✅ 122880 → 47513 rows
# Processing row group 37/978... ✅ 122880 → 52977 rows
# Processing row group 38/978... ✅ 122880 → 50097 rows
# Processing row group 39/978... ✅ 122880 → 52117 rows
# Processing row group 40/978... ✅ 122880 → 45505 rows
# Processing row group 41/978... ✅ 122880 → 50251 rows
# Processing row group 42/978... ✅ 122880 → 46845 rows
# Processing row group 43/978... ✅ 122880 → 47020 rows
# Processing row group 44/978... ✅ 122880 → 48546 rows
# Processing row group 45/978... ✅ 122880 → 48735 rows
# Processing row group 46/978... ✅ 122880 → 53222 rows
# Processing row group 47/978... ✅ 122880 → 46442 rows
# Processing row group 48/978... ✅ 122880 → 50527 rows
# Processing row group 49/978... ✅ 122880 → 58640 rows
# Processing row group 50/978... ✅ 122880 → 63613 rows
# Processing row group 51/978... ✅ 122880 → 50723 rows
# Processing row group 52/978... ✅ 123380 → 51620 rows
# Processing row group 53/978... ✅ 122880 → 56974 rows
# Processing row group 54/978... ✅ 122880 → 52038 rows
# Processing row group 55/978... ✅ 122880 → 51537 rows
# Processing row group 56/978... ✅ 122880 → 52882 rows
# Processing row group 57/978... ✅ 122880 → 44781 rows
# Processing row group 58/978... ✅ 122880 → 48369 rows
# Processing row group 59/978... ✅ 122880 → 43528 rows
# Processing row group 60/978... ✅ 122880 → 38233 rows
# Processing row group 61/978... ✅ 122880 → 55336 rows
# Processing row group 62/978... ✅ 122880 → 45980 rows
# Processing row group 63/978... ✅ 122880 → 36946 rows
# Processing row group 64/978... ✅ 122880 → 59743 rows
# Processing row group 65/978... ✅ 122880 → 53719 rows
# Processing row group 66/978... ✅ 122880 → 50613 rows
# Processing row group 67/978... ✅ 122880 → 50819 rows
# Processing row group 68/978... ✅ 122880 → 46914 rows
# Processing row group 69/978... ✅ 123380 → 50923 rows
# Processing row group 70/978... ✅ 122880 → 53218 rows
# Processing row group 71/978... ✅ 122880 → 54667 rows
# Processing row group 72/978... ✅ 122880 → 47117 rows
# Processing row group 73/978... ✅ 122880 → 44799 rows
# Processing row group 74/978... ✅ 122880 → 23405 rows
# Processing row group 75/978... ✅ 122880 → 47841 rows
# Processing row group 76/978... ✅ 122880 → 52649 rows
# Processing row group 77/978... ✅ 122880 → 53624 rows
# Processing row group 78/978... ✅ 122880 → 51934 rows
# Processing row group 79/978... ✅ 122880 → 49393 rows
# Processing row group 80/978... ✅ 122880 → 47250 rows
# Processing row group 81/978... ✅ 122880 → 46671 rows
# Processing row group 82/978... ✅ 122880 → 50817 rows
# Processing row group 83/978... ✅ 122880 → 53921 rows
# Processing row group 84/978... ✅ 122880 → 50190 rows
# Processing row group 85/978... ✅ 122880 → 49962 rows
# Processing row group 86/978... ✅ 123380 → 49585 rows
# Processing row group 87/978... ✅ 122880 → 48422 rows
# Processing row group 88/978... ✅ 122880 → 54172 rows
# Processing row group 89/978... ✅ 122880 → 50642 rows
# Processing row group 90/978... ✅ 122880 → 50130 rows
# Processing row group 91/978... ✅ 122880 → 53204 rows
# Processing row group 92/978... ✅ 122880 → 45913 rows
# Processing row group 93/978... ✅ 122880 → 47898 rows
# Processing row group 94/978... ✅ 122880 → 49439 rows
# Processing row group 95/978... ✅ 122880 → 48427 rows
# Processing row group 96/978... ✅ 122880 → 62134 rows
# Processing row group 97/978... ✅ 122880 → 122880 rows
# Processing row group 98/978... ✅ 122880 → 122880 rows
# Processing row group 99/978... ✅ 122880 → 68956 rows
# Processing row group 100/978... ✅ 122880 → 55837 rows
# Processing row group 101/978... ✅ 122880 → 57095 rows
# Processing row group 102/978... ✅ 122880 → 49517 rows
# Processing row group 103/978... ✅ 123380 → 49522 rows
# Processing row group 104/978... ✅ 122880 → 31917 rows
# Processing row group 105/978... ✅ 122880 → 82958 rows
# Processing row group 106/978... ✅ 122880 → 82601 rows
# Processing row group 107/978... ✅ 122880 → 52676 rows
# Processing row group 108/978... ✅ 122880 → 40074 rows
# Processing row group 109/978... ✅ 122880 → 49185 rows
# Processing row group 110/978... ✅ 122880 → 51635 rows
# Processing row group 111/978... ✅ 122880 → 41194 rows
# Processing row group 112/978... ✅ 122880 → 49511 rows
# Processing row group 113/978... ✅ 122880 → 52260 rows
# Processing row group 114/978... ✅ 122880 → 51560 rows
# Processing row group 115/978... ✅ 122880 → 45844 rows
# Processing row group 116/978... ✅ 122880 → 49505 rows
# Processing row group 117/978... ✅ 122880 → 54382 rows
# Processing row group 118/978... ✅ 122880 → 43775 rows
# Processing row group 119/978... ✅ 122880 → 53639 rows
# Processing row group 120/978... ✅ 123380 → 49870 rows
# Processing row group 121/978... ✅ 122880 → 57165 rows
# Processing row group 122/978... ✅ 122880 → 53758 rows
# Processing row group 123/978... ✅ 122880 → 48661 rows
# Processing row group 124/978... ✅ 122880 → 53257 rows
# Processing row group 125/978... ✅ 122880 → 47792 rows
# Processing row group 126/978... ✅ 122880 → 87538 rows
# Processing row group 127/978... ✅ 122880 → 122880 rows
# Processing row group 128/978... ✅ 122880 → 122880 rows
# Processing row group 129/978... ✅ 122880 → 122880 rows
# Processing row group 130/978... ✅ 122880 → 122880 rows
# Processing row group 131/978... ✅ 122880 → 122880 rows
# Processing row group 132/978... ✅ 122880 → 122880 rows
# Processing row group 133/978... ✅ 122880 → 122880 rows
# Processing row group 134/978... ✅ 122880 → 54059 rows
# Processing row group 135/978... ✅ 122880 → 50323 rows
# Processing row group 136/978... ✅ 122880 → 48077 rows
# Processing row group 137/978... ✅ 123380 → 48841 rows
# Processing row group 138/978... ✅ 122880 → 46342 rows
# Processing row group 139/978... ✅ 122880 → 67532 rows
# Processing row group 140/978... ✅ 122880 → 58315 rows
# Processing row group 141/978... ✅ 122880 → 47506 rows
# Processing row group 142/978... ✅ 122880 → 43622 rows
# Processing row group 143/978... ✅ 122880 → 50945 rows
# Processing row group 144/978... ✅ 122880 → 42334 rows
# Processing row group 145/978... ✅ 122880 → 47246 rows
# Processing row group 146/978... ✅ 122880 → 93928 rows
# Processing row group 147/978... ✅ 122880 → 106466 rows
# Processing row group 148/978... ✅ 122880 → 51567 rows
# Processing row group 149/978... ✅ 122880 → 49770 rows
# Processing row group 150/978... ✅ 122880 → 53160 rows
# Processing row group 151/978... ✅ 122880 → 46227 rows
# Processing row group 152/978... ✅ 122880 → 45100 rows
# Processing row group 153/978... ✅ 122880 → 81587 rows
# Processing row group 154/978... ✅ 123380 → 48364 rows
# Processing row group 155/978... ✅ 122880 → 50213 rows
# Processing row group 156/978... ✅ 122880 → 52824 rows
# Processing row group 157/978... ✅ 122880 → 46706 rows
# Processing row group 158/978... ✅ 122880 → 50689 rows
# Processing row group 159/978... ✅ 122880 → 51744 rows
# Processing row group 160/978... ✅ 122880 → 54998 rows
# Processing row group 161/978... ✅ 122880 → 54329 rows
# Processing row group 162/978... ✅ 122880 → 50797 rows
# Processing row group 163/978... ✅ 122880 → 60591 rows
# Processing row group 164/978... ✅ 122880 → 47626 rows
# Processing row group 165/978... ✅ 122880 → 48366 rows
# Processing row group 166/978... ✅ 122880 → 48793 rows
# Processing row group 167/978... ✅ 122880 → 46988 rows
# Processing row group 168/978... ✅ 122880 → 46420 rows
# Processing row group 169/978... ✅ 122880 → 49052 rows
# Processing row group 170/978... ✅ 122880 → 47489 rows
# Processing row group 171/978... ✅ 123380 → 51977 rows
# Processing row group 172/978... ✅ 122880 → 51712 rows
# Processing row group 173/978... ✅ 122880 → 52250 rows
# Processing row group 174/978... ✅ 122880 → 51417 rows
# Processing row group 175/978... ✅ 122880 → 49767 rows
# Processing row group 176/978... ✅ 122880 → 44601 rows
# Processing row group 177/978... ✅ 122880 → 46412 rows
# Processing row group 178/978... ✅ 122880 → 44472 rows
# Processing row group 179/978... ✅ 122880 → 46513 rows
# Processing row group 180/978... ✅ 122880 → 49369 rows
# Processing row group 181/978... ✅ 122880 → 47523 rows
# Processing row group 182/978... ✅ 122880 → 46818 rows
# Processing row group 183/978... ✅ 122880 → 53494 rows
# Processing row group 184/978... ✅ 122880 → 54009 rows
# Processing row group 185/978... ✅ 122880 → 46964 rows
# Processing row group 186/978... ✅ 122880 → 53755 rows
# Processing row group 187/978... ✅ 122880 → 41110 rows
# Processing row group 188/978... ✅ 123380 → 56536 rows
# Processing row group 189/978... ✅ 122880 → 52808 rows
# Processing row group 190/978... ✅ 122880 → 48463 rows
# Processing row group 191/978... ✅ 122880 → 55819 rows
# Processing row group 192/978... ✅ 122880 → 49274 rows
# Processing row group 193/978... ✅ 122880 → 43720 rows
# Processing row group 194/978... ✅ 122880 → 48955 rows
# Processing row group 195/978... ✅ 122880 → 43463 rows
# Processing row group 196/978... ✅ 122880 → 43747 rows
# Processing row group 197/978... ✅ 122880 → 48971 rows
# Processing row group 198/978... ✅ 122880 → 50623 rows
# Processing row group 199/978... ✅ 122880 → 53058 rows
# Processing row group 200/978... ✅ 122880 → 49612 rows
# Processing row group 201/978... ✅ 122880 → 52007 rows
# Processing row group 202/978... ✅ 122880 → 46588 rows
# Processing row group 203/978... ✅ 122880 → 49391 rows
# Processing row group 204/978... ✅ 122880 → 48994 rows
# Processing row group 205/978... ✅ 123380 → 50200 rows
# Processing row group 206/978... ✅ 122880 → 51430 rows
# Processing row group 207/978... ✅ 122880 → 45915 rows
# Processing row group 208/978... ✅ 122880 → 50467 rows
# Processing row group 209/978... ✅ 122880 → 54348 rows
# Processing row group 210/978... ✅ 122880 → 42970 rows
# Processing row group 211/978... ✅ 122880 → 48463 rows
# Processing row group 212/978... ✅ 122880 → 45857 rows
# Processing row group 213/978... ✅ 122880 → 51334 rows
# Processing row group 214/978... ✅ 122880 → 57147 rows
# Processing row group 215/978... ✅ 122880 → 55091 rows
# Processing row group 216/978... ✅ 122880 → 63452 rows
# Processing row group 217/978... ✅ 122880 → 52725 rows
# Processing row group 218/978... ✅ 122880 → 50146 rows
# Processing row group 219/978... ✅ 122880 → 51780 rows
# Processing row group 220/978... ✅ 122880 → 51042 rows
# Processing row group 221/978... ✅ 122880 → 57910 rows
# Processing row group 222/978... ✅ 123380 → 49704 rows
# Processing row group 223/978... ✅ 122880 → 46371 rows
# Processing row group 224/978... ✅ 122880 → 57470 rows
# Processing row group 225/978... ✅ 122880 → 46083 rows
# Processing row group 226/978... ✅ 122880 → 51699 rows
# Processing row group 227/978... ✅ 122880 → 42532 rows
# Processing row group 228/978... ✅ 122880 → 49529 rows
# Processing row group 229/978... ✅ 122880 → 42721 rows
# Processing row group 230/978... ✅ 122880 → 44815 rows
# Processing row group 231/978... ✅ 122880 → 44865 rows
# Processing row group 232/978... ✅ 122880 → 50399 rows
# Processing row group 233/978... ✅ 122880 → 57456 rows
# Processing row group 234/978... ✅ 122880 → 49969 rows
# Processing row group 235/978... ✅ 122880 → 52153 rows
# Processing row group 236/978... ✅ 122880 → 55320 rows
# Processing row group 237/978... ✅ 122880 → 51010 rows
# Processing row group 238/978... ✅ 122880 → 53725 rows
# Processing row group 239/978... ✅ 123380 → 43517 rows
# Processing row group 240/978... ✅ 122880 → 55688 rows
# Processing row group 241/978... ✅ 122880 → 47387 rows
# Processing row group 242/978... ✅ 122880 → 2887 rows
# Processing row group 243/978... ✅ 122880 → 2646 rows
# Processing row group 244/978... ✅ 122880 → 37828 rows
# Processing row group 245/978... ✅ 122880 → 29550 rows
# Processing row group 246/978... ✅ 122880 → 53182 rows
# Processing row group 247/978... ✅ 122880 → 47479 rows
# Processing row group 248/978... ✅ 122880 → 48313 rows
# Processing row group 249/978... ✅ 122880 → 49086 rows
# Processing row group 250/978... ✅ 122880 → 91647 rows
# Processing row group 251/978... ✅ 122880 → 52418 rows
# Processing row group 252/978... ✅ 122880 → 47425 rows
# Processing row group 253/978... ✅ 122880 → 51479 rows
# Processing row group 254/978... ✅ 122880 → 50140 rows
# Processing row group 255/978... ✅ 122880 → 39689 rows
# Processing row group 256/978... ✅ 123380 → 123380 rows
# Processing row group 257/978... ✅ 122880 → 122880 rows
# Processing row group 258/978... ✅ 122880 → 23817 rows
# Processing row group 259/978... ✅ 122880 → 54472 rows
# Processing row group 260/978... ✅ 122880 → 48750 rows
# Processing row group 261/978... ✅ 122880 → 50349 rows
# Processing row group 262/978... ✅ 122880 → 44109 rows
# Processing row group 263/978... ✅ 122880 → 47324 rows
# Processing row group 264/978... ✅ 122880 → 50871 rows
# Processing row group 265/978... ✅ 122880 → 51015 rows
# Processing row group 266/978... ✅ 122880 → 99019 rows
# Processing row group 267/978... ✅ 122880 → 56808 rows
# Processing row group 268/978... ✅ 122880 → 46087 rows
# Processing row group 269/978... ✅ 122880 → 48322 rows
# Processing row group 270/978... ✅ 122880 → 51254 rows
# Processing row group 271/978... ✅ 122880 → 52273 rows
# Processing row group 272/978... ✅ 122880 → 56173 rows
# Processing row group 273/978... ✅ 123380 → 53262 rows
# Processing row group 274/978... ✅ 122880 → 44519 rows
# Processing row group 275/978... ✅ 122880 → 51273 rows
# Processing row group 276/978... ✅ 122880 → 46827 rows
# Processing row group 277/978... ✅ 122880 → 41775 rows
# Processing row group 278/978... ✅ 122880 → 45849 rows
# Processing row group 279/978... ✅ 122880 → 55497 rows
# Processing row group 280/978... ✅ 122880 → 51346 rows
# Processing row group 281/978... ✅ 122880 → 47005 rows
# Processing row group 282/978... ✅ 122880 → 51365 rows
# Processing row group 283/978... ✅ 122880 → 54213 rows
# Processing row group 284/978... ✅ 122880 → 53511 rows
# Processing row group 285/978... ✅ 122880 → 52452 rows
# Processing row group 286/978... ✅ 122880 → 50842 rows
# Processing row group 287/978... ✅ 122880 → 50593 rows
# Processing row group 288/978... ✅ 122880 → 51304 rows
# Processing row group 289/978... ✅ 122880 → 50977 rows
# Processing row group 290/978... ✅ 123380 → 47846 rows
# Processing row group 291/978... ✅ 122880 → 46529 rows
# Processing row group 292/978... ✅ 122880 → 40327 rows
# Processing row group 293/978... ✅ 122880 → 55041 rows
# Processing row group 294/978... ✅ 122880 → 59728 rows
# Processing row group 295/978... ✅ 122880 → 48338 rows
# Processing row group 296/978... ✅ 122880 → 41915 rows
# Processing row group 297/978... ✅ 122880 → 49868 rows
# Processing row group 298/978... ✅ 122880 → 62701 rows
# Processing row group 299/978... ✅ 122880 → 58390 rows
# Processing row group 300/978... ✅ 122880 → 62005 rows
# Processing row group 301/978... ✅ 122880 → 50498 rows
# Processing row group 302/978... ✅ 122880 → 44698 rows
# Processing row group 303/978... ✅ 122880 → 49682 rows
# Processing row group 304/978... ✅ 122880 → 59391 rows
# Processing row group 305/978... ✅ 122880 → 35293 rows
# Processing row group 306/978... ✅ 122880 → 47449 rows
# Processing row group 307/978... ✅ 123380 → 50570 rows
# Processing row group 308/978... ✅ 122880 → 43230 rows
# Processing row group 309/978... ✅ 122880 → 47386 rows
# Processing row group 310/978... ✅ 122880 → 51380 rows
# Processing row group 311/978... ✅ 122880 → 42729 rows
# Processing row group 312/978... ✅ 122880 → 41385 rows
# Processing row group 313/978... ✅ 122880 → 41439 rows
# Processing row group 314/978... ✅ 122880 → 46140 rows
# Processing row group 315/978... ✅ 122880 → 50504 rows
# Processing row group 316/978... ✅ 122880 → 61181 rows
# Processing row group 317/978... ✅ 122880 → 53222 rows
# Processing row group 318/978... ✅ 122880 → 45031 rows
# Processing row group 319/978... ✅ 122880 → 45654 rows
# Processing row group 320/978... ✅ 122880 → 49512 rows
# Processing row group 321/978... ✅ 122880 → 48976 rows
# Processing row group 322/978... ✅ 122880 → 84259 rows
# Processing row group 323/978... ✅ 122880 → 48594 rows
# Processing row group 324/978... ✅ 123380 → 45971 rows
# Processing row group 325/978... ✅ 122880 → 58595 rows
# Processing row group 326/978... ✅ 122880 → 46936 rows
# Processing row group 327/978... ✅ 122880 → 39293 rows
# Processing row group 328/978... ✅ 122880 → 90163 rows
# Processing row group 329/978... ✅ 122880 → 48542 rows
# Processing row group 330/978... ✅ 122880 → 49696 rows
# Processing row group 331/978... ✅ 122880 → 54064 rows
# Processing row group 332/978... ✅ 122880 → 52368 rows
# Processing row group 333/978... ✅ 122880 → 50610 rows
# Processing row group 334/978... ✅ 122880 → 50242 rows
# Processing row group 335/978... ✅ 122880 → 52700 rows
# Processing row group 336/978... ✅ 122880 → 48266 rows
# Processing row group 337/978... ✅ 122880 → 31075 rows
# Processing row group 338/978... ✅ 122880 → 46093 rows
# Processing row group 339/978... ✅ 122880 → 45977 rows
# Processing row group 340/978... ✅ 122880 → 57035 rows
# Processing row group 341/978... ✅ 123380 → 53625 rows
# Processing row group 342/978... ✅ 122880 → 48577 rows
# Processing row group 343/978... ✅ 122880 → 53565 rows
# Processing row group 344/978... ✅ 122880 → 45924 rows
# Processing row group 345/978... ✅ 122880 → 55545 rows
# Processing row group 346/978... ✅ 122880 → 40664 rows
# Processing row group 347/978... ✅ 122880 → 55867 rows
# Processing row group 348/978... ✅ 122880 → 49466 rows
# Processing row group 349/978... ✅ 122880 → 43093 rows
# Processing row group 350/978... ✅ 122880 → 50582 rows
# Processing row group 351/978... ✅ 122880 → 42066 rows
# Processing row group 352/978... ✅ 122880 → 50312 rows
# Processing row group 353/978... ✅ 122880 → 31622 rows
# Processing row group 354/978... ✅ 122880 → 79950 rows
# Processing row group 355/978... ✅ 122880 → 47796 rows
# Processing row group 356/978... ✅ 122880 → 45950 rows
# Processing row group 357/978... ✅ 122880 → 49673 rows
# Processing row group 358/978... ✅ 123380 → 52797 rows
# Processing row group 359/978... ✅ 122880 → 48349 rows
# Processing row group 360/978... ✅ 122880 → 54309 rows
# Processing row group 361/978... ✅ 122880 → 50850 rows
# Processing row group 362/978... ✅ 122880 → 52947 rows
# Processing row group 363/978... ✅ 122880 → 66436 rows
# Processing row group 364/978... ✅ 122880 → 49262 rows
# Processing row group 365/978... ✅ 122880 → 48555 rows
# Processing row group 366/978... ✅ 122880 → 58289 rows
# Processing row group 367/978... ✅ 122880 → 33815 rows
# Processing row group 368/978... ✅ 122880 → 41467 rows
# Processing row group 369/978... ✅ 122880 → 49120 rows
# Processing row group 370/978... ✅ 122880 → 48314 rows
# Processing row group 371/978... ✅ 122880 → 58810 rows
# Processing row group 372/978... ✅ 122880 → 48988 rows
# Processing row group 373/978... ✅ 122880 → 42796 rows
# Processing row group 374/978... ✅ 122880 → 33735 rows
# Processing row group 375/978... ✅ 123380 → 108740 rows
# Processing row group 376/978... ✅ 122880 → 20449 rows
# Processing row group 377/978... ✅ 122880 → 64998 rows
# Processing row group 378/978... ✅ 122880 → 122880 rows
# Processing row group 379/978... ✅ 122880 → 91262 rows
# Processing row group 380/978... ✅ 122880 → 46329 rows
# Processing row group 381/978... ✅ 122880 → 42030 rows
# Processing row group 382/978... ✅ 122880 → 55419 rows
# Processing row group 383/978... ✅ 122880 → 51985 rows
# Processing row group 384/978... ✅ 122880 → 47512 rows
# Processing row group 385/978... ✅ 122880 → 52390 rows
# Processing row group 386/978... ✅ 122880 → 48840 rows
# Processing row group 387/978... ✅ 122880 → 53494 rows
# Processing row group 388/978... ✅ 122880 → 42922 rows
# Processing row group 389/978... ✅ 122880 → 51330 rows
# Processing row group 390/978... ✅ 122880 → 51357 rows
# Processing row group 391/978... ✅ 122880 → 61544 rows
# Processing row group 392/978... ✅ 123380 → 52166 rows
# Processing row group 393/978... ✅ 122880 → 50616 rows
# Processing row group 394/978... ✅ 122880 → 52085 rows
# Processing row group 395/978... ✅ 122880 → 48940 rows
# Processing row group 396/978... ✅ 122880 → 51020 rows
# Processing row group 397/978... ✅ 122880 → 47725 rows
# Processing row group 398/978... ✅ 122880 → 44182 rows
# Processing row group 399/978... ✅ 122880 → 50103 rows
# Processing row group 400/978... ✅ 122880 → 50394 rows
# Processing row group 401/978... ✅ 122880 → 51891 rows
# Processing row group 402/978... ✅ 122880 → 45787 rows
# Processing row group 403/978... ✅ 122880 → 56633 rows
# Processing row group 404/978... ✅ 122880 → 50469 rows
# Processing row group 405/978... ✅ 122880 → 58693 rows
# Processing row group 406/978... ✅ 122880 → 52447 rows
# Processing row group 407/978... ✅ 122880 → 59239 rows
# Processing row group 408/978... ✅ 122880 → 46427 rows
# Processing row group 409/978... ✅ 123380 → 48593 rows
# Processing row group 410/978... ✅ 122880 → 47903 rows
# Processing row group 411/978... ✅ 122880 → 48420 rows
# Processing row group 412/978... ✅ 122880 → 71002 rows
# Processing row group 413/978... ✅ 122880 → 48525 rows
# Processing row group 414/978... ✅ 122880 → 48047 rows
# Processing row group 415/978... ✅ 122880 → 58406 rows
# Processing row group 416/978... ✅ 122880 → 45427 rows
# Processing row group 417/978... ✅ 122880 → 46934 rows
# Processing row group 418/978... ✅ 122880 → 53959 rows
# Processing row group 419/978... ✅ 122880 → 49194 rows
# Processing row group 420/978... ✅ 122880 → 27071 rows
# Processing row group 421/978... ✅ 122880 → 48727 rows
# Processing row group 422/978... ✅ 122880 → 50398 rows
# Processing row group 423/978... ✅ 122880 → 53201 rows
# Processing row group 424/978... ✅ 122880 → 50819 rows
# Processing row group 425/978... ✅ 122880 → 50188 rows
# Processing row group 426/978... ✅ 123380 → 45439 rows
# Processing row group 427/978... ✅ 122880 → 38769 rows
# Processing row group 428/978... ✅ 122880 → 46746 rows
# Processing row group 429/978... ✅ 122880 → 34153 rows
# Processing row group 430/978... ✅ 122880 → 41761 rows
# Processing row group 431/978... ✅ 122880 → 46023 rows
# Processing row group 432/978... ✅ 122880 → 55539 rows
# Processing row group 433/978... ✅ 122880 → 54465 rows
# Processing row group 434/978... ✅ 122880 → 47118 rows
# Processing row group 435/978... ✅ 122880 → 43012 rows
# Processing row group 436/978... ✅ 122880 → 58169 rows
# Processing row group 437/978... ✅ 122880 → 54987 rows
# Processing row group 438/978... ✅ 122880 → 46978 rows
# Processing row group 439/978... ✅ 122880 → 46064 rows
# Processing row group 440/978... ✅ 122880 → 48895 rows
# Processing row group 441/978... ✅ 122880 → 46913 rows
# Processing row group 442/978... ✅ 122880 → 39668 rows
# Processing row group 443/978... ✅ 123380 → 42429 rows
# Processing row group 444/978... ✅ 122880 → 52391 rows
# Processing row group 445/978... ✅ 122880 → 47136 rows
# Processing row group 446/978... ✅ 122880 → 52535 rows
# Processing row group 447/978... ✅ 122880 → 53307 rows
# Processing row group 448/978... ✅ 122880 → 51726 rows
# Processing row group 449/978... ✅ 122880 → 61046 rows
# Processing row group 450/978... ✅ 122880 → 53244 rows
# Processing row group 451/978... ✅ 122880 → 46836 rows
# Processing row group 452/978... ✅ 122880 → 49891 rows
# Processing row group 453/978... ✅ 122880 → 52224 rows
# Processing row group 454/978... ✅ 122880 → 49099 rows
# Processing row group 455/978... ✅ 122880 → 49164 rows
# Processing row group 456/978... ✅ 122880 → 50509 rows
# Processing row group 457/978... ✅ 122880 → 45463 rows
# Processing row group 458/978... ✅ 122880 → 69325 rows
# Processing row group 459/978... ✅ 122880 → 51493 rows
# Processing row group 460/978... ✅ 123380 → 37489 rows
# Processing row group 461/978... ✅ 122880 → 49193 rows
# Processing row group 462/978... ✅ 122880 → 48333 rows
# Processing row group 463/978... ✅ 122880 → 47951 rows
# Processing row group 464/978... ✅ 122880 → 38829 rows
# Processing row group 465/978... ✅ 122880 → 49546 rows
# Processing row group 466/978... ✅ 122880 → 49873 rows
# Processing row group 467/978... ✅ 122880 → 49425 rows
# Processing row group 468/978... ✅ 122880 → 50910 rows
# Processing row group 469/978... ✅ 122880 → 35842 rows
# Processing row group 470/978... ✅ 122880 → 122880 rows
# Processing row group 471/978... ✅ 122880 → 82188 rows
# Processing row group 472/978... ✅ 122880 → 47289 rows
# Processing row group 473/978... ✅ 122880 → 34728 rows
# Processing row group 474/978... ✅ 122880 → 50210 rows
# Processing row group 475/978... ✅ 122880 → 57624 rows
# Processing row group 476/978... ✅ 122880 → 70947 rows
# Processing row group 477/978... ✅ 123380 → 58992 rows
# Processing row group 478/978... ✅ 122880 → 51573 rows
# Processing row group 479/978... ✅ 122880 → 50412 rows
# Processing row group 480/978... ✅ 122880 → 56922 rows
# Processing row group 481/978... ✅ 122880 → 45792 rows
# Processing row group 482/978... ✅ 122880 → 57612 rows
# Processing row group 483/978... ✅ 122880 → 79386 rows
# Processing row group 484/978... ✅ 122880 → 46806 rows
# Processing row group 485/978... ✅ 122880 → 52581 rows
# Processing row group 486/978... ✅ 122880 → 27988 rows
# Processing row group 487/978... ✅ 122880 → 104818 rows
# Processing row group 488/978... ✅ 122880 → 33963 rows
# Processing row group 489/978... ✅ 122880 → 46771 rows
# Processing row group 490/978... ✅ 122880 → 47497 rows
# Processing row group 491/978... ✅ 122880 → 61073 rows
# Processing row group 492/978... ✅ 122880 → 50907 rows
# Processing row group 493/978... ✅ 122880 → 45379 rows
# Processing row group 494/978... ✅ 123380 → 57460 rows
# Processing row group 495/978... ✅ 122880 → 52077 rows
# Processing row group 496/978... ✅ 122880 → 53394 rows
# Processing row group 497/978... ✅ 122880 → 44166 rows
# Processing row group 498/978... ✅ 122880 → 37251 rows
# Processing row group 499/978... ✅ 122880 → 58011 rows
# Processing row group 500/978... ✅ 122880 → 45751 rows
# Processing row group 501/978... ✅ 122880 → 50610 rows
# Processing row group 502/978... ✅ 122880 → 51408 rows
# Processing row group 503/978... ✅ 122880 → 47181 rows
# Processing row group 504/978... ✅ 122880 → 52135 rows
# Processing row group 505/978... ✅ 122880 → 51681 rows
# Processing row group 506/978... ✅ 122880 → 48673 rows
# Processing row group 507/978... ✅ 122880 → 51084 rows
# Processing row group 508/978... ✅ 122880 → 42999 rows
# Processing row group 509/978... ✅ 122880 → 53607 rows
# Processing row group 510/978... ✅ 122880 → 54579 rows
# Processing row group 511/978... ✅ 123380 → 50874 rows
# Processing row group 512/978... ✅ 122880 → 47116 rows
# Processing row group 513/978... ✅ 122880 → 11698 rows
# Processing row group 514/978... ✅ 122880 → 33740 rows
# Processing row group 515/978... ✅ 122880 → 59490 rows
# Processing row group 516/978... ✅ 122880 → 55342 rows
# Processing row group 517/978... ✅ 122880 → 60102 rows
# Processing row group 518/978... ✅ 122880 → 56356 rows
# Processing row group 519/978... ✅ 122880 → 49487 rows
# Processing row group 520/978... ✅ 122880 → 49306 rows
# Processing row group 521/978... ✅ 122880 → 82520 rows
# Processing row group 522/978... ✅ 122880 → 54769 rows
# Processing row group 523/978... ✅ 122880 → 59843 rows
# Processing row group 524/978... ✅ 122880 → 57590 rows
# Processing row group 525/978... ✅ 122880 → 49794 rows
# Processing row group 526/978... ✅ 122880 → 50023 rows
# Processing row group 527/978... ✅ 122880 → 52814 rows
# Processing row group 528/978... ✅ 123380 → 20954 rows
# Processing row group 529/978... ✅ 122880 → 47985 rows
# Processing row group 530/978... ✅ 122880 → 47963 rows
# Processing row group 531/978... ✅ 122880 → 47839 rows
# Processing row group 532/978... ✅ 122880 → 36348 rows
# Processing row group 533/978... ✅ 122880 → 32460 rows
# Processing row group 534/978... ✅ 122880 → 52061 rows
# Processing row group 535/978... ✅ 122880 → 48983 rows
# Processing row group 536/978... ✅ 122880 → 51636 rows
# Processing row group 537/978... ✅ 122880 → 78006 rows
# Processing row group 538/978... ✅ 122880 → 47653 rows
# Processing row group 539/978... ✅ 122880 → 51205 rows
# Processing row group 540/978... ✅ 122880 → 50406 rows
# Processing row group 541/978... ✅ 122880 → 45674 rows
# Processing row group 542/978... ✅ 122880 → 48898 rows
# Processing row group 543/978... ✅ 122880 → 49212 rows
# Processing row group 544/978... ✅ 122880 → 50565 rows
# Processing row group 545/978... ✅ 123380 → 51157 rows
# Processing row group 546/978... ✅ 122880 → 53431 rows
# Processing row group 547/978... ✅ 122880 → 84183 rows
# Processing row group 548/978... ✅ 122880 → 47836 rows
# Processing row group 549/978... ✅ 122880 → 47261 rows
# Processing row group 550/978... ✅ 122880 → 47255 rows
# Processing row group 551/978... ✅ 122880 → 53137 rows
# Processing row group 552/978... ✅ 122880 → 59074 rows
# Processing row group 553/978... ✅ 122880 → 50992 rows
# Processing row group 554/978... ✅ 122880 → 49738 rows
# Processing row group 555/978... ✅ 122880 → 52515 rows
# Processing row group 556/978... ✅ 122880 → 42077 rows
# Processing row group 557/978... ✅ 122880 → 54877 rows
# Processing row group 558/978... ✅ 122880 → 37625 rows
# Processing row group 559/978... ✅ 122880 → 51198 rows
# Processing row group 560/978... ✅ 122880 → 55465 rows
# Processing row group 561/978... ✅ 122880 → 51091 rows
# Processing row group 562/978... ✅ 123380 → 42811 rows
# Processing row group 563/978... ✅ 122880 → 45473 rows
# Processing row group 564/978... ✅ 122880 → 17318 rows
# Processing row group 565/978... ✅ 122880 → 47807 rows
# Processing row group 566/978... ✅ 122880 → 50354 rows
# Processing row group 567/978... ✅ 122880 → 56736 rows
# Processing row group 568/978... ✅ 122880 → 49357 rows
# Processing row group 569/978... ✅ 122880 → 45994 rows
# Processing row group 570/978... ✅ 122880 → 49325 rows
# Processing row group 571/978... ✅ 122880 → 44631 rows
# Processing row group 572/978... ✅ 122880 → 48040 rows
# Processing row group 573/978... ✅ 122880 → 60132 rows
# Processing row group 574/978... ✅ 122880 → 62727 rows
# Processing row group 575/978... ✅ 122880 → 54777 rows
# Processing row group 576/978... ✅ 122880 → 49870 rows
# Processing row group 577/978... ✅ 122880 → 50825 rows
# Processing row group 578/978... ✅ 122880 → 49146 rows
# Processing row group 579/978... ✅ 123380 → 48352 rows
# Processing row group 580/978... ✅ 122880 → 51154 rows
# Processing row group 581/978... ✅ 122880 → 53094 rows
# Processing row group 582/978... ✅ 122880 → 52826 rows
# Processing row group 583/978... ✅ 122880 → 45253 rows
# Processing row group 584/978... ✅ 122880 → 103507 rows
# Processing row group 585/978... ✅ 122880 → 122880 rows
# Processing row group 586/978... ✅ 122880 → 122880 rows
# Processing row group 587/978... ✅ 122880 → 122880 rows
# Processing row group 588/978... ✅ 122880 → 122880 rows
# Processing row group 589/978... ✅ 122880 → 122880 rows
# Processing row group 590/978... ✅ 122880 → 122880 rows
# Processing row group 591/978... ✅ 122880 → 122880 rows
# Processing row group 592/978... ✅ 122880 → 94158 rows
# Processing row group 593/978... ✅ 122880 → 49924 rows
# Processing row group 594/978... ✅ 122880 → 51620 rows
# Processing row group 595/978... ✅ 122880 → 51319 rows
# Processing row group 596/978... ✅ 123380 → 52688 rows
# Processing row group 597/978... ✅ 122880 → 51093 rows
# Processing row group 598/978... ✅ 122880 → 47984 rows
# Processing row group 599/978... ✅ 122880 → 52697 rows
# Processing row group 600/978... ✅ 122880 → 42793 rows
# Processing row group 601/978... ✅ 122880 → 48554 rows
# Processing row group 602/978... ✅ 122880 → 47650 rows
# Processing row group 603/978... ✅ 122880 → 49537 rows
# Processing row group 604/978... ✅ 122880 → 46990 rows
# Processing row group 605/978... ✅ 122880 → 61001 rows
# Processing row group 606/978... ✅ 122880 → 53752 rows
# Processing row group 607/978... ✅ 122880 → 48059 rows
# Processing row group 608/978... ✅ 122880 → 53440 rows
# Processing row group 609/978... ✅ 122880 → 51876 rows
# Processing row group 610/978... ✅ 122880 → 45318 rows
# Processing row group 611/978... ✅ 122880 → 48663 rows
# Processing row group 612/978... ✅ 122880 → 57460 rows
# Processing row group 613/978... ✅ 123380 → 53433 rows
# Processing row group 614/978... ✅ 122880 → 46883 rows
# Processing row group 615/978... ✅ 122880 → 55219 rows
# Processing row group 616/978... ✅ 122880 → 47795 rows
# Processing row group 617/978... ✅ 122880 → 50121 rows
# Processing row group 618/978... ✅ 122880 → 55384 rows
# Processing row group 619/978... ✅ 122880 → 43368 rows
# Processing row group 620/978... ✅ 122880 → 48860 rows
# Processing row group 621/978... ✅ 122880 → 48090 rows
# Processing row group 622/978... ✅ 122880 → 49446 rows
# Processing row group 623/978... ✅ 122880 → 16729 rows
# Processing row group 624/978... ✅ 122880 → 80154 rows
# Processing row group 625/978... ✅ 122880 → 57379 rows
# Processing row group 626/978... ✅ 122880 → 53483 rows
# Processing row group 627/978... ✅ 122880 → 46431 rows
# Processing row group 628/978... ✅ 122880 → 45339 rows
# Processing row group 629/978... ✅ 122880 → 35306 rows
# Processing row group 630/978... ✅ 123380 → 63713 rows
# Processing row group 631/978... ✅ 122880 → 54219 rows
# Processing row group 632/978... ✅ 122880 → 43106 rows
# Processing row group 633/978... ✅ 122880 → 38298 rows
# Processing row group 634/978... ✅ 122880 → 61948 rows
# Processing row group 635/978... ✅ 122880 → 55998 rows
# Processing row group 636/978... ✅ 122880 → 52594 rows
# Processing row group 637/978... ✅ 122880 → 52990 rows
# Processing row group 638/978... ✅ 122880 → 50585 rows
# Processing row group 639/978... ✅ 122880 → 50363 rows
# Processing row group 640/978... ✅ 122880 → 43997 rows
# Processing row group 641/978... ✅ 122880 → 47058 rows
# Processing row group 642/978... ✅ 122880 → 42430 rows
# Processing row group 643/978... ✅ 122880 → 51218 rows
# Processing row group 644/978... ✅ 122880 → 52199 rows
# Processing row group 645/978... ✅ 122880 → 51722 rows
# Processing row group 646/978... ✅ 122880 → 122880 rows
# Processing row group 647/978... ✅ 123380 → 87933 rows
# Processing row group 648/978... ✅ 122880 → 48112 rows
# Processing row group 649/978... ✅ 122880 → 57428 rows
# Processing row group 650/978... ✅ 122880 → 55865 rows
# Processing row group 651/978... ✅ 122880 → 48755 rows
# Processing row group 652/978... ✅ 122880 → 51151 rows
# Processing row group 653/978... ✅ 122880 → 43973 rows
# Processing row group 654/978... ✅ 122880 → 45759 rows
# Processing row group 655/978... ✅ 122880 → 49241 rows
# Processing row group 656/978... ✅ 122880 → 52672 rows
# Processing row group 657/978... ✅ 122880 → 46149 rows
# Processing row group 658/978... ✅ 122880 → 54251 rows
# Processing row group 659/978... ✅ 122880 → 47326 rows
# Processing row group 660/978... ✅ 122880 → 41787 rows
# Processing row group 661/978... ✅ 122880 → 52160 rows
# Processing row group 662/978... ✅ 122880 → 49307 rows
# Processing row group 663/978... ✅ 122880 → 48750 rows
# Processing row group 664/978... ✅ 123380 → 50272 rows
# Processing row group 665/978... ✅ 122880 → 45314 rows
# Processing row group 666/978... ✅ 122880 → 49175 rows
# Processing row group 667/978... ✅ 122880 → 52743 rows
# Processing row group 668/978... ✅ 122880 → 46159 rows
# Processing row group 669/978... ✅ 122880 → 49916 rows
# Processing row group 670/978... ✅ 122880 → 49217 rows
# Processing row group 671/978... ✅ 122880 → 44886 rows
# Processing row group 672/978... ✅ 122880 → 44857 rows
# Processing row group 673/978... ✅ 122880 → 52030 rows
# Processing row group 674/978... ✅ 122880 → 37317 rows
# Processing row group 675/978... ✅ 122880 → 51643 rows
# Processing row group 676/978... ✅ 122880 → 45962 rows
# Processing row group 677/978... ✅ 122880 → 55848 rows
# Processing row group 678/978... ✅ 122880 → 51726 rows
# Processing row group 679/978... ✅ 122880 → 42693 rows
# Processing row group 680/978... ✅ 122880 → 122880 rows
# Processing row group 681/978... ✅ 123380 → 17081 rows
# Processing row group 682/978... ✅ 122880 → 42409 rows
# Processing row group 683/978... ✅ 122880 → 53293 rows
# Processing row group 684/978... ✅ 122880 → 55959 rows
# Processing row group 685/978... ✅ 122880 → 44119 rows
# Processing row group 686/978... ✅ 122880 → 48270 rows
# Processing row group 687/978... ✅ 122880 → 70692 rows
# Processing row group 688/978... ✅ 122880 → 32231 rows
# Processing row group 689/978... ✅ 122880 → 37255 rows
# Processing row group 690/978... ✅ 122880 → 101344 rows
# Processing row group 691/978... ✅ 122880 → 45619 rows
# Processing row group 692/978... ✅ 122880 → 54106 rows
# Processing row group 693/978... ✅ 122880 → 28632 rows
# Processing row group 694/978... ✅ 122880 → 20594 rows
# Processing row group 695/978... ✅ 122880 → 44656 rows
# Processing row group 696/978... ✅ 122880 → 49470 rows
# Processing row group 697/978... ✅ 122880 → 10895 rows
# Processing row group 698/978... ✅ 123380 → 44577 rows
# Processing row group 699/978... ✅ 122880 → 122880 rows
# Processing row group 700/978... ✅ 122880 → 45611 rows
# Processing row group 701/978... ✅ 122880 → 51454 rows
# Processing row group 702/978... ✅ 122880 → 47531 rows
# Processing row group 703/978... ✅ 122880 → 30504 rows
# Processing row group 704/978... ✅ 122880 → 66322 rows
# Processing row group 705/978... ✅ 122880 → 47077 rows
# Processing row group 706/978... ✅ 122880 → 56192 rows
# Processing row group 707/978... ✅ 122880 → 43769 rows
# Processing row group 708/978... ✅ 122880 → 50213 rows
# Processing row group 709/978... ✅ 122880 → 41510 rows
# Processing row group 710/978... ✅ 122880 → 75958 rows
# Processing row group 711/978... ✅ 122880 → 51594 rows
# Processing row group 712/978... ✅ 122880 → 52152 rows
# Processing row group 713/978... ✅ 122880 → 51373 rows
# Processing row group 714/978... ✅ 122880 → 9716 rows
# Processing row group 715/978... ✅ 123380 → 48767 rows
# Processing row group 716/978... ✅ 122880 → 51030 rows
# Processing row group 717/978... ✅ 122880 → 47294 rows
# Processing row group 718/978... ✅ 122880 → 48922 rows
# Processing row group 719/978... ✅ 122880 → 50565 rows
# Processing row group 720/978... ✅ 122880 → 44006 rows
# Processing row group 721/978... ✅ 122880 → 51817 rows
# Processing row group 722/978... ✅ 122880 → 41699 rows
# Processing row group 723/978... ✅ 122880 → 49645 rows
# Processing row group 724/978... ✅ 122880 → 47983 rows
# Processing row group 725/978... ✅ 122880 → 46808 rows
# Processing row group 726/978... ✅ 122880 → 47639 rows
# Processing row group 727/978... ✅ 122880 → 53183 rows
# Processing row group 728/978... ✅ 122880 → 46765 rows
# Processing row group 729/978... ✅ 122880 → 45311 rows
# Processing row group 730/978... ✅ 122880 → 46014 rows
# Processing row group 731/978... ✅ 122880 → 30382 rows
# Processing row group 732/978... ✅ 123380 → 77157 rows
# Processing row group 733/978... ✅ 122880 → 51652 rows
# Processing row group 734/978... ✅ 122880 → 81833 rows
# Processing row group 735/978... ✅ 122880 → 57323 rows
# Processing row group 736/978... ✅ 122880 → 46410 rows
# Processing row group 737/978... ✅ 122880 → 122880 rows
# Processing row group 738/978... ✅ 122880 → 122880 rows
# Processing row group 739/978... ✅ 122880 → 93795 rows
# Processing row group 740/978... ✅ 122880 → 46574 rows
# Processing row group 741/978... ✅ 122880 → 54025 rows
# Processing row group 742/978... ✅ 122880 → 50413 rows
# Processing row group 743/978... ✅ 122880 → 49830 rows
# Processing row group 744/978... ✅ 122880 → 56420 rows
# Processing row group 745/978... ✅ 122880 → 47336 rows
# Processing row group 746/978... ✅ 122880 → 58074 rows
# Processing row group 747/978... ✅ 122880 → 49701 rows
# Processing row group 748/978... ✅ 122880 → 49889 rows
# Processing row group 749/978... ✅ 123380 → 52940 rows
# Processing row group 750/978... ✅ 122880 → 66402 rows
# Processing row group 751/978... ✅ 122880 → 43727 rows
# Processing row group 752/978... ✅ 122880 → 122880 rows
# Processing row group 753/978... ✅ 122880 → 122880 rows
# Processing row group 754/978... ✅ 122880 → 122880 rows
# Processing row group 755/978... ✅ 122880 → 122880 rows
# Processing row group 756/978... ✅ 122880 → 122880 rows
# Processing row group 757/978... ✅ 122880 → 122880 rows
# Processing row group 758/978... ✅ 122880 → 89901 rows
# Processing row group 759/978... ✅ 122880 → 122880 rows
# Processing row group 760/978... ✅ 122880 → 122880 rows
# Processing row group 761/978... ✅ 122880 → 122880 rows
# Processing row group 762/978... ✅ 122880 → 122880 rows
# Processing row group 763/978... ✅ 122880 → 122880 rows
# Processing row group 764/978... ✅ 122880 → 122880 rows
# Processing row group 765/978... ✅ 122880 → 122880 rows
# Processing row group 766/978... ✅ 123380 → 123380 rows
# Processing row group 767/978... ✅ 122880 → 122880 rows
# Processing row group 768/978... ✅ 122880 → 58698 rows
# Processing row group 769/978... ✅ 122880 → 47132 rows
# Processing row group 770/978... ✅ 122880 → 51856 rows
# Processing row group 771/978... ✅ 122880 → 48175 rows
# Processing row group 772/978... ✅ 122880 → 45874 rows
# Processing row group 773/978... ✅ 122880 → 48381 rows
# Processing row group 774/978... ✅ 122880 → 41162 rows
# Processing row group 775/978... ✅ 122880 → 105275 rows
# Processing row group 776/978... ✅ 122880 → 122880 rows
# Processing row group 777/978... ✅ 122880 → 122880 rows
# Processing row group 778/978... ✅ 122880 → 91339 rows
# Processing row group 779/978... ✅ 122880 → 53561 rows
# Processing row group 780/978... ✅ 122880 → 50895 rows
# Processing row group 781/978... ✅ 122880 → 54648 rows
# Processing row group 782/978... ✅ 122880 → 50886 rows
# Processing row group 783/978... ✅ 123380 → 55474 rows
# Processing row group 784/978... ✅ 122880 → 45153 rows
# Processing row group 785/978... ✅ 122880 → 47737 rows
# Processing row group 786/978... ✅ 122880 → 46844 rows
# Processing row group 787/978... ✅ 122880 → 48378 rows
# Processing row group 788/978... ✅ 122880 → 50485 rows
# Processing row group 789/978... ✅ 122880 → 49741 rows
# Processing row group 790/978... ✅ 122880 → 46724 rows
# Processing row group 791/978... ✅ 122880 → 41888 rows
# Processing row group 792/978... ✅ 122880 → 78733 rows
# Processing row group 793/978... ✅ 122880 → 53866 rows
# Processing row group 794/978... ✅ 122880 → 53339 rows
# Processing row group 795/978... ✅ 122880 → 52070 rows
# Processing row group 796/978... ✅ 122880 → 50008 rows
# Processing row group 797/978... ✅ 122880 → 50891 rows
# Processing row group 798/978... ✅ 122880 → 50031 rows
# Processing row group 799/978... ✅ 122880 → 56178 rows
# Processing row group 800/978... ✅ 123380 → 50042 rows
# Processing row group 801/978... ✅ 122880 → 52400 rows
# Processing row group 802/978... ✅ 122880 → 32249 rows
# Processing row group 803/978... ✅ 122880 → 117002 rows
# Processing row group 804/978... ✅ 122880 → 122880 rows
# Processing row group 805/978... ✅ 122880 → 50454 rows
# Processing row group 806/978... ✅ 122880 → 38532 rows
# Processing row group 807/978... ✅ 122880 → 55135 rows
# Processing row group 808/978... ✅ 122880 → 52490 rows
# Processing row group 809/978... ✅ 122880 → 49832 rows
# Processing row group 810/978... ✅ 122880 → 46499 rows
# Processing row group 811/978... ✅ 122880 → 48911 rows
# Processing row group 812/978... ✅ 122880 → 47855 rows
# Processing row group 813/978... ✅ 122880 → 48767 rows
# Processing row group 814/978... ✅ 122880 → 54059 rows
# Processing row group 815/978... ✅ 122880 → 31343 rows
# Processing row group 816/978... ✅ 122880 → 13860 rows
# Processing row group 817/978... ✅ 123380 → 26496 rows
# Processing row group 818/978... ✅ 122880 → 54181 rows
# Processing row group 819/978... ✅ 122880 → 43828 rows
# Processing row group 820/978... ✅ 122880 → 42087 rows
# Processing row group 821/978... ✅ 122880 → 45416 rows
# Processing row group 822/978... ✅ 122880 → 54908 rows
# Processing row group 823/978... ✅ 122880 → 48414 rows
# Processing row group 824/978... ✅ 122880 → 42387 rows
# Processing row group 825/978... ✅ 122880 → 49200 rows
# Processing row group 826/978... ✅ 122880 → 53029 rows
# Processing row group 827/978... ✅ 122880 → 78777 rows
# Processing row group 828/978... ✅ 122880 → 54706 rows
# Processing row group 829/978... ✅ 122880 → 48636 rows
# Processing row group 830/978... ✅ 122880 → 53468 rows
# Processing row group 831/978... ✅ 122880 → 53285 rows
# Processing row group 832/978... ✅ 122880 → 50833 rows
# Processing row group 833/978... ✅ 122880 → 47587 rows
# Processing row group 834/978... ✅ 123380 → 49579 rows
# Processing row group 835/978... ✅ 122880 → 44766 rows
# Processing row group 836/978... ✅ 122880 → 43783 rows
# Processing row group 837/978... ✅ 122880 → 46379 rows
# Processing row group 838/978... ✅ 122880 → 48008 rows
# Processing row group 839/978... ✅ 122880 → 33167 rows
# Processing row group 840/978... ✅ 122880 → 52590 rows
# Processing row group 841/978... ✅ 122880 → 49259 rows
# Processing row group 842/978... ✅ 122880 → 57794 rows
# Processing row group 843/978... ✅ 122880 → 55928 rows
# Processing row group 844/978... ✅ 122880 → 50706 rows
# Processing row group 845/978... ✅ 122880 → 52440 rows
# Processing row group 846/978... ✅ 122880 → 51391 rows
# Processing row group 847/978... ✅ 122880 → 50241 rows
# Processing row group 848/978... ✅ 122880 → 53122 rows
# Processing row group 849/978... ✅ 122880 → 48762 rows
# Processing row group 850/978... ✅ 122880 → 122880 rows
# Processing row group 851/978... ✅ 123380 → 123380 rows
# Processing row group 852/978... ✅ 122880 → 39247 rows
# Processing row group 853/978... ✅ 122880 → 32735 rows
# Processing row group 854/978... ✅ 122880 → 74211 rows
# Processing row group 855/978... ✅ 122880 → 42536 rows
# Processing row group 856/978... ✅ 122880 → 55787 rows
# Processing row group 857/978... ✅ 122880 → 52543 rows
# Processing row group 858/978... ✅ 122880 → 49984 rows
# Processing row group 859/978... ✅ 122880 → 47607 rows
# Processing row group 860/978... ✅ 122880 → 46733 rows
# Processing row group 861/978... ✅ 122880 → 48471 rows
# Processing row group 862/978... ✅ 122880 → 50245 rows
# Processing row group 863/978... ✅ 122880 → 50245 rows
# Processing row group 864/978... ✅ 122880 → 53960 rows
# Processing row group 865/978... ✅ 122880 → 47294 rows
# Processing row group 866/978... ✅ 122880 → 53366 rows
# Processing row group 867/978... ✅ 122880 → 42522 rows
# Processing row group 868/978... ✅ 123380 → 52162 rows
# Processing row group 869/978... ✅ 122880 → 47836 rows
# Processing row group 870/978... ✅ 122880 → 54528 rows
# Processing row group 871/978... ✅ 122880 → 52348 rows
# Processing row group 872/978... ✅ 122880 → 34916 rows
# Processing row group 873/978... ✅ 122880 → 53571 rows
# Processing row group 874/978... ✅ 122880 → 51602 rows
# Processing row group 875/978... ✅ 122880 → 51791 rows
# Processing row group 876/978... ✅ 122880 → 50689 rows
# Processing row group 877/978... ✅ 122880 → 47453 rows
# Processing row group 878/978... ✅ 122880 → 48986 rows
# Processing row group 879/978... ✅ 122880 → 53205 rows
# Processing row group 880/978... ✅ 122880 → 46394 rows
# Processing row group 881/978... ✅ 122880 → 47987 rows
# Processing row group 882/978... ✅ 122880 → 50188 rows
# Processing row group 883/978... ✅ 122880 → 47503 rows
# Processing row group 884/978... ✅ 122880 → 48543 rows
# Processing row group 885/978... ✅ 123380 → 47213 rows
# Processing row group 886/978... ✅ 122880 → 50067 rows
# Processing row group 887/978... ✅ 122880 → 45138 rows
# Processing row group 888/978... ✅ 122880 → 46420 rows
# Processing row group 889/978... ✅ 122880 → 57757 rows
# Processing row group 890/978... ✅ 122880 → 53340 rows
# Processing row group 891/978... ✅ 122880 → 45852 rows
# Processing row group 892/978... ✅ 122880 → 47290 rows
# Processing row group 893/978... ✅ 122880 → 51062 rows
# Processing row group 894/978... ✅ 122880 → 58213 rows
# Processing row group 895/978... ✅ 122880 → 48359 rows
# Processing row group 896/978... ✅ 122880 → 50385 rows
# Processing row group 897/978... ✅ 122880 → 44501 rows
# Processing row group 898/978... ✅ 122880 → 50232 rows
# Processing row group 899/978... ✅ 122880 → 48918 rows
# Processing row group 900/978... ✅ 122880 → 53531 rows
# Processing row group 901/978... ✅ 122880 → 50421 rows
# Processing row group 902/978... ✅ 123380 → 47533 rows
# Processing row group 903/978... ✅ 122880 → 48020 rows
# Processing row group 904/978... ✅ 122880 → 48121 rows
# Processing row group 905/978... ✅ 122880 → 46078 rows
# Processing row group 906/978... ✅ 122880 → 53388 rows
# Processing row group 907/978... ✅ 122880 → 35647 rows
# Processing row group 908/978... ✅ 122880 → 68829 rows
# Processing row group 909/978... ✅ 122880 → 52735 rows
# Processing row group 910/978... ✅ 122880 → 52516 rows
# Processing row group 911/978... ✅ 122880 → 48019 rows
# Processing row group 912/978... ✅ 122880 → 53685 rows
# Processing row group 913/978... ✅ 122880 → 43562 rows
# Processing row group 914/978... ✅ 122880 → 54475 rows
# Processing row group 915/978... ✅ 122880 → 39800 rows
# Processing row group 916/978... ✅ 122880 → 50338 rows
# Processing row group 917/978... ✅ 122880 → 43853 rows
# Processing row group 918/978... ✅ 122880 → 49321 rows
# Processing row group 919/978... ✅ 123380 → 55162 rows
# Processing row group 920/978... ✅ 122880 → 53279 rows
# Processing row group 921/978... ✅ 122880 → 48626 rows
# Processing row group 922/978... ✅ 122880 → 51717 rows
# Processing row group 923/978... ✅ 122880 → 50045 rows
# Processing row group 924/978... ✅ 122880 → 44025 rows
# Processing row group 925/978... ✅ 122880 → 60607 rows
# Processing row group 926/978... ✅ 122880 → 48725 rows
# Processing row group 927/978... ✅ 122880 → 47790 rows
# Processing row group 928/978... ✅ 122880 → 48706 rows
# Processing row group 929/978... ✅ 122880 → 47384 rows
# Processing row group 930/978... ✅ 122880 → 55368 rows
# Processing row group 931/978... ✅ 122880 → 50253 rows
# Processing row group 932/978... ✅ 122880 → 37844 rows
# Processing row group 933/978... ✅ 122880 → 48634 rows
# Processing row group 934/978... ✅ 122880 → 52371 rows
# Processing row group 935/978... ✅ 122880 → 49813 rows
# Processing row group 936/978... ✅ 123380 → 53630 rows
# Processing row group 937/978... ✅ 122880 → 53990 rows
# Processing row group 938/978... ✅ 122880 → 44859 rows
# Processing row group 939/978... ✅ 122880 → 51533 rows
# Processing row group 940/978... ✅ 122880 → 47186 rows
# Processing row group 941/978... ✅ 122880 → 54019 rows
# Processing row group 942/978... ✅ 122880 → 53332 rows
# Processing row group 943/978... ✅ 122880 → 44452 rows
# Processing row group 944/978... ✅ 122880 → 43147 rows
# Processing row group 945/978... ✅ 122880 → 49548 rows
# Processing row group 946/978... ✅ 122880 → 51579 rows
# Processing row group 947/978... ✅ 122880 → 50700 rows
# Processing row group 948/978... ✅ 122880 → 46819 rows
# Processing row group 949/978... ✅ 122880 → 60987 rows
# Processing row group 950/978... ✅ 122880 → 49363 rows
# Processing row group 951/978... ✅ 122880 → 51034 rows
# Processing row group 952/978... ✅ 122880 → 51593 rows
# Processing row group 953/978... ✅ 123380 → 50904 rows
# Processing row group 954/978... ✅ 122880 → 51048 rows
# Processing row group 955/978... ✅ 122880 → 60600 rows
# Processing row group 956/978... ✅ 122880 → 50015 rows
# Processing row group 957/978... ✅ 122880 → 40805 rows
# Processing row group 958/978... ✅ 122880 → 47768 rows
# Processing row group 959/978... ✅ 122880 → 48669 rows
# Processing row group 960/978... ✅ 122880 → 9458 rows
# Processing row group 961/978... ✅ 122880 → 122880 rows
# Processing row group 962/978... ✅ 122880 → 22590 rows
# Processing row group 963/978... ✅ 122880 → 55785 rows
# Processing row group 964/978... ✅ 122880 → 55645 rows
# Processing row group 965/978... ✅ 122880 → 47399 rows
# Processing row group 966/978... ✅ 122880 → 49273 rows
# Processing row group 967/978... ✅ 122880 → 52477 rows
# Processing row group 968/978... ✅ 122880 → 51925 rows
# Processing row group 969/978... ✅ 122880 → 38303 rows
# Processing row group 970/978... ✅ 123380 → 52915 rows
# Processing row group 971/978... ✅ 122880 → 52245 rows
# Processing row group 972/978... ✅ 122880 → 41980 rows
# Processing row group 973/978... ✅ 122880 → 65814 rows
# Processing row group 974/978... ✅ 122880 → 45242 rows
# Processing row group 975/978... ✅ 122880 → 48010 rows
# Processing row group 976/978... ✅ 122880 → 55998 rows
# Processing row group 977/978... ✅ 122880 → 43674 rows
# Processing row group 978/978... ✅ 6250 → 2917 rows
#
# ============================================================
# ROW GROUP CLEANING SUMMARY:
# ============================================================
# Row groups: 978 processed
# Rows:       120,088,510 → 52,696,134 (43.9% kept)
# File size:  1.49 GB → 0.63 GB
# Reduction:  0.86 GB (57.4%)
# Columns:    4 → 3
# ============================================================
# {'original_rows': 120088510,
#  'final_rows': 52696134,
#  'original_size': 1599106665,
#  'final_size': 680675386,
#  'row_groups_processed': 978}

# %% [markdown]
# ## Follows

# %%
i_file = "/home/ale/Documents/uni/mp/data/raw/follows.parquet"
o_file = "/home/ale/Documents/uni/mp/data/cleaned/follows.parquet"
# It's a large database so parallel processing may help.
# clean_parquet_parallel(i_file, o_file, CLEANING_RULES, table_type="follows")
clean_parquet_by_row_groups(i_file, o_file, CLEANING_RULES, table_type="follows")
# Out:
# Cleaning by row groups...
# Input file: 23.17 GB
# Processing 3 columns: ['created_at', 'subject_id', 'did_id']
# Processing 17551 row groups...
# Processing row group 1/17551... Applied rules: ['removed_null_did_id', 'removed_null_created_at', 'max_date_created_at', 'min_date_created_at', 'removed_null_subject_id']
# ✅ 122880 → 36307 rows
# Processing row group 2/17551... ✅ 122880 → 35983 rows
# Processing row group 3/17551... ✅ 122880 → 51292 rows
# Processing row group 4/17551... ✅ 122880 → 39006 rows
# Processing row group 5/17551... ✅ 122880 → 54021 rows
# Processing row group 6/17551... ✅ 122880 → 4283 rows
# Processing row group 7/17551... ✅ 122880 → 35367 rows
# Processing row group 8/17551... ✅ 122880 → 42626 rows
# Processing row group 9/17551... ✅ 122880 → 30177 rows
# Processing row group 10/17551... ✅ 122880 → 39326 rows
# Processing row group 11/17551... ✅ 122880 → 61343 rows
# Processing row group 12/17551... ✅ 122880 → 25545 rows
# Processing row group 13/17551... ✅ 122880 → 42342 rows
# Processing row group 14/17551... ✅ 122880 → 35908 rows
# Processing row group 15/17551... ✅ 122880 → 28323 rows
# Processing row group 16/17551... ✅ 122880 → 22699 rows
# Processing row group 17/17551... ✅ 122880 → 49567 rows
# Processing row group 18/17551... ✅ 122880 → 45382 rows
# Processing row group 19/17551... ✅ 122880 → 40519 rows
# Processing row group 20/17551... ✅ 122880 → 34996 rows
# Processing row group 21/17551... ✅ 122880 → 34393 rows
# Processing row group 22/17551... ✅ 122880 → 28923 rows
# Processing row group 23/17551... ✅ 122880 → 34794 rows
# Processing row group 24/17551... ✅ 122880 → 23052 rows
# Processing row group 25/17551... ✅ 122880 → 40909 rows
# Processing row group 26/17551... ✅ 122880 → 34991 rows
# Processing row group 27/17551... ✅ 122880 → 42031 rows
# Processing row group 28/17551... ✅ 122880 → 37246 rows
# Processing row group 29/17551... ✅ 122880 → 35099 rows
# Processing row group 30/17551... ✅ 122880 → 38718 rows
# Processing row group 31/17551... ✅ 122880 → 46073 rows
# Processing row group 32/17551... ✅ 122880 → 35751 rows
# Processing row group 33/17551... ✅ 122880 → 29724 rows
# Processing row group 34/17551... ✅ 122880 → 35583 rows
# Processing row group 35/17551... ✅ 122880 → 36435 rows
# Processing row group 36/17551... ✅ 122880 → 37238 rows
# Processing row group 37/17551... ✅ 122880 → 48828 rows
# Processing row group 38/17551... ✅ 122880 → 46064 rows
# Processing row group 39/17551... ✅ 122880 → 55457 rows
# Processing row group 40/17551... ✅ 122880 → 32534 rows
# Processing row group 41/17551... ✅ 122880 → 37828 rows
# Processing row group 42/17551... ✅ 122880 → 34686 rows
# Processing row group 43/17551... ✅ 122880 → 45729 rows
# Processing row group 44/17551... ✅ 122880 → 67769 rows
# Processing row group 45/17551... ✅ 122880 → 58801 rows
# Processing row group 46/17551... ✅ 122880 → 40856 rows
# Processing row group 47/17551... ✅ 122880 → 32126 rows
# Processing row group 48/17551... ✅ 122880 → 36736 rows
# Processing row group 49/17551... ✅ 122880 → 36982 rows
# Processing row group 50/17551... ✅ 123505 → 42902 rows
# Processing row group 51/17551... ✅ 122880 → 26581 rows
# Processing row group 52/17551... ✅ 122880 → 40834 rows
# Processing row group 53/17551... ✅ 122880 → 49807 rows
# Processing row group 54/17551... ✅ 122880 → 47441 rows
# Processing row group 55/17551... ✅ 122880 → 34410 rows
# Processing row group 56/17551... ✅ 122880 → 30909 rows
# Processing row group 57/17551... ✅ 122880 → 44616 rows
# Processing row group 58/17551... ✅ 122880 → 35631 rows
# Processing row group 59/17551... ✅ 122880 → 38833 rows
# Processing row group 60/17551... ✅ 122880 → 43748 rows
# Processing row group 61/17551... ✅ 122880 → 55211 rows
# Processing row group 62/17551... ✅ 122880 → 53810 rows
# Processing row group 63/17551... ✅ 122880 → 55960 rows
# Processing row group 64/17551... ✅ 122880 → 48922 rows
# Processing row group 65/17551... ✅ 122880 → 34589 rows
# Processing row group 66/17551... ✅ 122880 → 49177 rows
# Processing row group 67/17551... ✅ 122880 → 32846 rows
# Processing row group 68/17551... ✅ 122880 → 41754 rows
# Processing row group 69/17551... ✅ 122880 → 61660 rows
# Processing row group 70/17551... ✅ 122880 → 53554 rows
# Processing row group 71/17551... ✅ 122880 → 38314 rows
# Processing row group 72/17551... ✅ 122880 → 21321 rows
# Processing row group 73/17551... ✅ 122880 → 49143 rows
# Processing row group 74/17551... ✅ 122880 → 71971 rows
# Processing row group 75/17551... ✅ 122880 → 48083 rows
# Processing row group 76/17551... ✅ 122880 → 43869 rows
# Processing row group 77/17551... ✅ 122880 → 50512 rows
# Processing row group 78/17551... ✅ 122880 → 62198 rows
# Processing row group 79/17551... ✅ 122880 → 37122 rows
# Processing row group 80/17551... ✅ 122880 → 33729 rows
# Processing row group 81/17551... ✅ 122880 → 40319 rows
# Processing row group 82/17551... ✅ 122880 → 59477 rows
# Processing row group 83/17551... ✅ 122880 → 46275 rows
# Processing row group 84/17551... ✅ 122880 → 50307 rows
# Processing row group 85/17551... ✅ 122880 → 43770 rows
# Processing row group 86/17551... ✅ 122880 → 38649 rows
# Processing row group 87/17551... ✅ 122880 → 83027 rows
# Processing row group 88/17551... ✅ 122880 → 45163 rows
# Processing row group 89/17551... ✅ 122880 → 46619 rows
# Processing row group 90/17551... ✅ 122880 → 39065 rows
# Processing row group 91/17551... ✅ 122880 → 37054 rows
# Processing row group 92/17551... ✅ 122880 → 39193 rows
# Processing row group 93/17551... ✅ 122880 → 25615 rows
# Processing row group 94/17551... ✅ 122880 → 38377 rows
# Processing row group 95/17551... ✅ 122880 → 28960 rows
# Processing row group 96/17551... ✅ 122880 → 47643 rows
# Processing row group 97/17551... ✅ 122880 → 41810 rows
# Processing row group 98/17551... ✅ 122880 → 46506 rows
# Processing row group 99/17551... ✅ 122880 → 46047 rows
# Processing row group 100/17551... ✅ 123505 → 39578 rows
# Processing row group 101/17551... ✅ 122880 → 35988 rows
# Processing row group 102/17551... ✅ 122880 → 44368 rows
# Processing row group 103/17551... ✅ 122880 → 46575 rows
# Processing row group 104/17551... ✅ 122880 → 35165 rows
# Processing row group 105/17551... ✅ 122880 → 50259 rows
# Processing row group 106/17551... ✅ 122880 → 53223 rows
# Processing row group 107/17551... ✅ 122880 → 42445 rows
# Processing row group 108/17551... ✅ 122880 → 58536 rows
# Processing row group 109/17551... ✅ 122880 → 50362 rows
# Processing row group 110/17551... ✅ 122880 → 31469 rows
# Processing row group 111/17551... ✅ 122880 → 51165 rows
# Processing row group 112/17551... ✅ 122880 → 39937 rows
# Processing row group 113/17551... ✅ 122880 → 56835 rows
# Processing row group 114/17551... ✅ 122880 → 52763 rows
# Processing row group 115/17551... ✅ 122880 → 29489 rows
# Processing row group 116/17551... ✅ 122880 → 45294 rows
# Processing row group 117/17551... ✅ 122880 → 37531 rows
# Processing row group 118/17551... ✅ 122880 → 56203 rows
# Processing row group 119/17551... ✅ 122880 → 25115 rows
# Processing row group 120/17551... ✅ 122880 → 54950 rows
# Processing row group 121/17551... ✅ 122880 → 44012 rows
# Processing row group 122/17551... ✅ 122880 → 34885 rows
# Processing row group 123/17551... ✅ 122880 → 41028 rows
# Processing row group 124/17551... ✅ 122880 → 51610 rows
# Processing row group 125/17551... ✅ 122880 → 56840 rows
# Processing row group 126/17551... ✅ 122880 → 41370 rows
# Processing row group 127/17551... ✅ 122880 → 35589 rows
# Processing row group 128/17551... ✅ 122880 → 47129 rows
# Processing row group 129/17551... ✅ 122880 → 35196 rows
# Processing row group 130/17551... ✅ 122880 → 37006 rows
# Processing row group 131/17551... ✅ 122880 → 44524 rows
# Processing row group 132/17551... ✅ 122880 → 39866 rows
# Processing row group 133/17551... ✅ 122880 → 29788 rows
# Processing row group 134/17551... ✅ 122880 → 58353 rows
# Processing row group 135/17551... ✅ 122880 → 56871 rows
# Processing row group 136/17551... ✅ 122880 → 72207 rows
# Processing row group 137/17551... ✅ 122880 → 65564 rows
# Processing row group 138/17551... ✅ 122880 → 12222 rows
# Processing row group 139/17551... ✅ 122880 → 51560 rows
# Processing row group 140/17551... ✅ 122880 → 35057 rows
# Processing row group 141/17551... ✅ 122880 → 55264 rows
# Processing row group 142/17551... ✅ 122880 → 55495 rows
# Processing row group 143/17551... ✅ 122880 → 49793 rows
# Processing row group 144/17551... ✅ 122880 → 24186 rows
# Processing row group 145/17551... ✅ 122880 → 61277 rows
# Processing row group 146/17551... ✅ 122880 → 51722 rows
# Processing row group 147/17551... ✅ 122880 → 32380 rows
# Processing row group 148/17551... ✅ 122880 → 27733 rows
# Processing row group 149/17551... ✅ 122880 → 58599 rows
# Processing row group 150/17551... ✅ 123505 → 50862 rows
# Processing row group 151/17551... ✅ 122880 → 38892 rows
# Processing row group 152/17551... ✅ 122880 → 36826 rows
# Processing row group 153/17551... ✅ 122880 → 41419 rows
# Processing row group 154/17551... ✅ 122880 → 39300 rows
# Processing row group 155/17551... ✅ 122880 → 38165 rows
# Processing row group 156/17551... ✅ 122880 → 51405 rows
# Processing row group 157/17551... ✅ 122880 → 36235 rows
# Processing row group 158/17551... ✅ 122880 → 35379 rows
# Processing row group 159/17551... ✅ 122880 → 54078 rows
# Processing row group 160/17551... ✅ 122880 → 44624 rows
# Processing row group 161/17551... ✅ 122880 → 58998 rows
# Processing row group 162/17551... ✅ 122880 → 50688 rows
# Processing row group 163/17551... ✅ 122880 → 43778 rows
# Processing row group 164/17551... ✅ 122880 → 30115 rows
# Processing row group 165/17551... ✅ 122880 → 88412 rows
# Processing row group 166/17551... ✅ 122880 → 41256 rows
# Processing row group 167/17551... ✅ 122880 → 47526 rows
# Processing row group 168/17551... ✅ 122880 → 47163 rows
# Processing row group 169/17551... ✅ 122880 → 38531 rows
# Processing row group 170/17551... ✅ 122880 → 34954 rows
# Processing row group 171/17551... ✅ 122880 → 37008 rows
# Processing row group 172/17551... ✅ 122880 → 32387 rows
# Processing row group 173/17551... ✅ 122880 → 43286 rows
# Processing row group 174/17551... ✅ 122880 → 41368 rows
# Processing row group 175/17551... ✅ 122880 → 40942 rows
# Processing row group 176/17551... ✅ 122880 → 32693 rows
# Processing row group 177/17551... ✅ 122880 → 36736 rows
# Processing row group 178/17551... ✅ 122880 → 52370 rows
# Processing row group 179/17551... ✅ 122880 → 66282 rows
# Processing row group 180/17551... ✅ 122880 → 40880 rows
# Processing row group 181/17551... ✅ 122880 → 34040 rows
# Processing row group 182/17551... ✅ 122880 → 45731 rows
# Processing row group 183/17551... ✅ 122880 → 39503 rows
# Processing row group 184/17551... ✅ 122880 → 45997 rows
# Processing row group 185/17551... ✅ 122880 → 38991 rows
# Processing row group 186/17551... ✅ 122880 → 44091 rows
# Processing row group 187/17551... ✅ 122880 → 41843 rows
# Processing row group 188/17551... ✅ 122880 → 36092 rows
# Processing row group 189/17551... ✅ 122880 → 46282 rows
# Processing row group 190/17551... ✅ 122880 → 32881 rows
# Processing row group 191/17551... ✅ 122880 → 42458 rows
# Processing row group 192/17551... ✅ 122880 → 45219 rows
# Processing row group 193/17551... ✅ 122880 → 27941 rows
# Processing row group 194/17551... ✅ 122880 → 39540 rows
# Processing row group 195/17551... ✅ 122880 → 62046 rows
# Processing row group 196/17551... ✅ 122880 → 35859 rows
# Processing row group 197/17551... ✅ 122880 → 40644 rows
# Processing row group 198/17551... ✅ 122880 → 48633 rows
# Processing row group 199/17551... ✅ 122880 → 48414 rows
# Processing row group 200/17551... ✅ 123505 → 34541 rows
# Processing row group 201/17551... ✅ 122880 → 43443 rows
# Processing row group 202/17551... ✅ 122880 → 26197 rows
# Processing row group 203/17551... ✅ 122880 → 7812 rows
# Processing row group 204/17551... ✅ 122880 → 72859 rows
# Processing row group 205/17551... ✅ 122880 → 54566 rows
# Processing row group 206/17551... ✅ 122880 → 52007 rows
# Processing row group 207/17551... ✅ 122880 → 39549 rows
# Processing row group 208/17551... ✅ 122880 → 36691 rows
# Processing row group 209/17551... ✅ 122880 → 41909 rows
# Processing row group 210/17551... ✅ 122880 → 35487 rows
# Processing row group 211/17551... ✅ 122880 → 35082 rows
# Processing row group 212/17551... ✅ 122880 → 49161 rows
# Processing row group 213/17551... ✅ 122880 → 58296 rows
# Processing row group 214/17551... ✅ 122880 → 46407 rows
# Processing row group 215/17551... ✅ 122880 → 42761 rows
# Processing row group 216/17551... ✅ 122880 → 27571 rows
# Processing row group 217/17551... ✅ 122880 → 59775 rows
# Processing row group 218/17551... ✅ 122880 → 45118 rows
# Processing row group 219/17551... ✅ 122880 → 31033 rows
# Processing row group 220/17551... ✅ 122880 → 55840 rows
# Processing row group 221/17551... ✅ 122880 → 65535 rows
# Processing row group 222/17551... ✅ 122880 → 38825 rows
# Processing row group 223/17551... ✅ 122880 → 35762 rows
# Processing row group 224/17551... ✅ 122880 → 39225 rows
# Processing row group 225/17551... ✅ 122880 → 37357 rows
# Processing row group 226/17551... ✅ 122880 → 42362 rows
# Processing row group 227/17551... ✅ 122880 → 43192 rows
# Processing row group 228/17551... ✅ 122880 → 60379 rows
# Processing row group 229/17551... ✅ 122880 → 58386 rows
# Processing row group 230/17551... ✅ 122880 → 37612 rows
# Processing row group 231/17551... ✅ 122880 → 46161 rows
# Processing row group 232/17551... ✅ 122880 → 47753 rows
# Processing row group 233/17551... ✅ 122880 → 38134 rows
# Processing row group 234/17551... ✅ 122880 → 38888 rows
# Processing row group 235/17551... ✅ 122880 → 34857 rows
# Processing row group 236/17551... ✅ 122880 → 35996 rows
# Processing row group 237/17551... ✅ 122880 → 43180 rows
# Processing row group 238/17551... ✅ 122880 → 39684 rows
# Processing row group 239/17551... ✅ 122880 → 37625 rows
# Processing row group 240/17551... ✅ 122880 → 45063 rows
# Processing row group 241/17551... ✅ 122880 → 66724 rows
# Processing row group 242/17551... ✅ 122880 → 52529 rows
# Processing row group 243/17551... ✅ 122880 → 45290 rows
# Processing row group 244/17551... ✅ 122880 → 38206 rows
# Processing row group 245/17551... ✅ 122880 → 34022 rows
# Processing row group 246/17551... ✅ 122880 → 32055 rows
# Processing row group 247/17551... ✅ 122880 → 45882 rows
# Processing row group 248/17551... ✅ 122880 → 57280 rows
# Processing row group 249/17551... ✅ 123505 → 69884 rows
# Processing row group 250/17551... ✅ 122880 → 51239 rows
# Processing row group 251/17551... ✅ 122880 → 54577 rows
# Processing row group 252/17551... ✅ 122880 → 67873 rows
# Processing row group 253/17551... ✅ 122880 → 31610 rows
# Processing row group 254/17551... ✅ 122880 → 52703 rows
# Processing row group 255/17551... ✅ 122880 → 32497 rows
# Processing row group 256/17551... ✅ 122880 → 37613 rows
# Processing row group 257/17551... ✅ 122880 → 37668 rows
# Processing row group 258/17551... ✅ 122880 → 37369 rows
# Processing row group 259/17551... ✅ 122880 → 34811 rows
# Processing row group 260/17551... ✅ 122880 → 51594 rows
# Processing row group 261/17551... ✅ 122880 → 41494 rows
# Processing row group 262/17551... ✅ 122880 → 40568 rows
# Processing row group 263/17551... ✅ 122880 → 55142 rows
# Processing row group 264/17551... ✅ 122880 → 45552 rows
# Processing row group 265/17551... ✅ 122880 → 35924 rows
# Processing row group 266/17551... ✅ 122880 → 32559 rows
# Processing row group 267/17551... ✅ 122880 → 32956 rows
# Processing row group 268/17551... ✅ 122880 → 38705 rows
# Processing row group 269/17551... ✅ 122880 → 43104 rows
# Processing row group 270/17551... ✅ 122880 → 34893 rows
# Processing row group 271/17551... ✅ 122880 → 37877 rows
# Processing row group 272/17551... ✅ 122880 → 35272 rows
# Processing row group 273/17551... ✅ 122880 → 47752 rows
# Processing row group 274/17551... ✅ 122880 → 44154 rows
# Processing row group 275/17551... ✅ 122880 → 43048 rows
# Processing row group 276/17551... ✅ 122880 → 68719 rows
# Processing row group 277/17551... ✅ 122880 → 48765 rows
# Processing row group 278/17551... ✅ 122880 → 36461 rows
# Processing row group 279/17551... ✅ 122880 → 41629 rows
# Processing row group 280/17551... ✅ 122880 → 46619 rows
# Processing row group 281/17551... ✅ 122880 → 45320 rows
# Processing row group 282/17551... ✅ 122880 → 60405 rows
# Processing row group 283/17551... ✅ 122880 → 29571 rows
# Processing row group 284/17551... ✅ 122880 → 36846 rows
# Processing row group 285/17551... ✅ 122880 → 31928 rows
# Processing row group 286/17551... ✅ 122880 → 53225 rows
# Processing row group 287/17551... ✅ 122880 → 35261 rows
# Processing row group 288/17551... ✅ 122880 → 38193 rows
# Processing row group 289/17551... ✅ 122880 → 56794 rows
# Processing row group 290/17551... ✅ 122880 → 54690 rows
# Processing row group 291/17551... ✅ 122880 → 35589 rows
# Processing row group 292/17551... ✅ 122880 → 118157 rows
# Processing row group 293/17551... ✅ 122880 → 122880 rows
# Processing row group 294/17551... ✅ 122880 → 122880 rows
# Processing row group 295/17551... ✅ 122880 → 81768 rows
# Processing row group 296/17551... ✅ 122880 → 59002 rows
# Processing row group 297/17551... ✅ 122880 → 43763 rows
# Processing row group 298/17551... ✅ 122880 → 54866 rows
# Processing row group 299/17551... ✅ 123505 → 33589 rows
# Processing row group 300/17551... ✅ 122880 → 54295 rows
# Processing row group 301/17551... ✅ 122880 → 31456 rows
# Processing row group 302/17551... ✅ 122880 → 32663 rows
# Processing row group 303/17551... ✅ 122880 → 46241 rows
# Processing row group 304/17551... ✅ 122880 → 42733 rows
# Processing row group 305/17551... ✅ 122880 → 38095 rows
# Processing row group 306/17551... ✅ 122880 → 44483 rows
# Processing row group 307/17551... ✅ 122880 → 30047 rows
# Processing row group 308/17551... ✅ 122880 → 46033 rows
# Processing row group 309/17551... ✅ 122880 → 57485 rows
# Processing row group 310/17551... ✅ 122880 → 55445 rows
# Processing row group 311/17551... ✅ 122880 → 56099 rows
# Processing row group 312/17551... ✅ 122880 → 51016 rows
# Processing row group 313/17551... ✅ 122880 → 39294 rows
# Processing row group 314/17551... ✅ 122880 → 39466 rows
# Processing row group 315/17551... ✅ 122880 → 51929 rows
# Processing row group 316/17551... ✅ 122880 → 31867 rows
# Processing row group 317/17551... ✅ 122880 → 37574 rows
# Processing row group 318/17551... ✅ 122880 → 45186 rows
# Processing row group 319/17551... ✅ 122880 → 39824 rows
# Processing row group 320/17551... ✅ 122880 → 63244 rows
# Processing row group 321/17551... ✅ 122880 → 37601 rows
# Processing row group 322/17551... ✅ 122880 → 31336 rows
# Processing row group 323/17551... ✅ 122880 → 44099 rows
# Processing row group 324/17551... ✅ 122880 → 35880 rows
# Processing row group 325/17551... ✅ 122880 → 44596 rows
# Processing row group 326/17551... ✅ 122880 → 56909 rows
# Processing row group 327/17551... ✅ 122880 → 103402 rows
# Processing row group 328/17551... ✅ 122880 → 39482 rows
# Processing row group 329/17551... ✅ 122880 → 32970 rows
# Processing row group 330/17551... ✅ 122880 → 33506 rows
# Processing row group 331/17551... ✅ 122880 → 40491 rows
# Processing row group 332/17551... ✅ 122880 → 38704 rows
# Processing row group 333/17551... ✅ 122880 → 36276 rows
# Processing row group 334/17551... ✅ 122880 → 42086 rows
# Processing row group 335/17551... ✅ 122880 → 42533 rows
# Processing row group 336/17551... ✅ 122880 → 33622 rows
# Processing row group 337/17551... ✅ 122880 → 59165 rows
# Processing row group 338/17551... ✅ 122880 → 35365 rows
# Processing row group 339/17551... ✅ 122880 → 42953 rows
# Processing row group 340/17551... ✅ 122880 → 57270 rows
# Processing row group 341/17551... ✅ 122880 → 39382 rows
# Processing row group 342/17551... ✅ 122880 → 41067 rows
# Processing row group 343/17551... ✅ 122880 → 51649 rows
# Processing row group 344/17551... ✅ 122880 → 24450 rows
# Processing row group 345/17551... ✅ 122880 → 40414 rows
# Processing row group 346/17551... ✅ 122880 → 45674 rows
# Processing row group 347/17551... ✅ 122880 → 45725 rows
# Processing row group 348/17551... ✅ 122880 → 39905 rows
# Processing row group 349/17551... ✅ 123505 → 49688 rows
# Processing row group 350/17551... ✅ 122880 → 31161 rows
# Processing row group 351/17551... ✅ 122880 → 38752 rows
# Processing row group 352/17551... ✅ 122880 → 45535 rows
# Processing row group 353/17551... ✅ 122880 → 36964 rows
# Processing row group 354/17551... ✅ 122880 → 34790 rows
# Processing row group 355/17551... ✅ 122880 → 40049 rows
# Processing row group 356/17551... ✅ 122880 → 44722 rows
# Processing row group 357/17551... ✅ 122880 → 42332 rows
# Processing row group 358/17551... ✅ 122880 → 34009 rows
# Processing row group 359/17551... ✅ 122880 → 42616 rows
# Processing row group 360/17551... ✅ 122880 → 48473 rows
# Processing row group 361/17551... ✅ 122880 → 48459 rows
# Processing row group 362/17551... ✅ 122880 → 35867 rows
# Processing row group 363/17551... ✅ 122880 → 41605 rows
# Processing row group 364/17551... ✅ 122880 → 37904 rows
# Processing row group 365/17551... ✅ 122880 → 38592 rows
# Processing row group 366/17551... ✅ 122880 → 44940 rows
# Processing row group 367/17551... ✅ 122880 → 62172 rows
# Processing row group 368/17551... ✅ 122880 → 49378 rows
# Processing row group 369/17551... ✅ 122880 → 58675 rows
# Processing row group 370/17551... ✅ 122880 → 38235 rows
# Processing row group 371/17551... ✅ 122880 → 46213 rows
# Processing row group 372/17551... ✅ 122880 → 41448 rows
# Processing row group 373/17551... ✅ 122880 → 51348 rows
# Processing row group 374/17551... ✅ 122880 → 38317 rows
# Processing row group 375/17551... ✅ 122880 → 38485 rows
# Processing row group 376/17551... ✅ 122880 → 38501 rows
# Processing row group 377/17551... ✅ 122880 → 36286 rows
# Processing row group 378/17551... ✅ 122880 → 48070 rows
# Processing row group 379/17551... ✅ 122880 → 42024 rows
# Processing row group 380/17551... ✅ 122880 → 37856 rows
# Processing row group 381/17551... ✅ 122880 → 44094 rows
# Processing row group 382/17551... ✅ 122880 → 54167 rows
# Processing row group 383/17551... ✅ 122880 → 33401 rows
# Processing row group 384/17551... ✅ 122880 → 54535 rows
# Processing row group 385/17551... ✅ 122880 → 51508 rows
# Processing row group 386/17551... ✅ 122880 → 41952 rows
# Processing row group 387/17551... ✅ 122880 → 40064 rows
# Processing row group 388/17551... ✅ 122880 → 41430 rows
# Processing row group 389/17551... ✅ 122880 → 60008 rows
# Processing row group 390/17551... ✅ 122880 → 48728 rows
# Processing row group 391/17551... ✅ 122880 → 41852 rows
# Processing row group 392/17551... ✅ 122880 → 42785 rows
# Processing row group 393/17551... ✅ 122880 → 37024 rows
# Processing row group 394/17551... ✅ 122880 → 44216 rows
# Processing row group 395/17551... ✅ 122880 → 39491 rows
# Processing row group 396/17551... ✅ 122880 → 40661 rows
# Processing row group 397/17551... ✅ 122880 → 31104 rows
# Processing row group 398/17551... ✅ 122880 → 50325 rows
# Processing row group 399/17551... ✅ 123505 → 35558 rows
# Processing row group 400/17551... ✅ 122880 → 43441 rows
# Processing row group 401/17551... ✅ 122880 → 45722 rows
# Processing row group 402/17551... ✅ 122880 → 48023 rows
# Processing row group 403/17551... ✅ 122880 → 48125 rows
# Processing row group 404/17551... ✅ 122880 → 22027 rows
# Processing row group 405/17551... ✅ 122880 → 76222 rows
# Processing row group 406/17551... ✅ 122880 → 58339 rows
# Processing row group 407/17551... ✅ 122880 → 52632 rows
# Processing row group 408/17551... ✅ 122880 → 35836 rows
# Processing row group 409/17551... ✅ 122880 → 42812 rows
# Processing row group 410/17551... ✅ 122880 → 66452 rows
# Processing row group 411/17551... ✅ 122880 → 40601 rows
# Processing row group 412/17551... ✅ 122880 → 42194 rows
# Processing row group 413/17551... ✅ 122880 → 36442 rows
# Processing row group 414/17551... ✅ 122880 → 33580 rows
# Processing row group 415/17551... ✅ 122880 → 35527 rows
# Processing row group 416/17551... ✅ 122880 → 45644 rows
# Processing row group 417/17551... ✅ 122880 → 36597 rows
# Processing row group 418/17551... ✅ 122880 → 39528 rows
# Processing row group 419/17551... ✅ 122880 → 34968 rows
# Processing row group 420/17551... ✅ 122880 → 48271 rows
# Processing row group 421/17551... ✅ 122880 → 27235 rows
# Processing row group 422/17551... ✅ 122880 → 32806 rows
# Processing row group 423/17551... ✅ 122880 → 38440 rows
# Processing row group 424/17551... ✅ 122880 → 56195 rows
# Processing row group 425/17551... ✅ 122880 → 41193 rows
# Processing row group 426/17551... ✅ 122880 → 30794 rows
# Processing row group 427/17551... ✅ 122880 → 49350 rows
# Processing row group 428/17551... ✅ 122880 → 43964 rows
# Processing row group 429/17551... ✅ 122880 → 28902 rows
# Processing row group 430/17551... ✅ 122880 → 44822 rows
# Processing row group 431/17551... ✅ 122880 → 34528 rows
# Processing row group 432/17551... ✅ 122880 → 45946 rows
# Processing row group 433/17551... ✅ 122880 → 36860 rows
# Processing row group 434/17551... ✅ 122880 → 70389 rows
# Processing row group 435/17551... ✅ 122880 → 49090 rows
# Processing row group 436/17551... ✅ 122880 → 39056 rows
# Processing row group 437/17551... ✅ 122880 → 31127 rows
# Processing row group 438/17551... ✅ 122880 → 61985 rows
# Processing row group 439/17551... ✅ 122880 → 26554 rows
# Processing row group 440/17551... ✅ 122880 → 38585 rows
# Processing row group 441/17551... ✅ 122880 → 27894 rows
# Processing row group 442/17551... ✅ 122880 → 40472 rows
# Processing row group 443/17551... ✅ 122880 → 49051 rows
# Processing row group 444/17551... ✅ 122880 → 46594 rows
# Processing row group 445/17551... ✅ 122880 → 43882 rows
# Processing row group 446/17551... ✅ 122880 → 34048 rows
# Processing row group 447/17551... ✅ 122880 → 28907 rows
# Processing row group 448/17551... ✅ 122880 → 52049 rows
# Processing row group 449/17551... ✅ 123505 → 34734 rows
# Processing row group 450/17551... ✅ 122880 → 44598 rows
# Processing row group 451/17551... ✅ 122880 → 28668 rows
# Processing row group 452/17551... ✅ 122880 → 36624 rows
# Processing row group 453/17551... ✅ 122880 → 40727 rows
# Processing row group 454/17551... ✅ 122880 → 43973 rows
# Processing row group 455/17551... ✅ 122880 → 48744 rows
# Processing row group 456/17551... ✅ 122880 → 27198 rows
# Processing row group 457/17551... ✅ 122880 → 41593 rows
# Processing row group 458/17551... ✅ 122880 → 41814 rows
# Processing row group 459/17551... ✅ 122880 → 34389 rows
# Processing row group 460/17551... ✅ 122880 → 31695 rows
# Processing row group 461/17551... ✅ 122880 → 24555 rows
# Processing row group 462/17551... ✅ 122880 → 55578 rows
# Processing row group 463/17551... ✅ 122880 → 43634 rows
# Processing row group 464/17551... ✅ 122880 → 32869 rows
# Processing row group 465/17551... ✅ 122880 → 42772 rows
# Processing row group 466/17551... ✅ 122880 → 57630 rows
# Processing row group 467/17551... ✅ 122880 → 40644 rows
# Processing row group 468/17551... ✅ 122880 → 45772 rows
# Processing row group 469/17551... ✅ 122880 → 46158 rows
# Processing row group 470/17551... ✅ 122880 → 49153 rows
# Processing row group 471/17551... ✅ 122880 → 50565 rows
# Processing row group 472/17551... ✅ 122880 → 50836 rows
# Processing row group 473/17551... ✅ 122880 → 59413 rows
# Processing row group 474/17551... ✅ 122880 → 21685 rows
# Processing row group 475/17551... ✅ 122880 → 49127 rows
# Processing row group 476/17551... ✅ 122880 → 41694 rows
# Processing row group 477/17551... ✅ 122880 → 27729 rows
# Processing row group 478/17551... ✅ 122880 → 32128 rows
# Processing row group 479/17551... ✅ 122880 → 33446 rows
# Processing row group 480/17551... ✅ 122880 → 33826 rows
# Processing row group 481/17551... ✅ 122880 → 59150 rows
# Processing row group 482/17551... ✅ 122880 → 52938 rows
# Processing row group 483/17551... ✅ 122880 → 104100 rows
# Processing row group 484/17551... ✅ 122880 → 89778 rows
# Processing row group 485/17551... ✅ 122880 → 45250 rows
# Processing row group 486/17551... ✅ 122880 → 39756 rows
# Processing row group 487/17551... ✅ 122880 → 53294 rows
# Processing row group 488/17551... ✅ 122880 → 42412 rows
# Processing row group 489/17551... ✅ 122880 → 40294 rows
# Processing row group 490/17551... ✅ 122880 → 48286 rows
# Processing row group 491/17551... ✅ 122880 → 32336 rows
# Processing row group 492/17551... ✅ 122880 → 40275 rows
# Processing row group 493/17551... ✅ 122880 → 48268 rows
# Processing row group 494/17551... ✅ 122880 → 27590 rows
# Processing row group 495/17551... ✅ 122880 → 54039 rows
# Processing row group 496/17551... ✅ 122880 → 55044 rows
# Processing row group 497/17551... ✅ 122880 → 53763 rows
# Processing row group 498/17551... ✅ 123505 → 35944 rows
# Processing row group 499/17551... ✅ 122880 → 38301 rows
# Processing row group 500/17551... ✅ 122880 → 40414 rows
# Processing row group 501/17551... ✅ 122880 → 30028 rows
# Processing row group 502/17551... ✅ 122880 → 48767 rows
# Processing row group 503/17551... ✅ 122880 → 46560 rows
# Processing row group 504/17551... ✅ 122880 → 49771 rows
# Processing row group 505/17551... ✅ 122880 → 58534 rows
# Processing row group 506/17551... ✅ 122880 → 38474 rows
# Processing row group 507/17551... ✅ 122880 → 49724 rows
# Processing row group 508/17551... ✅ 122880 → 49622 rows
# Processing row group 509/17551... ✅ 122880 → 37622 rows
# Processing row group 510/17551... ✅ 122880 → 40711 rows
# Processing row group 511/17551... ✅ 122880 → 59869 rows
# Processing row group 512/17551... ✅ 122880 → 37759 rows
# Processing row group 513/17551... ✅ 122880 → 34690 rows
# Processing row group 514/17551... ✅ 122880 → 46485 rows
# Processing row group 515/17551... ✅ 122880 → 39934 rows
# Processing row group 516/17551... ✅ 122880 → 29026 rows
# Processing row group 517/17551... ✅ 122880 → 53811 rows
# Processing row group 518/17551... ✅ 122880 → 48864 rows
# Processing row group 519/17551... ✅ 122880 → 35668 rows
# Processing row group 520/17551... ✅ 122880 → 54764 rows
# Processing row group 521/17551... ✅ 122880 → 56327 rows
# Processing row group 522/17551... ✅ 122880 → 42464 rows
# Processing row group 523/17551... ✅ 122880 → 39228 rows
# Processing row group 524/17551... ✅ 122880 → 43103 rows
# Processing row group 525/17551... ✅ 122880 → 54968 rows
# Processing row group 526/17551... ✅ 122880 → 47079 rows
# Processing row group 527/17551... ✅ 122880 → 46494 rows
# Processing row group 528/17551... ✅ 122880 → 43537 rows
# Processing row group 529/17551... ✅ 122880 → 39575 rows
# Processing row group 530/17551... ✅ 122880 → 30994 rows
# Processing row group 531/17551... ✅ 122880 → 42455 rows
# Processing row group 532/17551... ✅ 122880 → 46765 rows
# Processing row group 533/17551... ✅ 122880 → 53879 rows
# Processing row group 534/17551... ✅ 122880 → 47358 rows
# Processing row group 535/17551... ✅ 122880 → 35292 rows
# Processing row group 536/17551... ✅ 122880 → 38631 rows
# Processing row group 537/17551... ✅ 122880 → 35578 rows
# Processing row group 538/17551... ✅ 122880 → 60124 rows
# Processing row group 539/17551... ✅ 122880 → 42464 rows
# Processing row group 540/17551... ✅ 122880 → 30360 rows
# Processing row group 541/17551... ✅ 122880 → 43364 rows
# Processing row group 542/17551... ✅ 122880 → 47320 rows
# Processing row group 543/17551... ✅ 122880 → 37582 rows
# Processing row group 544/17551... ✅ 122880 → 40759 rows
# Processing row group 545/17551... ✅ 122880 → 42237 rows
# Processing row group 546/17551... ✅ 122880 → 48629 rows
# Processing row group 547/17551... ✅ 122880 → 45932 rows
# Processing row group 548/17551... ✅ 123505 → 49430 rows
# Processing row group 549/17551... ✅ 122880 → 34438 rows
# Processing row group 550/17551... ✅ 122880 → 32704 rows
# Processing row group 551/17551... ✅ 122880 → 39533 rows
# Processing row group 552/17551... ✅ 122880 → 32296 rows
# Processing row group 553/17551... ✅ 122880 → 32227 rows
# Processing row group 554/17551... ✅ 122880 → 52024 rows
# Processing row group 555/17551... ✅ 122880 → 62290 rows
# Processing row group 556/17551... ✅ 122880 → 94959 rows
# Processing row group 557/17551... ✅ 122880 → 40242 rows
# Processing row group 558/17551... ✅ 122880 → 28839 rows
# Processing row group 559/17551... ✅ 122880 → 60798 rows
# Processing row group 560/17551... ✅ 122880 → 26199 rows
# Processing row group 561/17551... ✅ 122880 → 34943 rows
# Processing row group 562/17551... ✅ 122880 → 36211 rows
# Processing row group 563/17551... ✅ 122880 → 47757 rows
# Processing row group 564/17551... ✅ 122880 → 29707 rows
# Processing row group 565/17551... ✅ 122880 → 48440 rows
# Processing row group 566/17551... ✅ 122880 → 41724 rows
# Processing row group 567/17551... ✅ 122880 → 40988 rows
# Processing row group 568/17551... ✅ 122880 → 42340 rows
# Processing row group 569/17551... ✅ 122880 → 50353 rows
# Processing row group 570/17551... ✅ 122880 → 43096 rows
# Processing row group 571/17551... ✅ 122880 → 43630 rows
# Processing row group 572/17551... ✅ 122880 → 48796 rows
# Processing row group 573/17551... ✅ 122880 → 51847 rows
# Processing row group 574/17551... ✅ 122880 → 49592 rows
# Processing row group 575/17551... ✅ 122880 → 36848 rows
# Processing row group 576/17551... ✅ 122880 → 59692 rows
# Processing row group 577/17551... ✅ 122880 → 27207 rows
# Processing row group 578/17551... ✅ 122880 → 39900 rows
# Processing row group 579/17551... ✅ 122880 → 28791 rows
# Processing row group 580/17551... ✅ 122880 → 70206 rows
# Processing row group 581/17551... ✅ 122880 → 46423 rows
# Processing row group 582/17551... ✅ 122880 → 64120 rows
# Processing row group 583/17551... ✅ 122880 → 41856 rows
# Processing row group 584/17551... ✅ 122880 → 46904 rows
# Processing row group 585/17551... ✅ 122880 → 37568 rows
# Processing row group 586/17551... ✅ 122880 → 36262 rows
# Processing row group 587/17551... ✅ 122880 → 58952 rows
# Processing row group 588/17551... ✅ 122880 → 29692 rows
# Processing row group 589/17551... ✅ 122880 → 34545 rows
# Processing row group 590/17551... ✅ 122880 → 34199 rows
# Processing row group 591/17551... ✅ 122880 → 44025 rows
# Processing row group 592/17551... ✅ 122880 → 39897 rows
# Processing row group 593/17551... ✅ 122880 → 54212 rows
# Processing row group 594/17551... ✅ 122880 → 10975 rows
# Processing row group 595/17551... ✅ 122880 → 40004 rows
# Processing row group 596/17551... ✅ 122880 → 53141 rows
# Processing row group 597/17551... ✅ 122880 → 27933 rows
# Processing row group 598/17551... ✅ 123505 → 32182 rows
# Processing row group 599/17551... ✅ 122880 → 53143 rows
# Processing row group 600/17551... ✅ 122880 → 43106 rows
# Processing row group 601/17551... ✅ 122880 → 46361 rows
# Processing row group 602/17551... ✅ 122880 → 59383 rows
# Processing row group 603/17551... ✅ 122880 → 42829 rows
# Processing row group 604/17551... ✅ 122880 → 34216 rows
# Processing row group 605/17551... ✅ 122880 → 41267 rows
# Processing row group 606/17551... ✅ 122880 → 53548 rows
# Processing row group 607/17551... ✅ 122880 → 35745 rows
# Processing row group 608/17551... ✅ 122880 → 47504 rows
# Processing row group 609/17551... ✅ 122880 → 46501 rows
# Processing row group 610/17551... ✅ 122880 → 60317 rows
# Processing row group 611/17551... ✅ 122880 → 29404 rows
# Processing row group 612/17551... ✅ 122880 → 24696 rows
# Processing row group 613/17551... ✅ 122880 → 35419 rows
# Processing row group 614/17551... ✅ 122880 → 36851 rows
# Processing row group 615/17551... ✅ 122880 → 32947 rows
# Processing row group 616/17551... ✅ 122880 → 35266 rows
# Processing row group 617/17551... ✅ 122880 → 31654 rows
# Processing row group 618/17551... ✅ 122880 → 22280 rows
# Processing row group 619/17551... ✅ 122880 → 39641 rows
# Processing row group 620/17551... ✅ 122880 → 47374 rows
# Processing row group 621/17551... ✅ 122880 → 33743 rows
# Processing row group 622/17551... ✅ 122880 → 32236 rows
# Processing row group 623/17551... ✅ 122880 → 40364 rows
# Processing row group 624/17551... ✅ 122880 → 60894 rows
# Processing row group 625/17551... ✅ 122880 → 63105 rows
# Processing row group 626/17551... ✅ 122880 → 31849 rows
# Processing row group 627/17551... ✅ 122880 → 65623 rows
# Processing row group 628/17551... ✅ 122880 → 16749 rows
# Processing row group 629/17551... ✅ 122880 → 40626 rows
# Processing row group 630/17551... ✅ 122880 → 48945 rows
# Processing row group 631/17551... ✅ 122880 → 47992 rows
# Processing row group 632/17551... ✅ 122880 → 39877 rows
# Processing row group 633/17551... ✅ 122880 → 61646 rows
# Processing row group 634/17551... ✅ 122880 → 39037 rows
# Processing row group 635/17551... ✅ 122880 → 33830 rows
# Processing row group 636/17551... ✅ 122880 → 40173 rows
# Processing row group 637/17551... ✅ 122880 → 37761 rows
# Processing row group 638/17551... ✅ 122880 → 44349 rows
# Processing row group 639/17551... ✅ 122880 → 54395 rows
# Processing row group 640/17551... ✅ 122880 → 33394 rows
# Processing row group 641/17551... ✅ 122880 → 40275 rows
# Processing row group 642/17551... ✅ 122880 → 52053 rows
# Processing row group 643/17551... ✅ 122880 → 40964 rows
# Processing row group 644/17551... ✅ 122880 → 42393 rows
# Processing row group 645/17551... ✅ 122880 → 38161 rows
# Processing row group 646/17551... ✅ 122880 → 44409 rows
# Processing row group 647/17551... ✅ 122880 → 38015 rows
# Processing row group 648/17551... ✅ 123505 → 30521 rows
# Processing row group 649/17551... ✅ 122880 → 37244 rows
# Processing row group 650/17551... ✅ 122880 → 33985 rows
# Processing row group 651/17551... ✅ 122880 → 43779 rows
# Processing row group 652/17551... ✅ 122880 → 25119 rows
# Processing row group 653/17551... ✅ 122880 → 38674 rows
# Processing row group 654/17551... ✅ 122880 → 39692 rows
# Processing row group 655/17551... ✅ 122880 → 42313 rows
# Processing row group 656/17551... ✅ 122880 → 53682 rows
# Processing row group 657/17551... ✅ 122880 → 32178 rows
# Processing row group 658/17551... ✅ 122880 → 50549 rows
# Processing row group 659/17551... ✅ 122880 → 50339 rows
# Processing row group 660/17551... ✅ 122880 → 44262 rows
# Processing row group 661/17551... ✅ 122880 → 36944 rows
# Processing row group 662/17551... ✅ 122880 → 49569 rows
# Processing row group 663/17551... ✅ 122880 → 34828 rows
# Processing row group 664/17551... ✅ 122880 → 45686 rows
# Processing row group 665/17551... ✅ 122880 → 76538 rows
# Processing row group 666/17551... ✅ 122880 → 30134 rows
# Processing row group 667/17551... ✅ 122880 → 27289 rows
# Processing row group 668/17551... ✅ 122880 → 28509 rows
# Processing row group 669/17551... ✅ 122880 → 34926 rows
# Processing row group 670/17551... ✅ 122880 → 39369 rows
# Processing row group 671/17551... ✅ 122880 → 48294 rows
# Processing row group 672/17551... ✅ 122880 → 41600 rows
# Processing row group 673/17551... ✅ 122880 → 31362 rows
# Processing row group 674/17551... ✅ 122880 → 41985 rows
# Processing row group 675/17551... ✅ 122880 → 36440 rows
# Processing row group 676/17551... ✅ 122880 → 30932 rows
# Processing row group 677/17551... ✅ 122880 → 38346 rows
# Processing row group 678/17551... ✅ 122880 → 18980 rows
# Processing row group 679/17551... ✅ 122880 → 42003 rows
# Processing row group 680/17551... ✅ 122880 → 46689 rows
# Processing row group 681/17551... ✅ 122880 → 22230 rows
# Processing row group 682/17551... ✅ 122880 → 37936 rows
# Processing row group 683/17551... ✅ 122880 → 33054 rows
# Processing row group 684/17551... ✅ 122880 → 48197 rows
# Processing row group 685/17551... ✅ 122880 → 31511 rows
# Processing row group 686/17551... ✅ 122880 → 46017 rows
# Processing row group 687/17551... ✅ 122880 → 38201 rows
# Processing row group 688/17551... ✅ 122880 → 37346 rows
# Processing row group 689/17551... ✅ 122880 → 36554 rows
# Processing row group 690/17551... ✅ 122880 → 45574 rows
# Processing row group 691/17551... ✅ 122880 → 40441 rows
# Processing row group 692/17551... ✅ 122880 → 41972 rows
# Processing row group 693/17551... ✅ 122880 → 38701 rows
# Processing row group 694/17551... ✅ 122880 → 34491 rows
# Processing row group 695/17551... ✅ 122880 → 45156 rows
# Processing row group 696/17551... ✅ 122880 → 53417 rows
# Processing row group 697/17551... ✅ 123505 → 40301 rows
# Processing row group 698/17551... ✅ 122880 → 35754 rows
# Processing row group 699/17551... ✅ 122880 → 43748 rows
# Processing row group 700/17551... ✅ 122880 → 60238 rows
# Processing row group 701/17551... ✅ 122880 → 54282 rows
# Processing row group 702/17551... ✅ 122880 → 27054 rows
# Processing row group 703/17551... ✅ 122880 → 35151 rows
# Processing row group 704/17551... ✅ 122880 → 48474 rows
# Processing row group 705/17551... ✅ 122880 → 58499 rows
# Processing row group 706/17551... ✅ 122880 → 36637 rows
# Processing row group 707/17551... ✅ 122880 → 49453 rows
# Processing row group 708/17551... ✅ 122880 → 45486 rows
# Processing row group 709/17551... ✅ 122880 → 39994 rows
# Processing row group 710/17551... ✅ 122880 → 46345 rows
# Processing row group 711/17551... ✅ 122880 → 47270 rows
# Processing row group 712/17551... ✅ 122880 → 37567 rows
# Processing row group 713/17551... ✅ 122880 → 33414 rows
# Processing row group 714/17551... ✅ 122880 → 40047 rows
# Processing row group 715/17551... ✅ 122880 → 33472 rows
# Processing row group 716/17551... ✅ 122880 → 35142 rows
# Processing row group 717/17551... ✅ 122880 → 48927 rows
# Processing row group 718/17551... ✅ 122880 → 32031 rows
# Processing row group 719/17551... ✅ 122880 → 36018 rows
# Processing row group 720/17551... ✅ 122880 → 46688 rows
# Processing row group 721/17551... ✅ 122880 → 38603 rows
# Processing row group 722/17551... ✅ 122880 → 45855 rows
# Processing row group 723/17551... ✅ 122880 → 49379 rows
# Processing row group 724/17551... ✅ 122880 → 38106 rows
# Processing row group 725/17551... ✅ 122880 → 33995 rows
# Processing row group 726/17551... ✅ 122880 → 40421 rows
# Processing row group 727/17551... ✅ 122880 → 42484 rows
# Processing row group 728/17551... ✅ 122880 → 32298 rows
# Processing row group 729/17551... ✅ 122880 → 53771 rows
# Processing row group 730/17551... ✅ 122880 → 39858 rows
# Processing row group 731/17551... ✅ 122880 → 38741 rows
# Processing row group 732/17551... ✅ 122880 → 40405 rows
# Processing row group 733/17551... ✅ 122880 → 24423 rows
# Processing row group 734/17551... ✅ 122880 → 37677 rows
# Processing row group 735/17551... ✅ 122880 → 41776 rows
# Processing row group 736/17551... ✅ 122880 → 50766 rows
# Processing row group 737/17551... ✅ 122880 → 47138 rows
# Processing row group 738/17551... ✅ 122880 → 36666 rows
# Processing row group 739/17551... ✅ 122880 → 55703 rows
# Processing row group 740/17551... ✅ 122880 → 50068 rows
# Processing row group 741/17551... ✅ 122880 → 44082 rows
# Processing row group 742/17551... ✅ 122880 → 45947 rows
# Processing row group 743/17551... ✅ 122880 → 39548 rows
# Processing row group 744/17551... ✅ 122880 → 54195 rows
# Processing row group 745/17551... ✅ 122880 → 38621 rows
# Processing row group 746/17551... ✅ 122880 → 39893 rows
# Processing row group 747/17551... ✅ 123505 → 44551 rows
# Processing row group 748/17551... ✅ 122880 → 47728 rows
# Processing row group 749/17551... ✅ 122880 → 31734 rows
# Processing row group 750/17551... ✅ 122880 → 46710 rows
# Processing row group 751/17551... ✅ 122880 → 39680 rows
# Processing row group 752/17551... ✅ 122880 → 50019 rows
# Processing row group 753/17551... ✅ 122880 → 27056 rows
# Processing row group 754/17551... ✅ 122880 → 104866 rows
# Processing row group 755/17551... ✅ 122880 → 47606 rows
# Processing row group 756/17551... ✅ 122880 → 36071 rows
# Processing row group 757/17551... ✅ 122880 → 58835 rows
# Processing row group 758/17551... ✅ 122880 → 52243 rows
# Processing row group 759/17551... ✅ 122880 → 20803 rows
# Processing row group 760/17551... ✅ 122880 → 71864 rows
# Processing row group 761/17551... ✅ 122880 → 37107 rows
# Processing row group 762/17551... ✅ 122880 → 44951 rows
# Processing row group 763/17551... ✅ 122880 → 48161 rows
# Processing row group 764/17551... ✅ 122880 → 43736 rows
# Processing row group 765/17551... ✅ 122880 → 23285 rows
# Processing row group 766/17551... ✅ 122880 → 34882 rows
# Processing row group 767/17551... ✅ 122880 → 50066 rows
# Processing row group 768/17551... ✅ 122880 → 37064 rows
# Processing row group 769/17551... ✅ 122880 → 40945 rows
# Processing row group 770/17551... ✅ 122880 → 37889 rows
# Processing row group 771/17551... ✅ 122880 → 34142 rows
# Processing row group 772/17551... ✅ 122880 → 36148 rows
# Processing row group 773/17551... ✅ 122880 → 32255 rows
# Processing row group 774/17551... ✅ 122880 → 51090 rows
# Processing row group 775/17551... ✅ 122880 → 35747 rows
# Processing row group 776/17551... ✅ 122880 → 48609 rows
# Processing row group 777/17551... ✅ 122880 → 46083 rows
# Processing row group 778/17551... ✅ 122880 → 50021 rows
# Processing row group 779/17551... ✅ 122880 → 39130 rows
# Processing row group 780/17551... ✅ 122880 → 43586 rows
# Processing row group 781/17551... ✅ 122880 → 32661 rows
# Processing row group 782/17551... ✅ 122880 → 37789 rows
# Processing row group 783/17551... ✅ 122880 → 41463 rows
# Processing row group 784/17551... ✅ 122880 → 47805 rows
# Processing row group 785/17551... ✅ 122880 → 40422 rows
# Processing row group 786/17551... ✅ 122880 → 37853 rows
# Processing row group 787/17551... ✅ 122880 → 32863 rows
# Processing row group 788/17551... ✅ 122880 → 65546 rows
# Processing row group 789/17551... ✅ 122880 → 33514 rows
# Processing row group 790/17551... ✅ 122880 → 35679 rows
# Processing row group 791/17551... ✅ 122880 → 38365 rows
# Processing row group 792/17551... ✅ 122880 → 47388 rows
# Processing row group 793/17551... ✅ 122880 → 32939 rows
# Processing row group 794/17551... ✅ 122880 → 52915 rows
# Processing row group 795/17551... ✅ 122880 → 34253 rows
# Processing row group 796/17551... ✅ 122880 → 63021 rows
# Processing row group 797/17551... ✅ 123505 → 52830 rows
# Processing row group 798/17551... ✅ 122880 → 36299 rows
# Processing row group 799/17551... ✅ 122880 → 41654 rows
# Processing row group 800/17551... ✅ 122880 → 55292 rows
# Processing row group 801/17551... ✅ 122880 → 77251 rows
# Processing row group 802/17551... ✅ 122880 → 39769 rows
# Processing row group 803/17551... ✅ 122880 → 35975 rows
# Processing row group 804/17551... ✅ 122880 → 46756 rows
# Processing row group 805/17551... ✅ 122880 → 35949 rows
# Processing row group 806/17551... ✅ 122880 → 45038 rows
# Processing row group 807/17551... ✅ 122880 → 52356 rows
# Processing row group 808/17551... ✅ 122880 → 54693 rows
# Processing row group 809/17551... ✅ 122880 → 39299 rows
# Processing row group 810/17551... ✅ 122880 → 34018 rows
# Processing row group 811/17551... ✅ 122880 → 41144 rows
# Processing row group 812/17551... ✅ 122880 → 37958 rows
# Processing row group 813/17551... ✅ 122880 → 33972 rows
# Processing row group 814/17551... ✅ 122880 → 29606 rows
# Processing row group 815/17551... ✅ 122880 → 45520 rows
# Processing row group 816/17551... ✅ 122880 → 47792 rows
# Processing row group 817/17551... ✅ 122880 → 47638 rows
# Processing row group 818/17551... ✅ 122880 → 40697 rows
# Processing row group 819/17551... ✅ 122880 → 46380 rows
# Processing row group 820/17551... ✅ 122880 → 76710 rows
# Processing row group 821/17551... ✅ 122880 → 40769 rows
# Processing row group 822/17551... ✅ 122880 → 44908 rows
# Processing row group 823/17551... ✅ 122880 → 39764 rows
# Processing row group 824/17551... ✅ 122880 → 36864 rows
# Processing row group 825/17551... ✅ 122880 → 21659 rows
# Processing row group 826/17551... ✅ 122880 → 41132 rows
# Processing row group 827/17551... ✅ 122880 → 34184 rows
# Processing row group 828/17551... ✅ 122880 → 46205 rows
# Processing row group 829/17551... ✅ 122880 → 34331 rows
# Processing row group 830/17551... ✅ 122880 → 53433 rows
# Processing row group 831/17551... ✅ 122880 → 47341 rows
# Processing row group 832/17551... ✅ 122880 → 46138 rows
# Processing row group 833/17551... ✅ 122880 → 40988 rows
# Processing row group 834/17551... ✅ 122880 → 43535 rows
# Processing row group 835/17551... ✅ 122880 → 35217 rows
# Processing row group 836/17551... ✅ 122880 → 36031 rows
# Processing row group 837/17551... ✅ 122880 → 45954 rows
# Processing row group 838/17551... ✅ 122880 → 39407 rows
# Processing row group 839/17551... ✅ 122880 → 58383 rows
# Processing row group 840/17551... ✅ 122880 → 50735 rows
# Processing row group 841/17551... ✅ 122880 → 39750 rows
# Processing row group 842/17551... ✅ 122880 → 39986 rows
# Processing row group 843/17551... ✅ 122880 → 26782 rows
# Processing row group 844/17551... ✅ 122880 → 38289 rows
# Processing row group 845/17551... ✅ 122880 → 36933 rows
# Processing row group 846/17551... ✅ 122880 → 36895 rows
# Processing row group 847/17551... ✅ 123505 → 49517 rows
# Processing row group 848/17551... ✅ 122880 → 48930 rows
# Processing row group 849/17551... ✅ 122880 → 35720 rows
# Processing row group 850/17551... ✅ 122880 → 37741 rows
# Processing row group 851/17551... ✅ 122880 → 90013 rows
# Processing row group 852/17551... ✅ 122880 → 67427 rows
# Processing row group 853/17551... ✅ 122880 → 46006 rows
# Processing row group 854/17551... ✅ 122880 → 46177 rows
# ...
# Processing row group 17286/17551... ✅ 122880 → 58986 rows
# Processing row group 17287/17551... ✅ 122880 → 61165 rows
# Processing row group 17288/17551... ✅ 122880 → 42062 rows
# Processing row group 17289/17551... ✅ 122880 → 38324 rows
# Processing row group 17290/17551... ✅ 122880 → 15498 rows
# Processing row group 17291/17551... ✅ 122880 → 26224 rows
# Processing row group 17292/17551... ✅ 122880 → 40839 rows
# Processing row group 17293/17551... ✅ 122880 → 22931 rows
# Processing row group 17294/17551... ✅ 122880 → 35421 rows
# Processing row group 17295/17551... ✅ 122880 → 32630 rows
# Processing row group 17296/17551... ✅ 122880 → 41417 rows
# Processing row group 17297/17551... ✅ 122880 → 44932 rows
# Processing row group 17298/17551... ✅ 122880 → 34429 rows
# Processing row group 17299/17551... ✅ 122880 → 60615 rows
# Processing row group 17300/17551... ✅ 122880 → 41144 rows
# Processing row group 17301/17551... ✅ 122880 → 46305 rows
# Processing row group 17302/17551... ✅ 122880 → 12100 rows
# Processing row group 17303/17551... ✅ 122880 → 57585 rows
# Processing row group 17304/17551... ✅ 122880 → 32084 rows
# Processing row group 17305/17551... ✅ 122880 → 37150 rows
# Processing row group 17306/17551... ✅ 122880 → 43449 rows
# Processing row group 17307/17551... ✅ 122880 → 54708 rows
# Processing row group 17308/17551... ✅ 122880 → 44138 rows
# Processing row group 17309/17551... ✅ 122880 → 59098 rows
# Processing row group 17310/17551... ✅ 122880 → 39160 rows
# Processing row group 17311/17551... ✅ 122880 → 35920 rows
# Processing row group 17312/17551... ✅ 122880 → 64100 rows
# Processing row group 17313/17551... ✅ 122880 → 37276 rows
# Processing row group 17314/17551... ✅ 122880 → 39130 rows
# Processing row group 17315/17551... ✅ 122880 → 50311 rows
# Processing row group 17316/17551... ✅ 122880 → 39312 rows
# Processing row group 17317/17551... ✅ 122880 → 47463 rows
# Processing row group 17318/17551... ✅ 122880 → 29541 rows
# Processing row group 17319/17551... ✅ 122880 → 40982 rows
# Processing row group 17320/17551... ✅ 122880 → 36012 rows
# Processing row group 17321/17551... ✅ 122880 → 41461 rows
# Processing row group 17322/17551... ✅ 122880 → 43267 rows
# Processing row group 17323/17551... ✅ 122880 → 42663 rows
# Processing row group 17324/17551... ✅ 122880 → 40946 rows
# Processing row group 17325/17551... ✅ 123505 → 41975 rows
# Processing row group 17326/17551... ✅ 122880 → 43214 rows
# Processing row group 17327/17551... ✅ 122880 → 34374 rows
# Processing row group 17328/17551... ✅ 122880 → 38163 rows
# Processing row group 17329/17551... ✅ 122880 → 35547 rows
# Processing row group 17330/17551... ✅ 122880 → 35205 rows
# Processing row group 17331/17551... ✅ 122880 → 46639 rows
# Processing row group 17332/17551... ✅ 122880 → 48756 rows
# Processing row group 17333/17551... ✅ 122880 → 40278 rows
# Processing row group 17334/17551... ✅ 122880 → 46316 rows
# Processing row group 17335/17551... ✅ 122880 → 42270 rows
# Processing row group 17336/17551... ✅ 122880 → 35425 rows
# Processing row group 17337/17551... ✅ 122880 → 58772 rows
# Processing row group 17338/17551... ✅ 122880 → 32226 rows
# Processing row group 17339/17551... ✅ 122880 → 42935 rows
# Processing row group 17340/17551... ✅ 122880 → 40778 rows
# Processing row group 17341/17551... ✅ 122880 → 29947 rows
# Processing row group 17342/17551... ✅ 122880 → 44141 rows
# Processing row group 17343/17551... ✅ 122880 → 48699 rows
# Processing row group 17344/17551... ✅ 122880 → 45383 rows
# Processing row group 17345/17551... ✅ 122880 → 38227 rows
# Processing row group 17346/17551... ✅ 122880 → 50765 rows
# Processing row group 17347/17551... ✅ 122880 → 39257 rows
# Processing row group 17348/17551... ✅ 122880 → 29171 rows
# Processing row group 17349/17551... ✅ 122880 → 34840 rows
# Processing row group 17350/17551... ✅ 122880 → 44755 rows
# Processing row group 17351/17551... ✅ 122880 → 40684 rows
# Processing row group 17352/17551... ✅ 122880 → 73010 rows
# Processing row group 17353/17551... ✅ 122880 → 52776 rows
# Processing row group 17354/17551... ✅ 122880 → 51263 rows
# Processing row group 17355/17551... ✅ 122880 → 40267 rows
# Processing row group 17356/17551... ✅ 122880 → 38147 rows
# Processing row group 17357/17551... ✅ 122880 → 36968 rows
# Processing row group 17358/17551... ✅ 122880 → 54113 rows
# Processing row group 17359/17551... ✅ 122880 → 44344 rows
# Processing row group 17360/17551... ✅ 122880 → 50011 rows
# Processing row group 17361/17551... ✅ 122880 → 36619 rows
# Processing row group 17362/17551... ✅ 122880 → 77002 rows
# Processing row group 17363/17551... ✅ 122880 → 49164 rows
# Processing row group 17364/17551... ✅ 122880 → 72004 rows
# Processing row group 17365/17551... ✅ 122880 → 45601 rows
# Processing row group 17366/17551... ✅ 122880 → 39346 rows
# Processing row group 17367/17551... ✅ 122880 → 38151 rows
# Processing row group 17368/17551... ✅ 122880 → 38336 rows
# Processing row group 17369/17551... ✅ 122880 → 42074 rows
# Processing row group 17370/17551... ✅ 122880 → 30780 rows
# Processing row group 17371/17551... ✅ 122880 → 49039 rows
# Processing row group 17372/17551... ✅ 122880 → 36220 rows
# Processing row group 17373/17551... ✅ 122880 → 40137 rows
# Processing row group 17374/17551... ✅ 122880 → 45151 rows
# Processing row group 17375/17551... ✅ 123505 → 50164 rows
# Processing row group 17376/17551... ✅ 122880 → 62309 rows
# Processing row group 17377/17551... ✅ 122880 → 69556 rows
# Processing row group 17378/17551... ✅ 122880 → 38576 rows
# Processing row group 17379/17551... ✅ 122880 → 50277 rows
# Processing row group 17380/17551... ✅ 122880 → 50904 rows
# Processing row group 17381/17551... ✅ 122880 → 53883 rows
# Processing row group 17382/17551... ✅ 122880 → 46205 rows
# Processing row group 17383/17551... ✅ 122880 → 29223 rows
# Processing row group 17384/17551... ✅ 122880 → 35050 rows
# Processing row group 17385/17551... ✅ 122880 → 44377 rows
# Processing row group 17386/17551... ✅ 122880 → 49709 rows
# Processing row group 17387/17551... ✅ 122880 → 48348 rows
# Processing row group 17388/17551... ✅ 122880 → 68780 rows
# Processing row group 17389/17551... ✅ 122880 → 37360 rows
# Processing row group 17390/17551... ✅ 122880 → 40370 rows
# Processing row group 17391/17551... ✅ 122880 → 28943 rows
# Processing row group 17392/17551... ✅ 122880 → 27558 rows
# Processing row group 17393/17551... ✅ 122880 → 39435 rows
# Processing row group 17394/17551... ✅ 122880 → 33315 rows
# Processing row group 17395/17551... ✅ 122880 → 35395 rows
# Processing row group 17396/17551... ✅ 122880 → 32064 rows
# Processing row group 17397/17551... ✅ 122880 → 42145 rows
# Processing row group 17398/17551... ✅ 122880 → 40092 rows
# Processing row group 17399/17551... ✅ 122880 → 45294 rows
# Processing row group 17400/17551... ✅ 122880 → 52698 rows
# Processing row group 17401/17551... ✅ 122880 → 19210 rows
# Processing row group 17402/17551... ✅ 122880 → 42188 rows
# Processing row group 17403/17551... ✅ 122880 → 47301 rows
# Processing row group 17404/17551... ✅ 122880 → 53440 rows
# Processing row group 17405/17551... ✅ 122880 → 38336 rows
# Processing row group 17406/17551... ✅ 122880 → 39745 rows
# Processing row group 17407/17551... ✅ 122880 → 46096 rows
# Processing row group 17408/17551... ✅ 122880 → 42562 rows
# Processing row group 17409/17551... ✅ 122880 → 44785 rows
# Processing row group 17410/17551... ✅ 122880 → 52249 rows
# Processing row group 17411/17551... ✅ 122880 → 37273 rows
# Processing row group 17412/17551... ✅ 122880 → 51495 rows
# Processing row group 17413/17551... ✅ 122880 → 27659 rows
# Processing row group 17414/17551... ✅ 122880 → 101290 rows
# Processing row group 17415/17551... ✅ 122880 → 41992 rows
# Processing row group 17416/17551... ✅ 122880 → 45173 rows
# Processing row group 17417/17551... ✅ 122880 → 43572 rows
# Processing row group 17418/17551... ✅ 122880 → 35196 rows
# Processing row group 17419/17551... ✅ 122880 → 38680 rows
# Processing row group 17420/17551... ✅ 122880 → 42541 rows
# Processing row group 17421/17551... ✅ 122880 → 35330 rows
# Processing row group 17422/17551... ✅ 122880 → 31394 rows
# Processing row group 17423/17551... ✅ 122880 → 37988 rows
# Processing row group 17424/17551... ✅ 122880 → 38868 rows
# Processing row group 17425/17551... ✅ 123505 → 53661 rows
# Processing row group 17426/17551... ✅ 122880 → 43834 rows
# Processing row group 17427/17551... ✅ 122880 → 32924 rows
# Processing row group 17428/17551... ✅ 122880 → 43347 rows
# Processing row group 17429/17551... ✅ 122880 → 27150 rows
# Processing row group 17430/17551... ✅ 122880 → 98401 rows
# Processing row group 17431/17551... ✅ 122880 → 37043 rows
# Processing row group 17432/17551... ✅ 122880 → 65434 rows
# Processing row group 17433/17551... ✅ 122880 → 47418 rows
# Processing row group 17434/17551... ✅ 122880 → 51631 rows
# Processing row group 17435/17551... ✅ 122880 → 61601 rows
# Processing row group 17436/17551... ✅ 122880 → 44096 rows
# Processing row group 17437/17551... ✅ 122880 → 28545 rows
# Processing row group 17438/17551... ✅ 122880 → 28723 rows
# Processing row group 17439/17551... ✅ 122880 → 33804 rows
# Processing row group 17440/17551... ✅ 122880 → 44606 rows
# Processing row group 17441/17551... ✅ 122880 → 53414 rows
# Processing row group 17442/17551... ✅ 122880 → 66029 rows
# Processing row group 17443/17551... ✅ 122880 → 58642 rows
# Processing row group 17444/17551... ✅ 122880 → 43644 rows
# Processing row group 17445/17551... ✅ 122880 → 53403 rows
# Processing row group 17446/17551... ✅ 122880 → 22460 rows
# Processing row group 17447/17551... ✅ 122880 → 122880 rows
# Processing row group 17448/17551... ✅ 122880 → 39415 rows
# Processing row group 17449/17551... ✅ 122880 → 46575 rows
# Processing row group 17450/17551... ✅ 122880 → 35496 rows
# Processing row group 17451/17551... ✅ 122880 → 57228 rows
# Processing row group 17452/17551... ✅ 122880 → 40794 rows
# Processing row group 17453/17551... ✅ 122880 → 45455 rows
# Processing row group 17454/17551... ✅ 122880 → 43782 rows
# Processing row group 17455/17551... ✅ 122880 → 39893 rows
# Processing row group 17456/17551... ✅ 122880 → 39456 rows
# Processing row group 17457/17551... ✅ 122880 → 42534 rows
# Processing row group 17458/17551... ✅ 122880 → 55200 rows
# Processing row group 17459/17551... ✅ 122880 → 45672 rows
# Processing row group 17460/17551... ✅ 122880 → 36530 rows
# Processing row group 17461/17551... ✅ 122880 → 33145 rows
# Processing row group 17462/17551... ✅ 122880 → 27660 rows
# Processing row group 17463/17551... ✅ 122880 → 42015 rows
# Processing row group 17464/17551... ✅ 122880 → 38755 rows
# Processing row group 17465/17551... ✅ 122880 → 34061 rows
# Processing row group 17466/17551... ✅ 122880 → 33813 rows
# Processing row group 17467/17551... ✅ 122880 → 38654 rows
# Processing row group 17468/17551... ✅ 122880 → 48450 rows
# Processing row group 17469/17551... ✅ 122880 → 37608 rows
# Processing row group 17470/17551... ✅ 122880 → 46605 rows
# Processing row group 17471/17551... ✅ 122880 → 44908 rows
# Processing row group 17472/17551... ✅ 122880 → 55462 rows
# Processing row group 17473/17551... ✅ 122880 → 35788 rows
# Processing row group 17474/17551... ✅ 123505 → 35317 rows
# Processing row group 17475/17551... ✅ 122880 → 34880 rows
# Processing row group 17476/17551... ✅ 122880 → 41533 rows
# Processing row group 17477/17551... ✅ 122880 → 36265 rows
# Processing row group 17478/17551... ✅ 122880 → 40148 rows
# Processing row group 17479/17551... ✅ 122880 → 58100 rows
# Processing row group 17480/17551... ✅ 122880 → 38710 rows
# Processing row group 17481/17551... ✅ 122880 → 38925 rows
# Processing row group 17482/17551... ✅ 122880 → 38049 rows
# Processing row group 17483/17551... ✅ 122880 → 40517 rows
# Processing row group 17484/17551... ✅ 122880 → 40868 rows
# Processing row group 17485/17551... ✅ 122880 → 52799 rows
# Processing row group 17486/17551... ✅ 122880 → 23658 rows
# Processing row group 17487/17551... ✅ 122880 → 31454 rows
# Processing row group 17488/17551... ✅ 122880 → 36738 rows
# Processing row group 17489/17551... ✅ 122880 → 44840 rows
# Processing row group 17490/17551... ✅ 122880 → 21086 rows
# Processing row group 17491/17551... ✅ 122880 → 41791 rows
# Processing row group 17492/17551... ✅ 122880 → 56276 rows
# Processing row group 17493/17551... ✅ 122880 → 49688 rows
# Processing row group 17494/17551... ✅ 122880 → 37292 rows
# Processing row group 17495/17551... ✅ 122880 → 43305 rows
# Processing row group 17496/17551... ✅ 122880 → 38109 rows
# Processing row group 17497/17551... ✅ 122880 → 41604 rows
# Processing row group 17498/17551... ✅ 122880 → 36680 rows
# Processing row group 17499/17551... ✅ 122880 → 37600 rows
# Processing row group 17500/17551... ✅ 122880 → 40825 rows
# Processing row group 17501/17551... ✅ 122880 → 34740 rows
# Processing row group 17502/17551... ✅ 122880 → 42800 rows
# Processing row group 17503/17551... ✅ 122880 → 22954 rows
# Processing row group 17504/17551... ✅ 122880 → 47341 rows
# Processing row group 17505/17551... ✅ 122880 → 37440 rows
# Processing row group 17506/17551... ✅ 122880 → 26840 rows
# Processing row group 17507/17551... ✅ 122880 → 50911 rows
# Processing row group 17508/17551... ✅ 122880 → 49691 rows
# Processing row group 17509/17551... ✅ 122880 → 47426 rows
# Processing row group 17510/17551... ✅ 122880 → 51883 rows
# Processing row group 17511/17551... ✅ 122880 → 51374 rows
# Processing row group 17512/17551... ✅ 122880 → 48927 rows
# Processing row group 17513/17551... ✅ 122880 → 32604 rows
# Processing row group 17514/17551... ✅ 122880 → 49500 rows
# Processing row group 17515/17551... ✅ 122880 → 33369 rows
# Processing row group 17516/17551... ✅ 122880 → 52705 rows
# Processing row group 17517/17551... ✅ 122880 → 42486 rows
# Processing row group 17518/17551... ✅ 122880 → 53543 rows
# Processing row group 17519/17551... ✅ 122880 → 39899 rows
# Processing row group 17520/17551... ✅ 122880 → 42605 rows
# Processing row group 17521/17551... ✅ 122880 → 34367 rows
# Processing row group 17522/17551... ✅ 122880 → 35675 rows
# Processing row group 17523/17551... ✅ 122880 → 52040 rows
# Processing row group 17524/17551... ✅ 123505 → 37486 rows
# Processing row group 17525/17551... ✅ 122880 → 38283 rows
# Processing row group 17526/17551... ✅ 122880 → 25073 rows
# Processing row group 17527/17551... ✅ 122880 → 34250 rows
# Processing row group 17528/17551... ✅ 122880 → 37562 rows
# Processing row group 17529/17551... ✅ 122880 → 27333 rows
# Processing row group 17530/17551... ✅ 122880 → 38721 rows
# Processing row group 17531/17551... ✅ 122880 → 37910 rows
# Processing row group 17532/17551... ✅ 122880 → 70665 rows
# Processing row group 17533/17551... ✅ 122880 → 30053 rows
# Processing row group 17534/17551... ✅ 122880 → 31106 rows
# Processing row group 17535/17551... ✅ 122880 → 50637 rows
# Processing row group 17536/17551... ✅ 122880 → 54573 rows
# Processing row group 17537/17551... ✅ 122880 → 41255 rows
# Processing row group 17538/17551... ✅ 122880 → 33542 rows
# Processing row group 17539/17551... ✅ 122880 → 40027 rows
# Processing row group 17540/17551... ✅ 122880 → 54359 rows
# Processing row group 17541/17551... ✅ 122880 → 43013 rows
# Processing row group 17542/17551... ✅ 122880 → 37896 rows
# Processing row group 17543/17551... ✅ 122880 → 62782 rows
# Processing row group 17544/17551... ✅ 122880 → 33958 rows
# Processing row group 17545/17551... ✅ 122880 → 30688 rows
# Processing row group 17546/17551... ✅ 122880 → 40676 rows
# Processing row group 17547/17551... ✅ 122880 → 49002 rows
# Processing row group 17548/17551... ✅ 122880 → 35338 rows
# Processing row group 17549/17551... ✅ 122880 → 39303 rows
# Processing row group 17550/17551... ✅ 122880 → 42632 rows
# Processing row group 17551/17551... ✅ 16748 → 6563 rows
#
# ============================================================
# ROW GROUP CLEANING SUMMARY:
# ============================================================
# Row groups: 17551 processed
# Rows:       2,156,778,700 → 761,216,213 (35.3% kept)
# File size:  23.17 GB → 7.95 GB
# Reduction:  15.23 GB (65.7%)
# Columns:    4 → 3
# ============================================================
# {'original_rows': 2156778700,
#  'final_rows': 761216213,
#  'original_size': 24883242260,
#  'final_size': 8535272180,
#  'row_groups_processed': 17551}

# %% [markdown]
# ## Profiles

# %%
i_file = "/home/ale/Documents/uni/mp/data/raw/profiles.parquet"
o_file = "/home/ale/Documents/uni/mp/data/cleaned/profiles.parquet"
clean_parquet_by_row_groups(i_file, o_file, CLEANING_RULES, table_type="profiles")
# Out:
# Cleaning by row groups...
# Input file: 1.77 GB
# Processing row group 1/262... Applied rules: ['removed_null_did_id', 'removed_null_created_at', 'max_date_created_at', 'min_date_created_at']
# ✅ 122880 → 106653 rows
# Processing row group 2/262... ✅ 122880 → 106756 rows
# Processing row group 3/262... ✅ 122880 → 106585 rows
# Processing row group 4/262... ✅ 122880 → 106603 rows
# Processing row group 5/262... ✅ 122880 → 106731 rows
# Processing row group 6/262... ✅ 122880 → 106656 rows
# Processing row group 7/262... ✅ 122880 → 106534 rows
# Processing row group 8/262... ✅ 122880 → 106684 rows
# Processing row group 9/262... ✅ 122880 → 106592 rows
# Processing row group 10/262... ✅ 122880 → 106595 rows
# Processing row group 11/262... ✅ 122880 → 106560 rows
# Processing row group 12/262... ✅ 122880 → 106756 rows
# Processing row group 13/262... ✅ 122880 → 106681 rows
# Processing row group 14/262... ✅ 122880 → 106800 rows
# Processing row group 15/262... ✅ 122880 → 106770 rows
# Processing row group 16/262... ✅ 122880 → 106689 rows
# Processing row group 17/262... ✅ 122880 → 106496 rows
# Processing row group 18/262... ✅ 122880 → 106729 rows
# Processing row group 19/262... ✅ 122880 → 106579 rows
# Processing row group 20/262... ✅ 122880 → 106851 rows
# Processing row group 21/262... ✅ 122880 → 106631 rows
# Processing row group 22/262... ✅ 122880 → 106639 rows
# Processing row group 23/262... ✅ 122880 → 106704 rows
# Processing row group 24/262... ✅ 122880 → 106523 rows
# Processing row group 25/262... ✅ 122880 → 106690 rows
# Processing row group 26/262... ✅ 122880 → 106794 rows
# Processing row group 27/262... ✅ 122880 → 106682 rows
# Processing row group 28/262... ✅ 122880 → 106396 rows
# Processing row group 29/262... ✅ 122880 → 106549 rows
# Processing row group 30/262... ✅ 122880 → 106581 rows
# Processing row group 31/262... ✅ 122880 → 106645 rows
# Processing row group 32/262... ✅ 122880 → 106880 rows
# Processing row group 33/262... ✅ 122880 → 106703 rows
# Processing row group 34/262... ✅ 122880 → 106905 rows
# Processing row group 35/262... ✅ 122880 → 106786 rows
# Processing row group 36/262... ✅ 122880 → 106594 rows
# Processing row group 37/262... ✅ 122880 → 106849 rows
# Processing row group 38/262... ✅ 122880 → 106780 rows
# Processing row group 39/262... ✅ 122880 → 106724 rows
# Processing row group 40/262... ✅ 122880 → 106673 rows
# Processing row group 41/262... ✅ 122880 → 106363 rows
# Processing row group 42/262... ✅ 122880 → 106537 rows
# Processing row group 43/262... ✅ 122880 → 106722 rows
# Processing row group 44/262... ✅ 122880 → 106795 rows
# Processing row group 45/262... ✅ 122880 → 106663 rows
# Processing row group 46/262... ✅ 122880 → 106628 rows
# Processing row group 47/262... ✅ 122880 → 106695 rows
# Processing row group 48/262... ✅ 122880 → 106637 rows
# Processing row group 49/262... ✅ 122880 → 106728 rows
# Processing row group 50/262... ✅ 122880 → 106510 rows
# Processing row group 51/262... ✅ 122880 → 106818 rows
# Processing row group 52/262... ✅ 122880 → 106596 rows
# Processing row group 53/262... ✅ 122880 → 106561 rows
# Processing row group 54/262... ✅ 122880 → 106608 rows
# Processing row group 55/262... ✅ 122880 → 106669 rows
# Processing row group 56/262... ✅ 122880 → 106496 rows
# Processing row group 57/262... ✅ 122880 → 106707 rows
# Processing row group 58/262... ✅ 122880 → 106504 rows
# Processing row group 59/262... ✅ 122880 → 106706 rows
# Processing row group 60/262... ✅ 122880 → 106741 rows
# Processing row group 61/262... ✅ 122880 → 106399 rows
# Processing row group 62/262... ✅ 122880 → 106694 rows
# Processing row group 63/262... ✅ 122880 → 106854 rows
# Processing row group 64/262... ✅ 122880 → 106710 rows
# Processing row group 65/262... ✅ 122880 → 106754 rows
# Processing row group 66/262... ✅ 122880 → 106772 rows
# Processing row group 67/262... ✅ 122880 → 106693 rows
# Processing row group 68/262... ✅ 122880 → 106586 rows
# Processing row group 69/262... ✅ 122880 → 106602 rows
# Processing row group 70/262... ✅ 122880 → 106709 rows
# Processing row group 71/262... ✅ 122880 → 106860 rows
# Processing row group 72/262... ✅ 122880 → 106515 rows
# Processing row group 73/262... ✅ 122880 → 106608 rows
# Processing row group 74/262... ✅ 122880 → 106789 rows
# Processing row group 75/262... ✅ 122880 → 106620 rows
# Processing row group 76/262... ✅ 122880 → 106433 rows
# Processing row group 77/262... ✅ 122880 → 106730 rows
# Processing row group 78/262... ✅ 122880 → 106559 rows
# Processing row group 79/262... ✅ 122880 → 106735 rows
# Processing row group 80/262... ✅ 122880 → 106684 rows
# Processing row group 81/262... ✅ 122880 → 106883 rows
# Processing row group 82/262... ✅ 122880 → 106727 rows
# Processing row group 83/262... ✅ 122880 → 106674 rows
# Processing row group 84/262... ✅ 122880 → 106539 rows
# Processing row group 85/262... ✅ 122880 → 106835 rows
# Processing row group 86/262... ✅ 122880 → 106662 rows
# Processing row group 87/262... ✅ 122880 → 106653 rows
# Processing row group 88/262... ✅ 122880 → 106752 rows
# Processing row group 89/262... ✅ 122880 → 106550 rows
# Processing row group 90/262... ✅ 122880 → 106732 rows
# Processing row group 91/262... ✅ 122880 → 106591 rows
# Processing row group 92/262... ✅ 122880 → 106531 rows
# Processing row group 93/262... ✅ 122880 → 106729 rows
# Processing row group 94/262... ✅ 122880 → 106541 rows
# Processing row group 95/262... ✅ 122880 → 106607 rows
# Processing row group 96/262... ✅ 122880 → 106632 rows
# Processing row group 97/262... ✅ 122880 → 106577 rows
# Processing row group 98/262... ✅ 122880 → 106590 rows
# Processing row group 99/262... ✅ 122880 → 106665 rows
# Processing row group 100/262... ✅ 122880 → 106700 rows
# Processing row group 101/262... ✅ 122880 → 106711 rows
# Processing row group 102/262... ✅ 122880 → 106534 rows
# Processing row group 103/262... ✅ 122880 → 106502 rows
# Processing row group 104/262... ✅ 122880 → 106486 rows
# Processing row group 105/262... ✅ 122880 → 106583 rows
# Processing row group 106/262... ✅ 122880 → 106556 rows
# Processing row group 107/262... ✅ 122880 → 106591 rows
# Processing row group 108/262... ✅ 122880 → 106617 rows
# Processing row group 109/262... ✅ 122880 → 106815 rows
# Processing row group 110/262... ✅ 122880 → 106699 rows
# Processing row group 111/262... ✅ 122880 → 106477 rows
# Processing row group 112/262... ✅ 122880 → 106575 rows
# Processing row group 113/262... ✅ 122880 → 106544 rows
# Processing row group 114/262... ✅ 122880 → 106738 rows
# Processing row group 115/262... ✅ 122880 → 106589 rows
# Processing row group 116/262... ✅ 122880 → 106482 rows
# Processing row group 117/262... ✅ 122880 → 106741 rows
# Processing row group 118/262... ✅ 122880 → 106645 rows
# Processing row group 119/262... ✅ 122880 → 106820 rows
# Processing row group 120/262... ✅ 122880 → 106516 rows
# Processing row group 121/262... ✅ 122880 → 106560 rows
# Processing row group 122/262... ✅ 122880 → 106703 rows
# Processing row group 123/262... ✅ 122880 → 106702 rows
# Processing row group 124/262... ✅ 122880 → 106597 rows
# Processing row group 125/262... ✅ 122880 → 106684 rows
# Processing row group 126/262... ✅ 122880 → 106699 rows
# Processing row group 127/262... ✅ 122880 → 106694 rows
# Processing row group 128/262... ✅ 122880 → 106720 rows
# Processing row group 129/262... ✅ 122880 → 106654 rows
# Processing row group 130/262... ✅ 122880 → 106627 rows
# Processing row group 131/262... ✅ 122880 → 106467 rows
# Processing row group 132/262... ✅ 122880 → 106758 rows
# Processing row group 133/262... ✅ 122880 → 106569 rows
# Processing row group 134/262... ✅ 122880 → 106748 rows
# Processing row group 135/262... ✅ 122880 → 106828 rows
# Processing row group 136/262... ✅ 122880 → 106632 rows
# Processing row group 137/262... ✅ 122880 → 106764 rows
# Processing row group 138/262... ✅ 122880 → 106884 rows
# Processing row group 139/262... ✅ 122880 → 106659 rows
# Processing row group 140/262... ✅ 122880 → 106841 rows
# Processing row group 141/262... ✅ 122880 → 106600 rows
# Processing row group 142/262... ✅ 122880 → 106741 rows
# Processing row group 143/262... ✅ 122880 → 106598 rows
# Processing row group 144/262... ✅ 122880 → 106497 rows
# Processing row group 145/262... ✅ 122880 → 106694 rows
# Processing row group 146/262... ✅ 122880 → 106582 rows
# Processing row group 147/262... ✅ 122880 → 106672 rows
# Processing row group 148/262... ✅ 122880 → 106788 rows
# Processing row group 149/262... ✅ 122880 → 106908 rows
# Processing row group 150/262... ✅ 122880 → 106672 rows
# Processing row group 151/262... ✅ 122880 → 106665 rows
# Processing row group 152/262... ✅ 122880 → 106502 rows
# Processing row group 153/262... ✅ 122880 → 106661 rows
# Processing row group 154/262... ✅ 122880 → 106660 rows
# Processing row group 155/262... ✅ 122880 → 106552 rows
# Processing row group 156/262... ✅ 122880 → 106732 rows
# Processing row group 157/262... ✅ 122880 → 106678 rows
# Processing row group 158/262... ✅ 122880 → 106622 rows
# Processing row group 159/262... ✅ 122880 → 106653 rows
# Processing row group 160/262... ✅ 122880 → 106542 rows
# Processing row group 161/262... ✅ 122880 → 106725 rows
# Processing row group 162/262... ✅ 122880 → 106831 rows
# Processing row group 163/262... ✅ 122880 → 106631 rows
# Processing row group 164/262... ✅ 122880 → 106796 rows
# Processing row group 165/262... ✅ 122880 → 106696 rows
# Processing row group 166/262... ✅ 122880 → 106628 rows
# Processing row group 167/262... ✅ 122880 → 106582 rows
# Processing row group 168/262... ✅ 122880 → 106738 rows
# Processing row group 169/262... ✅ 122880 → 106611 rows
# Processing row group 170/262... ✅ 122880 → 106685 rows
# Processing row group 171/262... ✅ 122880 → 106678 rows
# Processing row group 172/262... ✅ 122880 → 106354 rows
# Processing row group 173/262... ✅ 122880 → 106903 rows
# Processing row group 174/262... ✅ 122880 → 106530 rows
# Processing row group 175/262... ✅ 122880 → 106536 rows
# Processing row group 176/262... ✅ 122880 → 106580 rows
# Processing row group 177/262... ✅ 122880 → 106860 rows
# Processing row group 178/262... ✅ 122880 → 106802 rows
# Processing row group 179/262... ✅ 122880 → 106802 rows
# Processing row group 180/262... ✅ 122880 → 106851 rows
# Processing row group 181/262... ✅ 122880 → 106815 rows
# Processing row group 182/262... ✅ 122880 → 106751 rows
# Processing row group 183/262... ✅ 122880 → 106803 rows
# Processing row group 184/262... ✅ 122880 → 106554 rows
# Processing row group 185/262... ✅ 122880 → 106678 rows
# Processing row group 186/262... ✅ 122880 → 106500 rows
# Processing row group 187/262... ✅ 122880 → 106652 rows
# Processing row group 188/262... ✅ 122880 → 106669 rows
# Processing row group 189/262... ✅ 122880 → 106789 rows
# Processing row group 190/262... ✅ 122880 → 106554 rows
# Processing row group 191/262... ✅ 122880 → 106801 rows
# Processing row group 192/262... ✅ 122880 → 106694 rows
# Processing row group 193/262... ✅ 122880 → 106398 rows
# Processing row group 194/262... ✅ 122880 → 106659 rows
# Processing row group 195/262... ✅ 122880 → 106690 rows
# Processing row group 196/262... ✅ 122880 → 106744 rows
# Processing row group 197/262... ✅ 122880 → 106605 rows
# Processing row group 198/262... ✅ 122880 → 106580 rows
# Processing row group 199/262... ✅ 122880 → 106761 rows
# Processing row group 200/262... ✅ 122880 → 106572 rows
# Processing row group 201/262... ✅ 122880 → 106861 rows
# Processing row group 202/262... ✅ 122880 → 106492 rows
# Processing row group 203/262... ✅ 122880 → 106630 rows
# Processing row group 204/262... ✅ 122880 → 106552 rows
# Processing row group 205/262... ✅ 122880 → 106455 rows
# Processing row group 206/262... ✅ 122880 → 106583 rows
# Processing row group 207/262... ✅ 122880 → 106755 rows
# Processing row group 208/262... ✅ 122880 → 106648 rows
# Processing row group 209/262... ✅ 122880 → 106875 rows
# Processing row group 210/262... ✅ 122880 → 106795 rows
# Processing row group 211/262... ✅ 122880 → 106519 rows
# Processing row group 212/262... ✅ 122880 → 106596 rows
# Processing row group 213/262... ✅ 122880 → 106693 rows
# Processing row group 214/262... ✅ 122880 → 106809 rows
# Processing row group 215/262... ✅ 122880 → 106737 rows
# Processing row group 216/262... ✅ 122880 → 106630 rows
# Processing row group 217/262... ✅ 122880 → 106604 rows
# Processing row group 218/262... ✅ 122880 → 106452 rows
# Processing row group 219/262... ✅ 122880 → 106638 rows
# Processing row group 220/262... ✅ 122880 → 106602 rows
# Processing row group 221/262... ✅ 122880 → 106873 rows
# Processing row group 222/262... ✅ 122880 → 106446 rows
# Processing row group 223/262... ✅ 122880 → 106727 rows
# Processing row group 224/262... ✅ 122880 → 106426 rows
# Processing row group 225/262... ✅ 122880 → 106398 rows
# Processing row group 226/262... ✅ 122880 → 106549 rows
# Processing row group 227/262... ✅ 122880 → 106707 rows
# Processing row group 228/262... ✅ 122880 → 106790 rows
# Processing row group 229/262... ✅ 122880 → 106537 rows
# Processing row group 230/262... ✅ 122880 → 106513 rows
# Processing row group 231/262... ✅ 122880 → 106770 rows
# Processing row group 232/262... ✅ 122880 → 106638 rows
# Processing row group 233/262... ✅ 122880 → 106806 rows
# Processing row group 234/262... ✅ 122880 → 106744 rows
# Processing row group 235/262... ✅ 122880 → 106699 rows
# Processing row group 236/262... ✅ 122880 → 106732 rows
# Processing row group 237/262... ✅ 122880 → 106548 rows
# Processing row group 238/262... ✅ 122880 → 106494 rows
# Processing row group 239/262... ✅ 122880 → 106597 rows
# Processing row group 240/262... ✅ 122880 → 106693 rows
# Processing row group 241/262... ✅ 122880 → 106708 rows
# Processing row group 242/262... ✅ 122880 → 106551 rows
# Processing row group 243/262... ✅ 122880 → 106481 rows
# Processing row group 244/262... ✅ 122880 → 106620 rows
# Processing row group 245/262... ✅ 122880 → 106586 rows
# Processing row group 246/262... ✅ 122880 → 106516 rows
# Processing row group 247/262... ✅ 122880 → 106781 rows
# Processing row group 248/262... ✅ 122880 → 106695 rows
# Processing row group 249/262... ✅ 122880 → 106687 rows
# Processing row group 250/262... ✅ 122880 → 106582 rows
# Processing row group 251/262... ✅ 122880 → 106484 rows
# Processing row group 252/262... ✅ 122880 → 106578 rows
# Processing row group 253/262... ✅ 122880 → 106620 rows
# Processing row group 254/262... ✅ 122880 → 106617 rows
# Processing row group 255/262... ✅ 122880 → 106932 rows
# Processing row group 256/262... ✅ 122880 → 106685 rows
# Processing row group 257/262... ✅ 122880 → 106637 rows
# Processing row group 258/262... ✅ 122880 → 106648 rows
# Processing row group 259/262... ✅ 122880 → 106797 rows
# Processing row group 260/262... ✅ 122880 → 106472 rows
# Processing row group 261/262... ✅ 122880 → 106671 rows
# Processing row group 262/262... ✅ 98619 → 85406 rows
#
# ============================================================
# ROW GROUP CLEANING SUMMARY:
# ============================================================
# Row groups: 262 processed
# Rows:       32,170,299 → 27,922,673 (86.8% kept)
# File size:  1.77 GB → 0.31 GB
# Reduction:  1.46 GB (82.4%)
# Columns:    9 → 3
# ============================================================
# {'original_rows': 32170299,
#  'final_rows': 27922673,
#  'original_size': 1902151733,
#  'final_size': 335482708,
#  'row_groups_processed': 262}
