# %%
# Imports and setup
import fsspec
import pyarrow.parquet as pq
import pyarrow as pa
import pyarrow.compute as pc

import os
import time
from datetime import datetime

print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!

# %% [markdown]
# # Remote Schema Exploration

# %%
URLS = {
    "Blocks": "https://bsky-data.leobalduf.com/blocks.parquet",
    "Follows": "https://bsky-data.leobalduf.com/follows.parquet",
    "Likes": "https://bsky-data.leobalduf.com/likes.parquet",
    "Posts": "https://bsky-data.leobalduf.com/posts.parquet",
    "Profiles": "https://bsky-data.leobalduf.com/profiles.parquet"
}

# %%
for name, url in URLS.items():
    with fsspec.open(url, "rb") as f:
        parquet_file = pq.ParquetFile(f)
        print(f"{name} Database")
        print("Columns:", parquet_file.schema.names)
        print("Number of rows:", parquet_file.metadata.num_rows)
        print("Number of row groups:", parquet_file.metadata.num_row_groups)
# Out:
# Blocks Database
# Columns: ['did_id', 'rkey', 'created_at', 'subject_id']
# Number of rows: 120088510
# Number of row groups: 978
# Follows Database
# Columns: ['did_id', 'rkey', 'created_at', 'subject_id']
# Number of rows: 2156778700
# Number of row groups: 17551
# Likes Database
# Columns: ['did_id', 'rkey', 'created_at', 'did_id', 'collection', 'rkey']
# Number of rows: 6938743344
# Number of row groups: 56461
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
def get_column_metadata(URL, column_names=None, detailed=False):
    
    with fsspec.open(URL, "rb") as f:
        parquet_file = pq.ParquetFile(f)
        metadata = parquet_file.metadata
        schema = parquet_file.schema_arrow
        
        # Handle column selection
        if column_names is None:
            column_names = schema.names
        elif isinstance(column_names, str):
            column_names = [column_names]
        
        # Validate columns exist
        valid_columns = []
        for col_name in column_names:
            if col_name in schema.names:
                valid_columns.append(col_name)
            else:
                print(f"Warning: Column '{col_name}' not found in schema. Available columns: {schema.names}")
        
        if not valid_columns:
            print("No valid columns to analyze")
            return
        
        mode = "DETAILED" if detailed else "OVERVIEW"
        print(f"=== {mode} FOR {len(valid_columns)} COLUMN(S) ===")
        
        # Process each column
        for column_name in valid_columns:
            col_idx = schema.names.index(column_name)
            col_type = schema.field(column_name).type
            
            if detailed:
                print(f"\n{'='*50}")
                print(f"DETAILED METADATA FOR '{column_name}'")
                print(f"{'='*50}")
            else:
                print(f"\n{column_name}: {col_type}")
            
            # Initialize aggregators
            total_nulls = 0
            total_values = 0
            has_min_max = False
            global_min = None
            global_max = None
            has_distinct_count = False
            distinct_count = None
            
            # Aggregate across all row groups
            for rg_idx in range(metadata.num_row_groups):
                rg_metadata = metadata.row_group(rg_idx)
                col_metadata = rg_metadata.column(col_idx)
                rg_num_rows = rg_metadata.num_rows
                
                if col_metadata.statistics:
                    stats = col_metadata.statistics
                    
                    # Aggregate null count
                    if stats.has_null_count:
                        total_nulls += stats.null_count
                    
                    # Aggregate min/max values
                    if stats.has_min_max:
                        has_min_max = True
                        try:
                            current_min = stats.min
                            current_max = stats.max
                            
                            # Handle different data types for comparison
                            if pa.types.is_timestamp(col_type):
                                current_min = pa.scalar(current_min).cast(col_type).as_py()
                                current_max = pa.scalar(current_max).cast(col_type).as_py()
                            
                            # Update global min/max
                            if global_min is None or current_min < global_min:
                                global_min = current_min
                            if global_max is None or current_max > global_max:
                                global_max = current_max
                                
                        except (OverflowError, Exception):
                            # If we can't compare, just take the first available values
                            if global_min is None:
                                global_min = stats.min
                                global_max = stats.max
                    
                    # Handle distinct count (take max across row groups as approximation)
                    if stats.has_distinct_count:
                        has_distinct_count = True
                        if distinct_count is None or stats.distinct_count > distinct_count:
                            distinct_count = stats.distinct_count
                
                total_values += rg_num_rows
            
            # Calculate percentages
            null_percentage = (total_nulls / total_values) * 100 if total_values > 0 else 0
            non_null_count = total_values - total_nulls
            
            # Display results based on detail level
            if detailed:
                print(f"Data type: {col_type}")
                print(f"Total rows: {total_values:,}")
                print(f"Null count: {total_nulls:,} ({null_percentage:.2f}%)")
                print(f"Non-null count: {non_null_count:,}")
                
                if has_min_max:
                    print(f"\nValue Range:")
                    try:
                        if pa.types.is_timestamp(col_type):
                            print(f"  Min: {global_min}")
                            print(f"  Max: {global_max}")
                        elif pa.types.is_string(col_type) or pa.types.is_large_string(col_type):
                            min_str = str(global_min)
                            max_str = str(global_max)
                            if len(min_str) > 50:
                                min_str = min_str[:47] + "..."
                            if len(max_str) > 50:
                                max_str = max_str[:47] + "..."
                            print(f"  Min: {min_str}")
                            print(f"  Max: {max_str}")
                        else:
                            print(f"  Min: {global_min}")
                            print(f"  Max: {global_max}")
                    except Exception as e:
                        print(f"  Min: <error displaying: {e}>")
                        print(f"  Max: <error displaying: {e}>")
                else:
                    print(f"\nValue Range: No min/max statistics available")
                
                if has_distinct_count:
                    print(f"Distinct values: {distinct_count:,}")
                else:
                    print(f"Distinct values: No distinct count statistics available")
                    
            else:
                # Quick overview mode
                print(f"  Total rows: {total_values:,}")
                print(f"  Null count: {total_nulls:,} ({null_percentage:.1f}%)")
                print(f"  Non-null: {non_null_count:,}")
                
                if has_min_max:
                    try:
                        if pa.types.is_timestamp(col_type):
                            print(f"  Value range: {global_min} to {global_max}")
                        elif pa.types.is_string(col_type) or pa.types.is_large_string(col_type):
                            min_str = str(global_min)[:20] + "..." if len(str(global_min)) > 20 else str(global_min)
                            max_str = str(global_max)[:20] + "..." if len(str(global_max)) > 20 else str(global_max)
                            print(f"  Value range: '{min_str}' to '{max_str}'")
                        else:
                            print(f"  Value range: {global_min} to {global_max}")
                    except Exception:
                        print(f"  Value range: Available (display error)")
                else:
                    print(f"  Value range: No statistics available")

# %%
get_column_metadata(URLS["Posts"], ["labels", "languages"], detailed=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 get_column_metadata(URLS["Posts"], ["labels", "languages"], detailed=True)
#
# NameError: name 'get_column_metadata' is not defined

# %%
get_column_metadata(URLS["Blocks"], ["subject_id"], detailed=True)
# Out:
# === DETAILED FOR 1 COLUMN(S) ===
#
# ==================================================
# DETAILED METADATA FOR 'subject_id'
# ==================================================
# Data type: int64
# Total rows: 120,088,510
# Null count: 0 (0.00%)
# Non-null count: 120,088,510
#
# Value Range:
#   Min: 3
#   Max: 34251851
# Distinct values: No distinct count statistics available

# %% [markdown]
# # Cleaning

# %%
MAX_DATE = '2025-05-14'
MIN_DATE = '2024-01-01'
# Define cleaning rules per databas Follows.
# NOTE: If the columns in the dictionary aren't sorted, my Kernel crashes ahaha. 
CLEANING_RULES = {
    'blocks': {
        'did_id': {
            'remove_null': True,
        },
        'created_at': {
            'remove_null': True,
            'max_date': MAX_DATE, 
            'min_date': MIN_DATE   # Filter out very old dates
        },
        'subject_id': {
            'remove_null': True,
        },
    },
    'follows': {
        'did_id': {
            'remove_null': True,
        },
        'created_at': {
            'remove_null': True,
            'max_date': MAX_DATE, 
            'min_date': MIN_DATE   # Filter out very old dates
        },
        'subject_id': {
            'remove_null': True,
        },
    },
    # Huge dataset
    'likes': {
    }, 
    'posts': {
        'did_id': {
            'remove_null': True,
            'remove_empty_strings': True
        },
        'created_at': {
            'remove_null': True,
            'max_date': MAX_DATE, 
            'min_date': MIN_DATE   # Filter out very old dates
        },
    },
    'profiles': {
        'did_id': {
            'remove_null': True,
            'remove_empty_strings': True
        },
        'created_at': {
            'remove_null': True,
            'max_date': MAX_DATE, 
            'min_date':  '2021-01-01' # It would be interesting when someone joined
        },
    },
}

# %%
def clean_table_with_rules(table, rules, table_type='default'):

    current_table = table
    applied_rules = []
    
    rule_set = rules.get(table_type, {})
    
    for column_name, column_rules in rule_set.items():
        if column_name not in current_table.column_names:
            continue
            
        temp_table = current_table
        
        if column_rules.get('remove_null'):
            mask = pc.is_valid(temp_table[column_name])
            temp_table = temp_table.filter(mask)
            applied_rules.append(f"removed_null_{column_name}")
            if temp_table.num_rows == 0:
                break  # No rows left, stop processing
        
        # Remove empty strings (May be expensive)
        if column_rules.get('remove_empty_strings') and pa.types.is_string(temp_table[column_name].type):
            mask = pc.not_equal(temp_table[column_name], "")
            temp_table = temp_table.filter(mask)
            applied_rules.append(f"removed_empty_{column_name}")
            if temp_table.num_rows == 0:
                break
        
        if column_rules.get('max_date') and pa.types.is_timestamp(temp_table[column_name].type):
            max_date = datetime.strptime(column_rules['max_date'], '%Y-%m-%d')
            max_date_scalar = pa.scalar(max_date, type=temp_table[column_name].type)
            mask = pc.less_equal(temp_table[column_name], max_date_scalar)
            temp_table = temp_table.filter(mask)
            applied_rules.append(f"max_date_{column_name}")
            if temp_table.num_rows == 0:
                break
            
        if column_rules.get('min_date') and pa.types.is_timestamp(temp_table[column_name].type):
            min_date = datetime.strptime(column_rules['min_date'], '%Y-%m-%d')
            min_date_scalar = pa.scalar(min_date, type=temp_table[column_name].type)
            mask = pc.greater_equal(temp_table[column_name], min_date_scalar)
            temp_table = temp_table.filter(mask)
            applied_rules.append(f"min_date_{column_name}")
            if temp_table.num_rows == 0:
                break
        
        current_table = temp_table
    
    return current_table, applied_rules, []

# %%
def clean_parquet_by_row_groups(input_path, output_path, rules, table_type='default'):
    """Clean Parquet file by processing row groups - most efficient approach"""
    
    print(f"Cleaning by row groups...")
    original_size = os.path.getsize(input_path)
    print(f"Input file: {original_size / (1024**3):.2f} GB")
    
    # Open Parquet file
    pf = pq.ParquetFile(input_path)
    
    # Determine which columns to read based on cleaning rules
    available_columns = set(pf.schema_arrow.names)
    rule_columns = set(rules.get(table_type, {}).keys())
    columns_to_read = list(rule_columns.intersection(available_columns))
    
    missing_columns = rule_columns - available_columns
    if missing_columns:
        print(f"Warning: Columns not found: {missing_columns}")
    
    print(f"Processing {len(columns_to_read)} columns: {columns_to_read}")
    print(f"Processing {pf.num_row_groups} row groups...")
    
    # Set up Parquet writer
    writer = None
    total_rows_processed = 0
    total_rows_kept = 0
    applied_rules = None
    
    # Process each row group
    for i in range(pf.num_row_groups):
        print(f"Processing row group {i+1}/{pf.num_row_groups}...", end=" ")
        
        # Read only the columns we need from this row group
        row_group_table = pf.read_row_group(i, columns=columns_to_read)
        total_rows_processed += row_group_table.num_rows
        
        # Apply cleaning rules
        cleaned_table, current_applied_rules, removal_log = clean_table_with_rules(
            row_group_table, rules, table_type
        )
        
        total_rows_kept += cleaned_table.num_rows
        
        # Store applied rules from first row group
        if applied_rules is None:
            applied_rules = current_applied_rules
            print(f"Applied rules: {applied_rules}")
        
        # Initialize writer with first cleaned table schema
        if writer is None:
            writer = pq.ParquetWriter(
                output_path,
                cleaned_table.schema,
                compression='zstd',
                use_dictionary=True,
                write_statistics=True
            )
        
        # Write cleaned row group
        if cleaned_table.num_rows > 0:
            writer.write_table(cleaned_table)
            print(f"✅ {row_group_table.num_rows} → {cleaned_table.num_rows} rows")
        else:
            print(f"❌ entire row group removed")
    
    if writer:
        writer.close()
    
    # Calculate and print summary
    final_size = os.path.getsize(output_path)
    size_reduction = original_size - final_size
    size_reduction_percent = (size_reduction / original_size * 100) if original_size > 0 else 0
    retention_rate = (total_rows_kept / total_rows_processed * 100) if total_rows_processed > 0 else 0
    
    print("\n" + "="*60)
    print("ROW GROUP CLEANING SUMMARY:")
    print("="*60)
    print(f"Row groups: {pf.num_row_groups} processed")
    print(f"Rows:       {total_rows_processed:,} → {total_rows_kept:,} ({retention_rate:.1f}% kept)")
    print(f"File size:  {original_size / (1024**3):.2f} GB → {final_size / (1024**3):.2f} GB")
    print(f"Reduction:  {size_reduction / (1024**3):.2f} GB ({size_reduction_percent:.1f}%)")
    print(f"Columns:    {len(pf.schema_arrow.names)} → {len(columns_to_read)}")
    print("="*60)
    
    return {
        'original_rows': total_rows_processed,
        'final_rows': total_rows_kept,
        'original_size': original_size,
        'final_size': final_size,
        'row_groups_processed': pf.num_row_groups
    }

# %%
import concurrent.futures

def clean_parquet_parallel(input_path, output_path, rules, table_type='default', max_workers=4):
    """Clean Parquet file by processing row groups in parallel"""
    
    print(f"Cleaning in parallel with {max_workers} workers...")
    
    pf = pq.ParquetFile(input_path)
    available_columns = set(pf.schema_arrow.names)
    rule_columns = set(rules.get(table_type, {}).keys())
    columns_to_read = list(rule_columns.intersection(available_columns))
    
    print(f"Processing {len(columns_to_read)} columns across {pf.num_row_groups} row groups")
    
    # Process first row group to get schema
    first_rg = pf.read_row_group(0, columns=columns_to_read)
    first_cleaned, applied_rules, _ = clean_table_with_rules(first_rg, rules, table_type)
    
    print(f"Applied rules: {applied_rules}")
    
    # Set up writer
    writer = pq.ParquetWriter(
        output_path,
        first_cleaned.schema,
        compression='zstd',
        use_dictionary=True,
        write_statistics=True
    )
    writer.write_table(first_cleaned)
    
    total_rows_processed = first_rg.num_rows
    total_rows_kept = first_cleaned.num_rows
    
    # Process remaining row groups in parallel
    def process_row_group(rg_index):
        rg_table = pf.read_row_group(rg_index, columns=columns_to_read)
        cleaned_table, _, _ = clean_table_with_rules(rg_table, rules, table_type)
        return cleaned_table, rg_table.num_rows, cleaned_table.num_rows
    
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Skip first row group (already processed)
        future_to_rg = {
            executor.submit(process_row_group, i): i 
            for i in range(1, pf.num_row_groups)
        }
        
        for future in concurrent.futures.as_completed(future_to_rg):
            rg_index = future_to_rg[future]
            try:
                cleaned_table, original_rows, kept_rows = future.result()
                total_rows_processed += original_rows
                total_rows_kept += kept_rows
                
                if cleaned_table.num_rows > 0:
                    writer.write_table(cleaned_table)
                
                print(f"Row group {rg_index}: {original_rows} → {kept_rows} rows")
                
            except Exception as e:
                print(f"Row group {rg_index} failed: {e}")
    
    writer.close()
    
    # Print summary
    original_size = os.path.getsize(input_path)
    final_size = os.path.getsize(output_path)
    
    print(f"\nParallel processing complete: {total_rows_processed:,} → {total_rows_kept:,} rows")
    print(f"File size: {original_size / (1024**3):.2f} GB → {final_size / (1024**3):.2f} GB")

# %% [markdown]
# ## Blocks

# %%
i_file = "/home/ale/Documents/uni/mp/data/raw/blocks.parquet"
o_file = "/home/ale/Documents/uni/mp/data/cleaned/blocks.parquet"
clean_parquet_by_row_groups(i_file, o_file, CLEANING_RULES, table_type="blocks")
# Out:
# Cleaning by row groups...
# Input file: 1.49 GB
# Processing 3 columns: ['subject_id', 'created_at', 'did_id']
# Processing 978 row groups...
# Processing row group 1/978... Applied rules: ['removed_null_did_id', 'removed_null_created_at', 'max_date_created_at', 'min_date_created_at', 'removed_null_subject_id']
# ✅ 122880 → 117903 rows
# Processing row group 2/978... ✅ 122880 → 116946 rows
# Processing row group 3/978... ✅ 122880 → 118206 rows
# Processing row group 4/978... ✅ 122880 → 117561 rows
# Processing row group 5/978... ✅ 122880 → 118129 rows
# Processing row group 6/978... ✅ 122880 → 119673 rows
# Processing row group 7/978... ✅ 122880 → 120205 rows
# Processing row group 8/978... ✅ 122880 → 120107 rows
# Processing row group 9/978... ✅ 122880 → 118116 rows
# Processing row group 10/978... ✅ 122880 → 120205 rows
# Processing row group 11/978... ✅ 122880 → 116454 rows
# Processing row group 12/978... ✅ 122880 → 118940 rows
# Processing row group 13/978... ✅ 122880 → 119115 rows
# Processing row group 14/978... ✅ 122880 → 118306 rows
# Processing row group 15/978... ✅ 122880 → 118139 rows
# Processing row group 16/978... ✅ 122880 → 118808 rows
# Processing row group 17/978... ✅ 122880 → 118485 rows
# Processing row group 18/978... ✅ 123380 → 120666 rows
# Processing row group 19/978... ✅ 122880 → 118230 rows
# Processing row group 20/978... ✅ 122880 → 118677 rows
# Processing row group 21/978... ✅ 122880 → 117315 rows
# Processing row group 22/978... ✅ 122880 → 119131 rows
# Processing row group 23/978... ✅ 122880 → 115538 rows
# Processing row group 24/978... ✅ 122880 → 117281 rows
# Processing row group 25/978... ✅ 122880 → 117868 rows
# Processing row group 26/978... ✅ 122880 → 118286 rows
# Processing row group 27/978... ✅ 122880 → 119142 rows
# Processing row group 28/978... ✅ 122880 → 118365 rows
# Processing row group 29/978... ✅ 122880 → 119137 rows
# Processing row group 30/978... ✅ 122880 → 115944 rows
# Processing row group 31/978... ✅ 122880 → 116689 rows
# Processing row group 32/978... ✅ 122880 → 120451 rows
# Processing row group 33/978... ✅ 122880 → 119782 rows
# Processing row group 34/978... ✅ 122880 → 119003 rows
# Processing row group 35/978... ✅ 123380 → 119671 rows
# Processing row group 36/978... ✅ 122880 → 118573 rows
# Processing row group 37/978... ✅ 122880 → 118258 rows
# Processing row group 38/978... ✅ 122880 → 116836 rows
# Processing row group 39/978... ✅ 122880 → 117961 rows
# Processing row group 40/978... ✅ 122880 → 118581 rows
# Processing row group 41/978... ✅ 122880 → 119081 rows
# Processing row group 42/978... ✅ 122880 → 117121 rows
# Processing row group 43/978... ✅ 122880 → 117952 rows
# Processing row group 44/978... ✅ 122880 → 119920 rows
# Processing row group 45/978... ✅ 122880 → 118541 rows
# Processing row group 46/978... ✅ 122880 → 117881 rows
# Processing row group 47/978... ✅ 122880 → 118439 rows
# Processing row group 48/978... ✅ 122880 → 117162 rows
# Processing row group 49/978... ✅ 122880 → 119536 rows
# Processing row group 50/978... ✅ 122880 → 118669 rows
# Processing row group 51/978... ✅ 122880 → 118410 rows
# Processing row group 52/978... ✅ 123380 → 119207 rows
# Processing row group 53/978... ✅ 122880 → 118446 rows
# Processing row group 54/978... ✅ 122880 → 117715 rows
# Processing row group 55/978... ✅ 122880 → 117892 rows
# Processing row group 56/978... ✅ 122880 → 118684 rows
# Processing row group 57/978... ✅ 122880 → 118743 rows
# Processing row group 58/978... ✅ 122880 → 118427 rows
# Processing row group 59/978... ✅ 122880 → 115876 rows
# Processing row group 60/978... ✅ 122880 → 118691 rows
# Processing row group 61/978... ✅ 122880 → 119302 rows
# Processing row group 62/978... ✅ 122880 → 117711 rows
# Processing row group 63/978... ✅ 122880 → 112810 rows
# Processing row group 64/978... ✅ 122880 → 121215 rows
# Processing row group 65/978... ✅ 122880 → 118553 rows
# Processing row group 66/978... ✅ 122880 → 119045 rows
# Processing row group 67/978... ✅ 122880 → 114655 rows
# Processing row group 68/978... ✅ 122880 → 117565 rows
# Processing row group 69/978... ✅ 123380 → 117175 rows
# Processing row group 70/978... ✅ 122880 → 117113 rows
# Processing row group 71/978... ✅ 122880 → 119020 rows
# Processing row group 72/978... ✅ 122880 → 117457 rows
# Processing row group 73/978... ✅ 122880 → 117556 rows
# Processing row group 74/978... ✅ 122880 → 118929 rows
# Processing row group 75/978... ✅ 122880 → 116538 rows
# Processing row group 76/978... ✅ 122880 → 118726 rows
# Processing row group 77/978... ✅ 122880 → 119049 rows
# Processing row group 78/978... ✅ 122880 → 119057 rows
# Processing row group 79/978... ✅ 122880 → 117024 rows
# Processing row group 80/978... ✅ 122880 → 120009 rows
# Processing row group 81/978... ✅ 122880 → 115445 rows
# Processing row group 82/978... ✅ 122880 → 116338 rows
# Processing row group 83/978... ✅ 122880 → 119321 rows
# Processing row group 84/978... ✅ 122880 → 114654 rows
# Processing row group 85/978... ✅ 122880 → 116992 rows
# Processing row group 86/978... ✅ 123380 → 117648 rows
# Processing row group 87/978... ✅ 122880 → 117804 rows
# Processing row group 88/978... ✅ 122880 → 117562 rows
# Processing row group 89/978... ✅ 122880 → 119971 rows
# Processing row group 90/978... ✅ 122880 → 117379 rows
# Processing row group 91/978... ✅ 122880 → 119230 rows
# Processing row group 92/978... ✅ 122880 → 116904 rows
# Processing row group 93/978... ✅ 122880 → 119107 rows
# Processing row group 94/978... ✅ 122880 → 118799 rows
# Processing row group 95/978... ✅ 122880 → 117966 rows
# Processing row group 96/978... ✅ 122880 → 121685 rows
# Processing row group 97/978... ✅ 122880 → 122880 rows
# Processing row group 98/978... ✅ 122880 → 122880 rows
# Processing row group 99/978... ✅ 122880 → 120841 rows
# Processing row group 100/978... ✅ 122880 → 119390 rows
# Processing row group 101/978... ✅ 122880 → 119001 rows
# Processing row group 102/978... ✅ 122880 → 117932 rows
# Processing row group 103/978... ✅ 123380 → 118388 rows
# Processing row group 104/978... ✅ 122880 → 119874 rows
# Processing row group 105/978... ✅ 122880 → 122880 rows
# Processing row group 106/978... ✅ 122880 → 120066 rows
# Processing row group 107/978... ✅ 122880 → 117059 rows
# Processing row group 108/978... ✅ 122880 → 115801 rows
# Processing row group 109/978... ✅ 122880 → 119448 rows
# Processing row group 110/978... ✅ 122880 → 119322 rows
# Processing row group 111/978... ✅ 122880 → 115481 rows
# Processing row group 112/978... ✅ 122880 → 118924 rows
# Processing row group 113/978... ✅ 122880 → 119395 rows
# Processing row group 114/978... ✅ 122880 → 118055 rows
# Processing row group 115/978... ✅ 122880 → 118191 rows
# Processing row group 116/978... ✅ 122880 → 116701 rows
# Processing row group 117/978... ✅ 122880 → 119165 rows
# Processing row group 118/978... ✅ 122880 → 121079 rows
# Processing row group 119/978... ✅ 122880 → 117950 rows
# Processing row group 120/978... ✅ 123380 → 119802 rows
# Processing row group 121/978... ✅ 122880 → 118678 rows
# Processing row group 122/978... ✅ 122880 → 118039 rows
# Processing row group 123/978... ✅ 122880 → 118087 rows
# Processing row group 124/978... ✅ 122880 → 117916 rows
# Processing row group 125/978... ✅ 122880 → 118240 rows
# Processing row group 126/978... ✅ 122880 → 121242 rows
# Processing row group 127/978... ✅ 122880 → 122880 rows
# Processing row group 128/978... ✅ 122880 → 122880 rows
# Processing row group 129/978... ✅ 122880 → 122880 rows
# Processing row group 130/978... ✅ 122880 → 122880 rows
# Processing row group 131/978... ✅ 122880 → 122880 rows
# Processing row group 132/978... ✅ 122880 → 122880 rows
# Processing row group 133/978... ✅ 122880 → 122880 rows
# Processing row group 134/978... ✅ 122880 → 119273 rows
# Processing row group 135/978... ✅ 122880 → 118295 rows
# Processing row group 136/978... ✅ 122880 → 118714 rows
# Processing row group 137/978... ✅ 123380 → 118727 rows
# Processing row group 138/978... ✅ 122880 → 116324 rows
# Processing row group 139/978... ✅ 122880 → 119703 rows
# Processing row group 140/978... ✅ 122880 → 112925 rows
# Processing row group 141/978... ✅ 122880 → 117816 rows
# Processing row group 142/978... ✅ 122880 → 118648 rows
# Processing row group 143/978... ✅ 122880 → 116365 rows
# Processing row group 144/978... ✅ 122880 → 118183 rows
# Processing row group 145/978... ✅ 122880 → 112876 rows
# Processing row group 146/978... ✅ 122880 → 122212 rows
# Processing row group 147/978... ✅ 122880 → 121676 rows
# Processing row group 148/978... ✅ 122880 → 118197 rows
# Processing row group 149/978... ✅ 122880 → 119360 rows
# Processing row group 150/978... ✅ 122880 → 117621 rows
# Processing row group 151/978... ✅ 122880 → 116014 rows
# Processing row group 152/978... ✅ 122880 → 113522 rows
# Processing row group 153/978... ✅ 122880 → 120160 rows
# Processing row group 154/978... ✅ 123380 → 117213 rows
# Processing row group 155/978... ✅ 122880 → 119338 rows
# Processing row group 156/978... ✅ 122880 → 119616 rows
# Processing row group 157/978... ✅ 122880 → 117060 rows
# Processing row group 158/978... ✅ 122880 → 118737 rows
# Processing row group 159/978... ✅ 122880 → 119516 rows
# Processing row group 160/978... ✅ 122880 → 119183 rows
# Processing row group 161/978... ✅ 122880 → 118821 rows
# Processing row group 162/978... ✅ 122880 → 118527 rows
# Processing row group 163/978... ✅ 122880 → 118326 rows
# Processing row group 164/978... ✅ 122880 → 116504 rows
# Processing row group 165/978... ✅ 122880 → 115839 rows
# Processing row group 166/978... ✅ 122880 → 118303 rows
# Processing row group 167/978... ✅ 122880 → 120761 rows
# Processing row group 168/978... ✅ 122880 → 115746 rows
# Processing row group 169/978... ✅ 122880 → 118631 rows
# Processing row group 170/978... ✅ 122880 → 118112 rows
# Processing row group 171/978... ✅ 123380 → 119677 rows
# Processing row group 172/978... ✅ 122880 → 117949 rows
# Processing row group 173/978... ✅ 122880 → 118322 rows
# Processing row group 174/978... ✅ 122880 → 119911 rows
# Processing row group 175/978... ✅ 122880 → 118380 rows
# Processing row group 176/978... ✅ 122880 → 118972 rows
# Processing row group 177/978... ✅ 122880 → 118561 rows
# Processing row group 178/978... ✅ 122880 → 118006 rows
# Processing row group 179/978... ✅ 122880 → 115189 rows
# Processing row group 180/978... ✅ 122880 → 119355 rows
# Processing row group 181/978... ✅ 122880 → 118799 rows
# Processing row group 182/978... ✅ 122880 → 111444 rows
# Processing row group 183/978... ✅ 122880 → 118866 rows
# Processing row group 184/978... ✅ 122880 → 118980 rows
# Processing row group 185/978... ✅ 122880 → 120078 rows
# Processing row group 186/978... ✅ 122880 → 119186 rows
# Processing row group 187/978... ✅ 122880 → 110850 rows
# Processing row group 188/978... ✅ 123380 → 118929 rows
# Processing row group 189/978... ✅ 122880 → 113360 rows
# Processing row group 190/978... ✅ 122880 → 117661 rows
# Processing row group 191/978... ✅ 122880 → 119569 rows
# Processing row group 192/978... ✅ 122880 → 117354 rows
# Processing row group 193/978... ✅ 122880 → 116763 rows
# Processing row group 194/978... ✅ 122880 → 118473 rows
# Processing row group 195/978... ✅ 122880 → 114319 rows
# Processing row group 196/978... ✅ 122880 → 118943 rows
# Processing row group 197/978... ✅ 122880 → 115819 rows
# Processing row group 198/978... ✅ 122880 → 118257 rows
# Processing row group 199/978... ✅ 122880 → 117165 rows
# Processing row group 200/978... ✅ 122880 → 111571 rows
# Processing row group 201/978... ✅ 122880 → 119087 rows
# Processing row group 202/978... ✅ 122880 → 116089 rows
# Processing row group 203/978... ✅ 122880 → 118009 rows
# Processing row group 204/978... ✅ 122880 → 118195 rows
# Processing row group 205/978... ✅ 123380 → 118499 rows
# Processing row group 206/978... ✅ 122880 → 117558 rows
# Processing row group 207/978... ✅ 122880 → 119018 rows
# Processing row group 208/978... ✅ 122880 → 118035 rows
# Processing row group 209/978... ✅ 122880 → 118800 rows
# Processing row group 210/978... ✅ 122880 → 118096 rows
# Processing row group 211/978... ✅ 122880 → 117546 rows
# Processing row group 212/978... ✅ 122880 → 114472 rows
# Processing row group 213/978... ✅ 122880 → 119056 rows
# Processing row group 214/978... ✅ 122880 → 119215 rows
# Processing row group 215/978... ✅ 122880 → 118810 rows
# Processing row group 216/978... ✅ 122880 → 120728 rows
# Processing row group 217/978... ✅ 122880 → 118160 rows
# Processing row group 218/978... ✅ 122880 → 119755 rows
# Processing row group 219/978... ✅ 122880 → 119492 rows
# Processing row group 220/978... ✅ 122880 → 119440 rows
# Processing row group 221/978... ✅ 122880 → 118971 rows
# Processing row group 222/978... ✅ 123380 → 118731 rows
# Processing row group 223/978... ✅ 122880 → 114776 rows
# Processing row group 224/978... ✅ 122880 → 119435 rows
# Processing row group 225/978... ✅ 122880 → 118904 rows
# Processing row group 226/978... ✅ 122880 → 118968 rows
# Processing row group 227/978... ✅ 122880 → 118659 rows
# Processing row group 228/978... ✅ 122880 → 116565 rows
# Processing row group 229/978... ✅ 122880 → 119950 rows
# Processing row group 230/978... ✅ 122880 → 119315 rows
# Processing row group 231/978... ✅ 122880 → 118737 rows
# Processing row group 232/978... ✅ 122880 → 118459 rows
# Processing row group 233/978... ✅ 122880 → 119319 rows
# Processing row group 234/978... ✅ 122880 → 115258 rows
# Processing row group 235/978... ✅ 122880 → 114221 rows
# Processing row group 236/978... ✅ 122880 → 117796 rows
# Processing row group 237/978... ✅ 122880 → 116156 rows
# Processing row group 238/978... ✅ 122880 → 118415 rows
# Processing row group 239/978... ✅ 123380 → 119687 rows
# Processing row group 240/978... ✅ 122880 → 118059 rows
# Processing row group 241/978... ✅ 122880 → 120041 rows
# Processing row group 242/978... ✅ 122880 → 122203 rows
# Processing row group 243/978... ✅ 122880 → 122737 rows
# Processing row group 244/978... ✅ 122880 → 118292 rows
# Processing row group 245/978... ✅ 122880 → 120342 rows
# Processing row group 246/978... ✅ 122880 → 119012 rows
# Processing row group 247/978... ✅ 122880 → 118550 rows
# Processing row group 248/978... ✅ 122880 → 118006 rows
# Processing row group 249/978... ✅ 122880 → 117525 rows
# Processing row group 250/978... ✅ 122880 → 120144 rows
# Processing row group 251/978... ✅ 122880 → 119641 rows
# Processing row group 252/978... ✅ 122880 → 120128 rows
# Processing row group 253/978... ✅ 122880 → 116451 rows
# Processing row group 254/978... ✅ 122880 → 119788 rows
# Processing row group 255/978... ✅ 122880 → 99774 rows
# Processing row group 256/978... ✅ 123380 → 123380 rows
# Processing row group 257/978... ✅ 122880 → 122880 rows
# Processing row group 258/978... ✅ 122880 → 71548 rows
# Processing row group 259/978... ✅ 122880 → 116826 rows
# Processing row group 260/978... ✅ 122880 → 119615 rows
# Processing row group 261/978... ✅ 122880 → 119939 rows
# Processing row group 262/978... ✅ 122880 → 115803 rows
# Processing row group 263/978... ✅ 122880 → 113916 rows
# Processing row group 264/978... ✅ 122880 → 118597 rows
# Processing row group 265/978... ✅ 122880 → 118817 rows
# Processing row group 266/978... ✅ 122880 → 122179 rows
# Processing row group 267/978... ✅ 122880 → 118930 rows
# Processing row group 268/978... ✅ 122880 → 117442 rows
# Processing row group 269/978... ✅ 122880 → 119594 rows
# Processing row group 270/978... ✅ 122880 → 118048 rows
# Processing row group 271/978... ✅ 122880 → 118563 rows
# Processing row group 272/978... ✅ 122880 → 118133 rows
# Processing row group 273/978... ✅ 123380 → 119797 rows
# Processing row group 274/978... ✅ 122880 → 118450 rows
# Processing row group 275/978... ✅ 122880 → 117934 rows
# Processing row group 276/978... ✅ 122880 → 116851 rows
# Processing row group 277/978... ✅ 122880 → 117202 rows
# Processing row group 278/978... ✅ 122880 → 120215 rows
# Processing row group 279/978... ✅ 122880 → 116549 rows
# Processing row group 280/978... ✅ 122880 → 117663 rows
# Processing row group 281/978... ✅ 122880 → 117197 rows
# Processing row group 282/978... ✅ 122880 → 118830 rows
# Processing row group 283/978... ✅ 122880 → 117990 rows
# Processing row group 284/978... ✅ 122880 → 116947 rows
# Processing row group 285/978... ✅ 122880 → 113335 rows
# Processing row group 286/978... ✅ 122880 → 117786 rows
# Processing row group 287/978... ✅ 122880 → 119779 rows
# Processing row group 288/978... ✅ 122880 → 115655 rows
# Processing row group 289/978... ✅ 122880 → 114507 rows
# Processing row group 290/978... ✅ 123380 → 118561 rows
# Processing row group 291/978... ✅ 122880 → 116642 rows
# Processing row group 292/978... ✅ 122880 → 114976 rows
# Processing row group 293/978... ✅ 122880 → 117686 rows
# Processing row group 294/978... ✅ 122880 → 119531 rows
# Processing row group 295/978... ✅ 122880 → 119792 rows
# Processing row group 296/978... ✅ 122880 → 119036 rows
# Processing row group 297/978... ✅ 122880 → 116548 rows
# Processing row group 298/978... ✅ 122880 → 119856 rows
# Processing row group 299/978... ✅ 122880 → 119773 rows
# Processing row group 300/978... ✅ 122880 → 118553 rows
# Processing row group 301/978... ✅ 122880 → 114776 rows
# Processing row group 302/978... ✅ 122880 → 117110 rows
# Processing row group 303/978... ✅ 122880 → 117237 rows
# Processing row group 304/978... ✅ 122880 → 119440 rows
# Processing row group 305/978... ✅ 122880 → 111773 rows
# Processing row group 306/978... ✅ 122880 → 117954 rows
# Processing row group 307/978... ✅ 123380 → 117963 rows
# Processing row group 308/978... ✅ 122880 → 118308 rows
# Processing row group 309/978... ✅ 122880 → 117718 rows
# Processing row group 310/978... ✅ 122880 → 118028 rows
# Processing row group 311/978... ✅ 122880 → 111148 rows
# Processing row group 312/978... ✅ 122880 → 113240 rows
# Processing row group 313/978... ✅ 122880 → 117589 rows
# Processing row group 314/978... ✅ 122880 → 117759 rows
# Processing row group 315/978... ✅ 122880 → 119282 rows
# Processing row group 316/978... ✅ 122880 → 119864 rows
# Processing row group 317/978... ✅ 122880 → 118373 rows
# Processing row group 318/978... ✅ 122880 → 116728 rows
# Processing row group 319/978... ✅ 122880 → 113203 rows
# Processing row group 320/978... ✅ 122880 → 119053 rows
# Processing row group 321/978... ✅ 122880 → 117302 rows
# Processing row group 322/978... ✅ 122880 → 121326 rows
# Processing row group 323/978... ✅ 122880 → 119133 rows
# Processing row group 324/978... ✅ 123380 → 118906 rows
# Processing row group 325/978... ✅ 122880 → 118381 rows
# Processing row group 326/978... ✅ 122880 → 113284 rows
# Processing row group 327/978... ✅ 122880 → 118537 rows
# Processing row group 328/978... ✅ 122880 → 121453 rows
# Processing row group 329/978... ✅ 122880 → 116583 rows
# Processing row group 330/978... ✅ 122880 → 119843 rows
# Processing row group 331/978... ✅ 122880 → 119116 rows
# Processing row group 332/978... ✅ 122880 → 117962 rows
# Processing row group 333/978... ✅ 122880 → 120535 rows
# Processing row group 334/978... ✅ 122880 → 118493 rows
# Processing row group 335/978... ✅ 122880 → 117341 rows
# Processing row group 336/978... ✅ 122880 → 118938 rows
# Processing row group 337/978... ✅ 122880 → 120232 rows
# Processing row group 338/978... ✅ 122880 → 117957 rows
# Processing row group 339/978... ✅ 122880 → 119366 rows
# Processing row group 340/978... ✅ 122880 → 119107 rows
# Processing row group 341/978... ✅ 123380 → 119718 rows
# Processing row group 342/978... ✅ 122880 → 118658 rows
# Processing row group 343/978... ✅ 122880 → 119349 rows
# Processing row group 344/978... ✅ 122880 → 118205 rows
# Processing row group 345/978... ✅ 122880 → 115989 rows
# Processing row group 346/978... ✅ 122880 → 119125 rows
# Processing row group 347/978... ✅ 122880 → 119237 rows
# Processing row group 348/978... ✅ 122880 → 115922 rows
# Processing row group 349/978... ✅ 122880 → 115413 rows
# Processing row group 350/978... ✅ 122880 → 117076 rows
# Processing row group 351/978... ✅ 122880 → 117663 rows
# Processing row group 352/978... ✅ 122880 → 119263 rows
# Processing row group 353/978... ✅ 122880 → 118319 rows
# Processing row group 354/978... ✅ 122880 → 121185 rows
# Processing row group 355/978... ✅ 122880 → 116575 rows
# Processing row group 356/978... ✅ 122880 → 117250 rows
# Processing row group 357/978... ✅ 122880 → 119007 rows
# Processing row group 358/978... ✅ 123380 → 117827 rows
# Processing row group 359/978... ✅ 122880 → 115513 rows
# Processing row group 360/978... ✅ 122880 → 119354 rows
# Processing row group 361/978... ✅ 122880 → 118286 rows
# Processing row group 362/978... ✅ 122880 → 118996 rows
# Processing row group 363/978... ✅ 122880 → 117759 rows
# Processing row group 364/978... ✅ 122880 → 118056 rows
# Processing row group 365/978... ✅ 122880 → 119014 rows
# Processing row group 366/978... ✅ 122880 → 119910 rows
# Processing row group 367/978... ✅ 122880 → 100335 rows
# Processing row group 368/978... ✅ 122880 → 95562 rows
# Processing row group 369/978... ✅ 122880 → 118649 rows
# Processing row group 370/978... ✅ 122880 → 118890 rows
# Processing row group 371/978... ✅ 122880 → 119320 rows
# Processing row group 372/978... ✅ 122880 → 120094 rows
# Processing row group 373/978... ✅ 122880 → 119482 rows
# Processing row group 374/978... ✅ 122880 → 120328 rows
# Processing row group 375/978... ✅ 123380 → 123376 rows
# Processing row group 376/978... ✅ 122880 → 90652 rows
# Processing row group 377/978... ✅ 122880 → 122880 rows
# Processing row group 378/978... ✅ 122880 → 122880 rows
# Processing row group 379/978... ✅ 122880 → 121514 rows
# Processing row group 380/978... ✅ 122880 → 115637 rows
# Processing row group 381/978... ✅ 122880 → 121229 rows
# Processing row group 382/978... ✅ 122880 → 118082 rows
# Processing row group 383/978... ✅ 122880 → 115620 rows
# Processing row group 384/978... ✅ 122880 → 119396 rows
# Processing row group 385/978... ✅ 122880 → 120063 rows
# Processing row group 386/978... ✅ 122880 → 118824 rows
# Processing row group 387/978... ✅ 122880 → 117214 rows
# Processing row group 388/978... ✅ 122880 → 118421 rows
# Processing row group 389/978... ✅ 122880 → 119841 rows
# Processing row group 390/978... ✅ 122880 → 117726 rows
# Processing row group 391/978... ✅ 122880 → 118623 rows
# Processing row group 392/978... ✅ 123380 → 118365 rows
# Processing row group 393/978... ✅ 122880 → 117554 rows
# Processing row group 394/978... ✅ 122880 → 118418 rows
# Processing row group 395/978... ✅ 122880 → 119188 rows
# Processing row group 396/978... ✅ 122880 → 117749 rows
# Processing row group 397/978... ✅ 122880 → 118353 rows
# Processing row group 398/978... ✅ 122880 → 116273 rows
# Processing row group 399/978... ✅ 122880 → 118009 rows
# Processing row group 400/978... ✅ 122880 → 112052 rows
# Processing row group 401/978... ✅ 122880 → 118211 rows
# Processing row group 402/978... ✅ 122880 → 118676 rows
# Processing row group 403/978... ✅ 122880 → 114860 rows
# Processing row group 404/978... ✅ 122880 → 118267 rows
# Processing row group 405/978... ✅ 122880 → 118159 rows
# Processing row group 406/978... ✅ 122880 → 117238 rows
# Processing row group 407/978... ✅ 122880 → 116924 rows
# Processing row group 408/978... ✅ 122880 → 118759 rows
# Processing row group 409/978... ✅ 123380 → 117642 rows
# Processing row group 410/978... ✅ 122880 → 119465 rows
# Processing row group 411/978... ✅ 122880 → 116433 rows
# Processing row group 412/978... ✅ 122880 → 119348 rows
# Processing row group 413/978... ✅ 122880 → 116428 rows
# Processing row group 414/978... ✅ 122880 → 117392 rows
# Processing row group 415/978... ✅ 122880 → 118799 rows
# Processing row group 416/978... ✅ 122880 → 118373 rows
# Processing row group 417/978... ✅ 122880 → 119781 rows
# Processing row group 418/978... ✅ 122880 → 117765 rows
# Processing row group 419/978... ✅ 122880 → 119564 rows
# Processing row group 420/978... ✅ 122880 → 120143 rows
# Processing row group 421/978... ✅ 122880 → 118829 rows
# Processing row group 422/978... ✅ 122880 → 113188 rows
# Processing row group 423/978... ✅ 122880 → 115225 rows
# Processing row group 424/978... ✅ 122880 → 117739 rows
# Processing row group 425/978... ✅ 122880 → 114835 rows
# Processing row group 426/978... ✅ 123380 → 117699 rows
# Processing row group 427/978... ✅ 122880 → 116395 rows
# Processing row group 428/978... ✅ 122880 → 116296 rows
# Processing row group 429/978... ✅ 122880 → 120301 rows
# Processing row group 430/978... ✅ 122880 → 117569 rows
# Processing row group 431/978... ✅ 122880 → 118474 rows
# Processing row group 432/978... ✅ 122880 → 118633 rows
# Processing row group 433/978... ✅ 122880 → 119633 rows
# Processing row group 434/978... ✅ 122880 → 117938 rows
# Processing row group 435/978... ✅ 122880 → 111330 rows
# Processing row group 436/978... ✅ 122880 → 119914 rows
# Processing row group 437/978... ✅ 122880 → 118222 rows
# Processing row group 438/978... ✅ 122880 → 117852 rows
# Processing row group 439/978... ✅ 122880 → 116704 rows
# Processing row group 440/978... ✅ 122880 → 117655 rows
# Processing row group 441/978... ✅ 122880 → 111588 rows
# Processing row group 442/978... ✅ 122880 → 120123 rows
# Processing row group 443/978... ✅ 123380 → 113720 rows
# Processing row group 444/978... ✅ 122880 → 118922 rows
# Processing row group 445/978... ✅ 122880 → 117047 rows
# Processing row group 446/978... ✅ 122880 → 117219 rows
# Processing row group 447/978... ✅ 122880 → 118786 rows
# Processing row group 448/978... ✅ 122880 → 118381 rows
# Processing row group 449/978... ✅ 122880 → 118901 rows
# Processing row group 450/978... ✅ 122880 → 119337 rows
# Processing row group 451/978... ✅ 122880 → 118819 rows
# Processing row group 452/978... ✅ 122880 → 116993 rows
# Processing row group 453/978... ✅ 122880 → 117519 rows
# Processing row group 454/978... ✅ 122880 → 118456 rows
# Processing row group 455/978... ✅ 122880 → 116615 rows
# Processing row group 456/978... ✅ 122880 → 117890 rows
# Processing row group 457/978... ✅ 122880 → 109502 rows
# Processing row group 458/978... ✅ 122880 → 119484 rows
# Processing row group 459/978... ✅ 122880 → 117643 rows
# Processing row group 460/978... ✅ 123380 → 123289 rows
# Processing row group 461/978... ✅ 122880 → 115653 rows
# Processing row group 462/978... ✅ 122880 → 119249 rows
# Processing row group 463/978... ✅ 122880 → 113771 rows
# Processing row group 464/978... ✅ 122880 → 117798 rows
# Processing row group 465/978... ✅ 122880 → 116513 rows
# Processing row group 466/978... ✅ 122880 → 117008 rows
# Processing row group 467/978... ✅ 122880 → 115970 rows
# Processing row group 468/978... ✅ 122880 → 118799 rows
# Processing row group 469/978... ✅ 122880 → 121261 rows
# Processing row group 470/978... ✅ 122880 → 122880 rows
# Processing row group 471/978... ✅ 122880 → 119805 rows
# Processing row group 472/978... ✅ 122880 → 117616 rows
# Processing row group 473/978... ✅ 122880 → 114338 rows
# Processing row group 474/978... ✅ 122880 → 117001 rows
# Processing row group 475/978... ✅ 122880 → 119832 rows
# Processing row group 476/978... ✅ 122880 → 119027 rows
# Processing row group 477/978... ✅ 123380 → 118914 rows
# Processing row group 478/978... ✅ 122880 → 116600 rows
# Processing row group 479/978... ✅ 122880 → 118286 rows
# Processing row group 480/978... ✅ 122880 → 118369 rows
# Processing row group 481/978... ✅ 122880 → 118711 rows
# Processing row group 482/978... ✅ 122880 → 118238 rows
# Processing row group 483/978... ✅ 122880 → 120683 rows
# Processing row group 484/978... ✅ 122880 → 118418 rows
# Processing row group 485/978... ✅ 122880 → 118655 rows
# Processing row group 486/978... ✅ 122880 → 118942 rows
# Processing row group 487/978... ✅ 122880 → 121642 rows
# Processing row group 488/978... ✅ 122880 → 117375 rows
# Processing row group 489/978... ✅ 122880 → 117049 rows
# Processing row group 490/978... ✅ 122880 → 119714 rows
# Processing row group 491/978... ✅ 122880 → 120645 rows
# Processing row group 492/978... ✅ 122880 → 117479 rows
# Processing row group 493/978... ✅ 122880 → 119059 rows
# Processing row group 494/978... ✅ 123380 → 117897 rows
# Processing row group 495/978... ✅ 122880 → 117240 rows
# Processing row group 496/978... ✅ 122880 → 119968 rows
# Processing row group 497/978... ✅ 122880 → 112450 rows
# Processing row group 498/978... ✅ 122880 → 118324 rows
# Processing row group 499/978... ✅ 122880 → 119156 rows
# Processing row group 500/978... ✅ 122880 → 119780 rows
# Processing row group 501/978... ✅ 122880 → 114340 rows
# Processing row group 502/978... ✅ 122880 → 117351 rows
# Processing row group 503/978... ✅ 122880 → 111945 rows
# Processing row group 504/978... ✅ 122880 → 118102 rows
# Processing row group 505/978... ✅ 122880 → 118612 rows
# Processing row group 506/978... ✅ 122880 → 117457 rows
# Processing row group 507/978... ✅ 122880 → 114277 rows
# Processing row group 508/978... ✅ 122880 → 119322 rows
# Processing row group 509/978... ✅ 122880 → 118048 rows
# Processing row group 510/978... ✅ 122880 → 118633 rows
# Processing row group 511/978... ✅ 123380 → 117597 rows
# Processing row group 512/978... ✅ 122880 → 117942 rows
# Processing row group 513/978... ✅ 122880 → 122118 rows
# Processing row group 514/978... ✅ 122880 → 121968 rows
# Processing row group 515/978... ✅ 122880 → 118366 rows
# Processing row group 516/978... ✅ 122880 → 117916 rows
# Processing row group 517/978... ✅ 122880 → 118843 rows
# Processing row group 518/978... ✅ 122880 → 119217 rows
# Processing row group 519/978... ✅ 122880 → 118473 rows
# Processing row group 520/978... ✅ 122880 → 118022 rows
# Processing row group 521/978... ✅ 122880 → 122276 rows
# Processing row group 522/978... ✅ 122880 → 119980 rows
# Processing row group 523/978... ✅ 122880 → 120117 rows
# Processing row group 524/978... ✅ 122880 → 120317 rows
# Processing row group 525/978... ✅ 122880 → 118760 rows
# Processing row group 526/978... ✅ 122880 → 117592 rows
# Processing row group 527/978... ✅ 122880 → 117886 rows
# Processing row group 528/978... ✅ 123380 → 121325 rows
# Processing row group 529/978... ✅ 122880 → 116211 rows
# Processing row group 530/978... ✅ 122880 → 120395 rows
# Processing row group 531/978... ✅ 122880 → 118824 rows
# Processing row group 532/978... ✅ 122880 → 120400 rows
# Processing row group 533/978... ✅ 122880 → 122622 rows
# Processing row group 534/978... ✅ 122880 → 118062 rows
# Processing row group 535/978... ✅ 122880 → 112175 rows
# Processing row group 536/978... ✅ 122880 → 119067 rows
# Processing row group 537/978... ✅ 122880 → 120177 rows
# Processing row group 538/978... ✅ 122880 → 112061 rows
# Processing row group 539/978... ✅ 122880 → 118903 rows
# Processing row group 540/978... ✅ 122880 → 117952 rows
# Processing row group 541/978... ✅ 122880 → 116720 rows
# Processing row group 542/978... ✅ 122880 → 108553 rows
# Processing row group 543/978... ✅ 122880 → 116745 rows
# Processing row group 544/978... ✅ 122880 → 117683 rows
# Processing row group 545/978... ✅ 123380 → 119253 rows
# Processing row group 546/978... ✅ 122880 → 120034 rows
# Processing row group 547/978... ✅ 122880 → 120786 rows
# Processing row group 548/978... ✅ 122880 → 117527 rows
# Processing row group 549/978... ✅ 122880 → 117578 rows
# Processing row group 550/978... ✅ 122880 → 118163 rows
# Processing row group 551/978... ✅ 122880 → 119291 rows
# Processing row group 552/978... ✅ 122880 → 119334 rows
# Processing row group 553/978... ✅ 122880 → 112821 rows
# Processing row group 554/978... ✅ 122880 → 117960 rows
# Processing row group 555/978... ✅ 122880 → 119419 rows
# Processing row group 556/978... ✅ 122880 → 113505 rows
# Processing row group 557/978... ✅ 122880 → 118056 rows
# Processing row group 558/978... ✅ 122880 → 115081 rows
# Processing row group 559/978... ✅ 122880 → 118274 rows
# Processing row group 560/978... ✅ 122880 → 119458 rows
# Processing row group 561/978... ✅ 122880 → 116251 rows
# Processing row group 562/978... ✅ 123380 → 121612 rows
# Processing row group 563/978... ✅ 122880 → 115137 rows
# Processing row group 564/978... ✅ 122880 → 116697 rows
# Processing row group 565/978... ✅ 122880 → 118909 rows
# Processing row group 566/978... ✅ 122880 → 117473 rows
# Processing row group 567/978... ✅ 122880 → 118874 rows
# Processing row group 568/978... ✅ 122880 → 118118 rows
# Processing row group 569/978... ✅ 122880 → 119454 rows
# Processing row group 570/978... ✅ 122880 → 117203 rows
# Processing row group 571/978... ✅ 122880 → 108246 rows
# Processing row group 572/978... ✅ 122880 → 115216 rows
# Processing row group 573/978... ✅ 122880 → 117504 rows
# Processing row group 574/978... ✅ 122880 → 119462 rows
# Processing row group 575/978... ✅ 122880 → 119568 rows
# Processing row group 576/978... ✅ 122880 → 117704 rows
# Processing row group 577/978... ✅ 122880 → 116429 rows
# Processing row group 578/978... ✅ 122880 → 117960 rows
# Processing row group 579/978... ✅ 123380 → 120055 rows
# Processing row group 580/978... ✅ 122880 → 119580 rows
# Processing row group 581/978... ✅ 122880 → 118120 rows
# Processing row group 582/978... ✅ 122880 → 118157 rows
# Processing row group 583/978... ✅ 122880 → 118550 rows
# Processing row group 584/978... ✅ 122880 → 121649 rows
# Processing row group 585/978... ✅ 122880 → 122880 rows
# Processing row group 586/978... ✅ 122880 → 122880 rows
# Processing row group 587/978... ✅ 122880 → 122880 rows
# Processing row group 588/978... ✅ 122880 → 122880 rows
# Processing row group 589/978... ✅ 122880 → 122880 rows
# Processing row group 590/978... ✅ 122880 → 122880 rows
# Processing row group 591/978... ✅ 122880 → 122880 rows
# Processing row group 592/978... ✅ 122880 → 120673 rows
# Processing row group 593/978... ✅ 122880 → 119460 rows
# Processing row group 594/978... ✅ 122880 → 115353 rows
# Processing row group 595/978... ✅ 122880 → 115157 rows
# Processing row group 596/978... ✅ 123380 → 119721 rows
# Processing row group 597/978... ✅ 122880 → 119139 rows
# Processing row group 598/978... ✅ 122880 → 118639 rows
# Processing row group 599/978... ✅ 122880 → 117484 rows
# Processing row group 600/978... ✅ 122880 → 118663 rows
# Processing row group 601/978... ✅ 122880 → 119491 rows
# Processing row group 602/978... ✅ 122880 → 116580 rows
# Processing row group 603/978... ✅ 122880 → 114601 rows
# Processing row group 604/978... ✅ 122880 → 117633 rows
# Processing row group 605/978... ✅ 122880 → 118194 rows
# Processing row group 606/978... ✅ 122880 → 118048 rows
# Processing row group 607/978... ✅ 122880 → 114706 rows
# Processing row group 608/978... ✅ 122880 → 118527 rows
# Processing row group 609/978... ✅ 122880 → 118978 rows
# Processing row group 610/978... ✅ 122880 → 118445 rows
# Processing row group 611/978... ✅ 122880 → 117955 rows
# Processing row group 612/978... ✅ 122880 → 119018 rows
# Processing row group 613/978... ✅ 123380 → 119939 rows
# Processing row group 614/978... ✅ 122880 → 117739 rows
# Processing row group 615/978... ✅ 122880 → 119533 rows
# Processing row group 616/978... ✅ 122880 → 117095 rows
# Processing row group 617/978... ✅ 122880 → 118592 rows
# Processing row group 618/978... ✅ 122880 → 117933 rows
# Processing row group 619/978... ✅ 122880 → 118439 rows
# Processing row group 620/978... ✅ 122880 → 118852 rows
# Processing row group 621/978... ✅ 122880 → 109973 rows
# Processing row group 622/978... ✅ 122880 → 118651 rows
# Processing row group 623/978... ✅ 122880 → 119124 rows
# Processing row group 624/978... ✅ 122880 → 120805 rows
# Processing row group 625/978... ✅ 122880 → 119444 rows
# Processing row group 626/978... ✅ 122880 → 118487 rows
# Processing row group 627/978... ✅ 122880 → 119241 rows
# Processing row group 628/978... ✅ 122880 → 119530 rows
# Processing row group 629/978... ✅ 122880 → 120870 rows
# Processing row group 630/978... ✅ 123380 → 120427 rows
# Processing row group 631/978... ✅ 122880 → 120664 rows
# Processing row group 632/978... ✅ 122880 → 118605 rows
# Processing row group 633/978... ✅ 122880 → 119222 rows
# Processing row group 634/978... ✅ 122880 → 119791 rows
# Processing row group 635/978... ✅ 122880 → 119436 rows
# Processing row group 636/978... ✅ 122880 → 118732 rows
# Processing row group 637/978... ✅ 122880 → 117944 rows
# Processing row group 638/978... ✅ 122880 → 118913 rows
# Processing row group 639/978... ✅ 122880 → 119273 rows
# Processing row group 640/978... ✅ 122880 → 117945 rows
# Processing row group 641/978... ✅ 122880 → 118395 rows
# Processing row group 642/978... ✅ 122880 → 113139 rows
# Processing row group 643/978... ✅ 122880 → 116251 rows
# Processing row group 644/978... ✅ 122880 → 119407 rows
# Processing row group 645/978... ✅ 122880 → 115786 rows
# Processing row group 646/978... ✅ 122880 → 122880 rows
# Processing row group 647/978... ✅ 123380 → 121533 rows
# Processing row group 648/978... ✅ 122880 → 117239 rows
# Processing row group 649/978... ✅ 122880 → 117047 rows
# Processing row group 650/978... ✅ 122880 → 118656 rows
# Processing row group 651/978... ✅ 122880 → 117743 rows
# Processing row group 652/978... ✅ 122880 → 118519 rows
# Processing row group 653/978... ✅ 122880 → 117975 rows
# Processing row group 654/978... ✅ 122880 → 115538 rows
# Processing row group 655/978... ✅ 122880 → 116787 rows
# Processing row group 656/978... ✅ 122880 → 117663 rows
# Processing row group 657/978... ✅ 122880 → 115465 rows
# Processing row group 658/978... ✅ 122880 → 119194 rows
# Processing row group 659/978... ✅ 122880 → 119349 rows
# Processing row group 660/978... ✅ 122880 → 118994 rows
# Processing row group 661/978... ✅ 122880 → 116375 rows
# Processing row group 662/978... ✅ 122880 → 118692 rows
# Processing row group 663/978... ✅ 122880 → 117298 rows
# Processing row group 664/978... ✅ 123380 → 118692 rows
# Processing row group 665/978... ✅ 122880 → 117698 rows
# Processing row group 666/978... ✅ 122880 → 118410 rows
# Processing row group 667/978... ✅ 122880 → 118452 rows
# Processing row group 668/978... ✅ 122880 → 117960 rows
# Processing row group 669/978... ✅ 122880 → 116448 rows
# Processing row group 670/978... ✅ 122880 → 116342 rows
# Processing row group 671/978... ✅ 122880 → 117659 rows
# Processing row group 672/978... ✅ 122880 → 121080 rows
# Processing row group 673/978... ✅ 122880 → 117306 rows
# Processing row group 674/978... ✅ 122880 → 119001 rows
# Processing row group 675/978... ✅ 122880 → 118673 rows
# Processing row group 676/978... ✅ 122880 → 114573 rows
# Processing row group 677/978... ✅ 122880 → 118778 rows
# Processing row group 678/978... ✅ 122880 → 118991 rows
# Processing row group 679/978... ✅ 122880 → 119282 rows
# Processing row group 680/978... ✅ 122880 → 122880 rows
# Processing row group 681/978... ✅ 123380 → 121841 rows
# Processing row group 682/978... ✅ 122880 → 119420 rows
# Processing row group 683/978... ✅ 122880 → 117213 rows
# Processing row group 684/978... ✅ 122880 → 112811 rows
# Processing row group 685/978... ✅ 122880 → 117105 rows
# Processing row group 686/978... ✅ 122880 → 117040 rows
# Processing row group 687/978... ✅ 122880 → 120031 rows
# Processing row group 688/978... ✅ 122880 → 118743 rows
# Processing row group 689/978... ✅ 122880 → 118742 rows
# Processing row group 690/978... ✅ 122880 → 120786 rows
# Processing row group 691/978... ✅ 122880 → 115431 rows
# Processing row group 692/978... ✅ 122880 → 117530 rows
# Processing row group 693/978... ✅ 122880 → 120461 rows
# Processing row group 694/978... ✅ 122880 → 114554 rows
# Processing row group 695/978... ✅ 122880 → 114937 rows
# Processing row group 696/978... ✅ 122880 → 119507 rows
# Processing row group 697/978... ✅ 122880 → 113793 rows
# Processing row group 698/978... ✅ 123380 → 123380 rows
# Processing row group 699/978... ✅ 122880 → 122880 rows
# Processing row group 700/978... ✅ 122880 → 118978 rows
# Processing row group 701/978... ✅ 122880 → 118048 rows
# Processing row group 702/978... ✅ 122880 → 116432 rows
# Processing row group 703/978... ✅ 122880 → 118459 rows
# Processing row group 704/978... ✅ 122880 → 120560 rows
# Processing row group 705/978... ✅ 122880 → 117790 rows
# Processing row group 706/978... ✅ 122880 → 120103 rows
# Processing row group 707/978... ✅ 122880 → 119169 rows
# Processing row group 708/978... ✅ 122880 → 117096 rows
# Processing row group 709/978... ✅ 122880 → 119346 rows
# Processing row group 710/978... ✅ 122880 → 121574 rows
# Processing row group 711/978... ✅ 122880 → 117738 rows
# Processing row group 712/978... ✅ 122880 → 117630 rows
# Processing row group 713/978... ✅ 122880 → 118549 rows
# Processing row group 714/978... ✅ 122880 → 122880 rows
# Processing row group 715/978... ✅ 123380 → 119093 rows
# Processing row group 716/978... ✅ 122880 → 117995 rows
# Processing row group 717/978... ✅ 122880 → 116517 rows
# Processing row group 718/978... ✅ 122880 → 117505 rows
# Processing row group 719/978... ✅ 122880 → 114176 rows
# Processing row group 720/978... ✅ 122880 → 118522 rows
# Processing row group 721/978... ✅ 122880 → 118083 rows
# Processing row group 722/978... ✅ 122880 → 119947 rows
# Processing row group 723/978... ✅ 122880 → 118544 rows
# Processing row group 724/978... ✅ 122880 → 117193 rows
# Processing row group 725/978... ✅ 122880 → 117879 rows
# Processing row group 726/978... ✅ 122880 → 118523 rows
# Processing row group 727/978... ✅ 122880 → 120236 rows
# Processing row group 728/978... ✅ 122880 → 114382 rows
# Processing row group 729/978... ✅ 122880 → 116556 rows
# Processing row group 730/978... ✅ 122880 → 117785 rows
# Processing row group 731/978... ✅ 122880 → 120229 rows
# Processing row group 732/978... ✅ 123380 → 120061 rows
# Processing row group 733/978... ✅ 122880 → 119186 rows
# Processing row group 734/978... ✅ 122880 → 120446 rows
# Processing row group 735/978... ✅ 122880 → 119998 rows
# Processing row group 736/978... ✅ 122880 → 122220 rows
# Processing row group 737/978... ✅ 122880 → 122880 rows
# Processing row group 738/978... ✅ 122880 → 122880 rows
# Processing row group 739/978... ✅ 122880 → 119920 rows
# Processing row group 740/978... ✅ 122880 → 118080 rows
# Processing row group 741/978... ✅ 122880 → 119348 rows
# Processing row group 742/978... ✅ 122880 → 117556 rows
# Processing row group 743/978... ✅ 122880 → 119525 rows
# Processing row group 744/978... ✅ 122880 → 120028 rows
# Processing row group 745/978... ✅ 122880 → 116493 rows
# Processing row group 746/978... ✅ 122880 → 119854 rows
# Processing row group 747/978... ✅ 122880 → 119001 rows
# Processing row group 748/978... ✅ 122880 → 118789 rows
# Processing row group 749/978... ✅ 123380 → 119627 rows
# Processing row group 750/978... ✅ 122880 → 119626 rows
# Processing row group 751/978... ✅ 122880 → 119063 rows
# Processing row group 752/978... ✅ 122880 → 122880 rows
# Processing row group 753/978... ✅ 122880 → 122880 rows
# Processing row group 754/978... ✅ 122880 → 122880 rows
# Processing row group 755/978... ✅ 122880 → 122880 rows
# Processing row group 756/978... ✅ 122880 → 122880 rows
# Processing row group 757/978... ✅ 122880 → 122880 rows
# Processing row group 758/978... ✅ 122880 → 122880 rows
# Processing row group 759/978... ✅ 122880 → 122880 rows
# Processing row group 760/978... ✅ 122880 → 122880 rows
# Processing row group 761/978... ✅ 122880 → 122880 rows
# Processing row group 762/978... ✅ 122880 → 122880 rows
# Processing row group 763/978... ✅ 122880 → 122880 rows
# Processing row group 764/978... ✅ 122880 → 122880 rows
# Processing row group 765/978... ✅ 122880 → 122880 rows
# Processing row group 766/978... ✅ 123380 → 123380 rows
# Processing row group 767/978... ✅ 122880 → 122880 rows
# Processing row group 768/978... ✅ 122880 → 112102 rows
# Processing row group 769/978... ✅ 122880 → 113859 rows
# Processing row group 770/978... ✅ 122880 → 119036 rows
# Processing row group 771/978... ✅ 122880 → 117766 rows
# Processing row group 772/978... ✅ 122880 → 116649 rows
# Processing row group 773/978... ✅ 122880 → 119386 rows
# Processing row group 774/978... ✅ 122880 → 117896 rows
# Processing row group 775/978... ✅ 122880 → 122880 rows
# Processing row group 776/978... ✅ 122880 → 122880 rows
# Processing row group 777/978... ✅ 122880 → 122880 rows
# Processing row group 778/978... ✅ 122880 → 120800 rows
# Processing row group 779/978... ✅ 122880 → 119099 rows
# Processing row group 780/978... ✅ 122880 → 117565 rows
# Processing row group 781/978... ✅ 122880 → 119097 rows
# Processing row group 782/978... ✅ 122880 → 118542 rows
# Processing row group 783/978... ✅ 123380 → 118270 rows
# Processing row group 784/978... ✅ 122880 → 119031 rows
# Processing row group 785/978... ✅ 122880 → 116242 rows
# Processing row group 786/978... ✅ 122880 → 114043 rows
# Processing row group 787/978... ✅ 122880 → 118142 rows
# Processing row group 788/978... ✅ 122880 → 118888 rows
# Processing row group 789/978... ✅ 122880 → 120248 rows
# Processing row group 790/978... ✅ 122880 → 116923 rows
# Processing row group 791/978... ✅ 122880 → 118401 rows
# Processing row group 792/978... ✅ 122880 → 122435 rows
# Processing row group 793/978... ✅ 122880 → 111836 rows
# Processing row group 794/978... ✅ 122880 → 118397 rows
# Processing row group 795/978... ✅ 122880 → 118641 rows
# Processing row group 796/978... ✅ 122880 → 118503 rows
# Processing row group 797/978... ✅ 122880 → 119351 rows
# Processing row group 798/978... ✅ 122880 → 117046 rows
# Processing row group 799/978... ✅ 122880 → 116756 rows
# Processing row group 800/978... ✅ 123380 → 117693 rows
# Processing row group 801/978... ✅ 122880 → 119652 rows
# Processing row group 802/978... ✅ 122880 → 117207 rows
# Processing row group 803/978... ✅ 122880 → 122880 rows
# Processing row group 804/978... ✅ 122880 → 122880 rows
# Processing row group 805/978... ✅ 122880 → 117427 rows
# Processing row group 806/978... ✅ 122880 → 118981 rows
# Processing row group 807/978... ✅ 122880 → 119121 rows
# Processing row group 808/978... ✅ 122880 → 119035 rows
# Processing row group 809/978... ✅ 122880 → 116783 rows
# Processing row group 810/978... ✅ 122880 → 118650 rows
# Processing row group 811/978... ✅ 122880 → 116973 rows
# Processing row group 812/978... ✅ 122880 → 118992 rows
# Processing row group 813/978... ✅ 122880 → 117864 rows
# Processing row group 814/978... ✅ 122880 → 119965 rows
# Processing row group 815/978... ✅ 122880 → 119736 rows
# Processing row group 816/978... ✅ 122880 → 122560 rows
# Processing row group 817/978... ✅ 123380 → 122098 rows
# Processing row group 818/978... ✅ 122880 → 118079 rows
# Processing row group 819/978... ✅ 122880 → 119328 rows
# Processing row group 820/978... ✅ 122880 → 116889 rows
# Processing row group 821/978... ✅ 122880 → 116172 rows
# Processing row group 822/978... ✅ 122880 → 119735 rows
# Processing row group 823/978... ✅ 122880 → 114409 rows
# Processing row group 824/978... ✅ 122880 → 117554 rows
# Processing row group 825/978... ✅ 122880 → 117322 rows
# Processing row group 826/978... ✅ 122880 → 118794 rows
# Processing row group 827/978... ✅ 122880 → 120674 rows
# Processing row group 828/978... ✅ 122880 → 119057 rows
# Processing row group 829/978... ✅ 122880 → 118159 rows
# Processing row group 830/978... ✅ 122880 → 119996 rows
# Processing row group 831/978... ✅ 122880 → 119440 rows
# Processing row group 832/978... ✅ 122880 → 117638 rows
# Processing row group 833/978... ✅ 122880 → 117777 rows
# Processing row group 834/978... ✅ 123380 → 119339 rows
# Processing row group 835/978... ✅ 122880 → 117007 rows
# Processing row group 836/978... ✅ 122880 → 118419 rows
# Processing row group 837/978... ✅ 122880 → 115287 rows
# Processing row group 838/978... ✅ 122880 → 117619 rows
# Processing row group 839/978... ✅ 122880 → 122105 rows
# Processing row group 840/978... ✅ 122880 → 117121 rows
# Processing row group 841/978... ✅ 122880 → 117791 rows
# Processing row group 842/978... ✅ 122880 → 119306 rows
# Processing row group 843/978... ✅ 122880 → 117112 rows
# Processing row group 844/978... ✅ 122880 → 117050 rows
# Processing row group 845/978... ✅ 122880 → 117041 rows
# Processing row group 846/978... ✅ 122880 → 115717 rows
# Processing row group 847/978... ✅ 122880 → 117147 rows
# Processing row group 848/978... ✅ 122880 → 118355 rows
# Processing row group 849/978... ✅ 122880 → 109849 rows
# Processing row group 850/978... ✅ 122880 → 122880 rows
# Processing row group 851/978... ✅ 123380 → 123380 rows
# Processing row group 852/978... ✅ 122880 → 84762 rows
# Processing row group 853/978... ✅ 122880 → 119485 rows
# Processing row group 854/978... ✅ 122880 → 119516 rows
# Processing row group 855/978... ✅ 122880 → 119605 rows
# Processing row group 856/978... ✅ 122880 → 116890 rows
# Processing row group 857/978... ✅ 122880 → 118078 rows
# Processing row group 858/978... ✅ 122880 → 118986 rows
# Processing row group 859/978... ✅ 122880 → 118775 rows
# Processing row group 860/978... ✅ 122880 → 118725 rows
# Processing row group 861/978... ✅ 122880 → 117920 rows
# Processing row group 862/978... ✅ 122880 → 119056 rows
# Processing row group 863/978... ✅ 122880 → 117424 rows
# Processing row group 864/978... ✅ 122880 → 119203 rows
# Processing row group 865/978... ✅ 122880 → 119110 rows
# Processing row group 866/978... ✅ 122880 → 119123 rows
# Processing row group 867/978... ✅ 122880 → 117478 rows
# Processing row group 868/978... ✅ 123380 → 117821 rows
# Processing row group 869/978... ✅ 122880 → 117382 rows
# Processing row group 870/978... ✅ 122880 → 118949 rows
# Processing row group 871/978... ✅ 122880 → 117822 rows
# Processing row group 872/978... ✅ 122880 → 118831 rows
# Processing row group 873/978... ✅ 122880 → 120147 rows
# Processing row group 874/978... ✅ 122880 → 119797 rows
# Processing row group 875/978... ✅ 122880 → 118582 rows
# Processing row group 876/978... ✅ 122880 → 118132 rows
# Processing row group 877/978... ✅ 122880 → 117467 rows
# Processing row group 878/978... ✅ 122880 → 117851 rows
# Processing row group 879/978... ✅ 122880 → 117293 rows
# Processing row group 880/978... ✅ 122880 → 117126 rows
# Processing row group 881/978... ✅ 122880 → 117227 rows
# Processing row group 882/978... ✅ 122880 → 118140 rows
# Processing row group 883/978... ✅ 122880 → 118770 rows
# Processing row group 884/978... ✅ 122880 → 118368 rows
# Processing row group 885/978... ✅ 123380 → 117200 rows
# Processing row group 886/978... ✅ 122880 → 117947 rows
# Processing row group 887/978... ✅ 122880 → 118080 rows
# Processing row group 888/978... ✅ 122880 → 119537 rows
# Processing row group 889/978... ✅ 122880 → 118757 rows
# Processing row group 890/978... ✅ 122880 → 118517 rows
# Processing row group 891/978... ✅ 122880 → 119086 rows
# Processing row group 892/978... ✅ 122880 → 117828 rows
# Processing row group 893/978... ✅ 122880 → 118617 rows
# Processing row group 894/978... ✅ 122880 → 118884 rows
# Processing row group 895/978... ✅ 122880 → 118092 rows
# Processing row group 896/978... ✅ 122880 → 118478 rows
# Processing row group 897/978... ✅ 122880 → 118362 rows
# Processing row group 898/978... ✅ 122880 → 111745 rows
# Processing row group 899/978... ✅ 122880 → 116293 rows
# Processing row group 900/978... ✅ 122880 → 119565 rows
# Processing row group 901/978... ✅ 122880 → 119270 rows
# Processing row group 902/978... ✅ 123380 → 115692 rows
# Processing row group 903/978... ✅ 122880 → 117751 rows
# Processing row group 904/978... ✅ 122880 → 113776 rows
# Processing row group 905/978... ✅ 122880 → 117969 rows
# Processing row group 906/978... ✅ 122880 → 118393 rows
# Processing row group 907/978... ✅ 122880 → 119465 rows
# Processing row group 908/978... ✅ 122880 → 118823 rows
# Processing row group 909/978... ✅ 122880 → 118467 rows
# Processing row group 910/978... ✅ 122880 → 119248 rows
# Processing row group 911/978... ✅ 122880 → 119091 rows
# Processing row group 912/978... ✅ 122880 → 116075 rows
# Processing row group 913/978... ✅ 122880 → 117322 rows
# Processing row group 914/978... ✅ 122880 → 119077 rows
# Processing row group 915/978... ✅ 122880 → 113662 rows
# Processing row group 916/978... ✅ 122880 → 119731 rows
# Processing row group 917/978... ✅ 122880 → 118392 rows
# Processing row group 918/978... ✅ 122880 → 119686 rows
# Processing row group 919/978... ✅ 123380 → 119112 rows
# Processing row group 920/978... ✅ 122880 → 118030 rows
# Processing row group 921/978... ✅ 122880 → 117700 rows
# Processing row group 922/978... ✅ 122880 → 118659 rows
# Processing row group 923/978... ✅ 122880 → 119134 rows
# Processing row group 924/978... ✅ 122880 → 117821 rows
# Processing row group 925/978... ✅ 122880 → 119971 rows
# Processing row group 926/978... ✅ 122880 → 116861 rows
# Processing row group 927/978... ✅ 122880 → 118738 rows
# Processing row group 928/978... ✅ 122880 → 118851 rows
# Processing row group 929/978... ✅ 122880 → 121321 rows
# Processing row group 930/978... ✅ 122880 → 116364 rows
# Processing row group 931/978... ✅ 122880 → 117892 rows
# Processing row group 932/978... ✅ 122880 → 119374 rows
# Processing row group 933/978... ✅ 122880 → 116432 rows
# Processing row group 934/978... ✅ 122880 → 117957 rows
# Processing row group 935/978... ✅ 122880 → 118247 rows
# Processing row group 936/978... ✅ 123380 → 118481 rows
# Processing row group 937/978... ✅ 122880 → 119296 rows
# Processing row group 938/978... ✅ 122880 → 116011 rows
# Processing row group 939/978... ✅ 122880 → 119037 rows
# Processing row group 940/978... ✅ 122880 → 116064 rows
# Processing row group 941/978... ✅ 122880 → 119737 rows
# Processing row group 942/978... ✅ 122880 → 117920 rows
# Processing row group 943/978... ✅ 122880 → 118079 rows
# Processing row group 944/978... ✅ 122880 → 116624 rows
# Processing row group 945/978... ✅ 122880 → 117505 rows
# Processing row group 946/978... ✅ 122880 → 117063 rows
# Processing row group 947/978... ✅ 122880 → 118027 rows
# Processing row group 948/978... ✅ 122880 → 120791 rows
# Processing row group 949/978... ✅ 122880 → 118968 rows
# Processing row group 950/978... ✅ 122880 → 115681 rows
# Processing row group 951/978... ✅ 122880 → 116772 rows
# Processing row group 952/978... ✅ 122880 → 118793 rows
# Processing row group 953/978... ✅ 123380 → 118591 rows
# Processing row group 954/978... ✅ 122880 → 118423 rows
# Processing row group 955/978... ✅ 122880 → 117209 rows
# Processing row group 956/978... ✅ 122880 → 117397 rows
# Processing row group 957/978... ✅ 122880 → 118747 rows
# Processing row group 958/978... ✅ 122880 → 119457 rows
# Processing row group 959/978... ✅ 122880 → 120051 rows
# Processing row group 960/978... ✅ 122880 → 21518 rows
# Processing row group 961/978... ✅ 122880 → 122880 rows
# Processing row group 962/978... ✅ 122880 → 22730 rows
# Processing row group 963/978... ✅ 122880 → 119470 rows
# Processing row group 964/978... ✅ 122880 → 119948 rows
# Processing row group 965/978... ✅ 122880 → 118660 rows
# Processing row group 966/978... ✅ 122880 → 118694 rows
# Processing row group 967/978... ✅ 122880 → 117745 rows
# Processing row group 968/978... ✅ 122880 → 118172 rows
# Processing row group 969/978... ✅ 122880 → 119198 rows
# Processing row group 970/978... ✅ 123380 → 118251 rows
# Processing row group 971/978... ✅ 122880 → 119885 rows
# Processing row group 972/978... ✅ 122880 → 120818 rows
# Processing row group 973/978... ✅ 122880 → 119177 rows
# Processing row group 974/978... ✅ 122880 → 118088 rows
# Processing row group 975/978... ✅ 122880 → 118299 rows
# Processing row group 976/978... ✅ 122880 → 118982 rows
# Processing row group 977/978... ✅ 122880 → 115709 rows
# Processing row group 978/978... ✅ 6250 → 6056 rows
#
# ============================================================
# ROW GROUP CLEANING SUMMARY:
# ============================================================
# Row groups: 978 processed
# Rows:       120,088,510 → 115,298,850 (96.0% kept)
# File size:  1.49 GB → 1.39 GB
# Reduction:  0.10 GB (6.7%)
# Columns:    4 → 3
# ============================================================
# {'original_rows': 120088510,
#  'final_rows': 115298850,
#  'original_size': 1599106665,
#  'final_size': 1491583739,
#  'row_groups_processed': 978}

# %% [markdown]
# ## Follows

# %%
i_file = "/home/ale/Documents/uni/mp/data/raw/follows.parquet"
o_file = "/home/ale/Documents/uni/mp/data/cleaned/follows.parquet"
# It's a large database so parallel processing may help.
# clean_parquet_parallel(i_file, o_file, CLEANING_RULES, table_type="follows")
clean_parquet_by_row_groups(i_file, o_file, CLEANING_RULES, table_type="follows")
# Out:
# Cleaning in parallel with 4 workers...
# Processing 3 columns across 17551 row groups
# Applied rules: ['removed_null_did_id', 'removed_null_created_at', 'max_date_created_at', 'min_date_created_at', 'removed_null_subject_id']

# %% [markdown]
# ## Profiles

# %%
i_file = "/home/ale/Documents/uni/mp/data/raw/profiles.parquet"
o_file = "/home/ale/Documents/uni/mp/data/cleaned/profiles.parquet"
clean_parquet_by_row_groups(i_file, o_file, CLEANING_RULES, table_type="profiles")
# Out:
# Cleaning by row groups...
# Input file: 1.77 GB
# Processing 2 columns: ['did_id', 'created_at']
# Processing 262 row groups...
# Processing row group 1/262... Applied rules: ['removed_null_did_id', 'removed_null_created_at', 'max_date_created_at', 'min_date_created_at']
# ✅ 122880 → 106653 rows
# Processing row group 2/262... ✅ 122880 → 106756 rows
# Processing row group 3/262... ✅ 122880 → 106585 rows
# Processing row group 4/262... ✅ 122880 → 106603 rows
# Processing row group 5/262... ✅ 122880 → 106731 rows
# Processing row group 6/262... ✅ 122880 → 106656 rows
# Processing row group 7/262... ✅ 122880 → 106534 rows
# Processing row group 8/262... ✅ 122880 → 106684 rows
# Processing row group 9/262... ✅ 122880 → 106592 rows
# Processing row group 10/262... ✅ 122880 → 106595 rows
# Processing row group 11/262... ✅ 122880 → 106560 rows
# Processing row group 12/262... ✅ 122880 → 106756 rows
# Processing row group 13/262... ✅ 122880 → 106681 rows
# Processing row group 14/262... ✅ 122880 → 106800 rows
# Processing row group 15/262... ✅ 122880 → 106770 rows
# Processing row group 16/262... ✅ 122880 → 106689 rows
# Processing row group 17/262... ✅ 122880 → 106496 rows
# Processing row group 18/262... ✅ 122880 → 106729 rows
# Processing row group 19/262... ✅ 122880 → 106579 rows
# Processing row group 20/262... ✅ 122880 → 106851 rows
# Processing row group 21/262... ✅ 122880 → 106631 rows
# Processing row group 22/262... ✅ 122880 → 106639 rows
# Processing row group 23/262... ✅ 122880 → 106704 rows
# Processing row group 24/262... ✅ 122880 → 106523 rows
# Processing row group 25/262... ✅ 122880 → 106690 rows
# Processing row group 26/262... ✅ 122880 → 106794 rows
# Processing row group 27/262... ✅ 122880 → 106682 rows
# Processing row group 28/262... ✅ 122880 → 106396 rows
# Processing row group 29/262... ✅ 122880 → 106549 rows
# Processing row group 30/262... ✅ 122880 → 106581 rows
# Processing row group 31/262... ✅ 122880 → 106645 rows
# Processing row group 32/262... ✅ 122880 → 106880 rows
# Processing row group 33/262... ✅ 122880 → 106703 rows
# Processing row group 34/262... ✅ 122880 → 106905 rows
# Processing row group 35/262... ✅ 122880 → 106786 rows
# Processing row group 36/262... ✅ 122880 → 106594 rows
# Processing row group 37/262... ✅ 122880 → 106849 rows
# Processing row group 38/262... ✅ 122880 → 106780 rows
# Processing row group 39/262... ✅ 122880 → 106724 rows
# Processing row group 40/262... ✅ 122880 → 106673 rows
# Processing row group 41/262... ✅ 122880 → 106363 rows
# Processing row group 42/262... ✅ 122880 → 106537 rows
# Processing row group 43/262... ✅ 122880 → 106722 rows
# Processing row group 44/262... ✅ 122880 → 106795 rows
# Processing row group 45/262... ✅ 122880 → 106663 rows
# Processing row group 46/262... ✅ 122880 → 106628 rows
# Processing row group 47/262... ✅ 122880 → 106695 rows
# Processing row group 48/262... ✅ 122880 → 106637 rows
# Processing row group 49/262... ✅ 122880 → 106728 rows
# Processing row group 50/262... ✅ 122880 → 106510 rows
# Processing row group 51/262... ✅ 122880 → 106818 rows
# Processing row group 52/262... ✅ 122880 → 106596 rows
# Processing row group 53/262... ✅ 122880 → 106561 rows
# Processing row group 54/262... ✅ 122880 → 106608 rows
# Processing row group 55/262... ✅ 122880 → 106669 rows
# Processing row group 56/262... ✅ 122880 → 106496 rows
# Processing row group 57/262... ✅ 122880 → 106707 rows
# Processing row group 58/262... ✅ 122880 → 106504 rows
# Processing row group 59/262... ✅ 122880 → 106706 rows
# Processing row group 60/262... ✅ 122880 → 106741 rows
# Processing row group 61/262... ✅ 122880 → 106399 rows
# Processing row group 62/262... ✅ 122880 → 106694 rows
# Processing row group 63/262... ✅ 122880 → 106854 rows
# Processing row group 64/262... ✅ 122880 → 106710 rows
# Processing row group 65/262... ✅ 122880 → 106754 rows
# Processing row group 66/262... ✅ 122880 → 106772 rows
# Processing row group 67/262... ✅ 122880 → 106693 rows
# Processing row group 68/262... ✅ 122880 → 106586 rows
# Processing row group 69/262... ✅ 122880 → 106602 rows
# Processing row group 70/262... ✅ 122880 → 106709 rows
# Processing row group 71/262... ✅ 122880 → 106860 rows
# Processing row group 72/262... ✅ 122880 → 106515 rows
# Processing row group 73/262... ✅ 122880 → 106608 rows
# Processing row group 74/262... ✅ 122880 → 106789 rows
# Processing row group 75/262... ✅ 122880 → 106620 rows
# Processing row group 76/262... ✅ 122880 → 106433 rows
# Processing row group 77/262... ✅ 122880 → 106730 rows
# Processing row group 78/262... ✅ 122880 → 106559 rows
# Processing row group 79/262... ✅ 122880 → 106735 rows
# Processing row group 80/262... ✅ 122880 → 106684 rows
# Processing row group 81/262... ✅ 122880 → 106883 rows
# Processing row group 82/262... ✅ 122880 → 106727 rows
# Processing row group 83/262... ✅ 122880 → 106674 rows
# Processing row group 84/262... ✅ 122880 → 106539 rows
# Processing row group 85/262... ✅ 122880 → 106835 rows
# Processing row group 86/262... ✅ 122880 → 106662 rows
# Processing row group 87/262... ✅ 122880 → 106653 rows
# Processing row group 88/262... ✅ 122880 → 106752 rows
# Processing row group 89/262... ✅ 122880 → 106550 rows
# Processing row group 90/262... ✅ 122880 → 106732 rows
# Processing row group 91/262... ✅ 122880 → 106591 rows
# Processing row group 92/262... ✅ 122880 → 106531 rows
# Processing row group 93/262... ✅ 122880 → 106729 rows
# Processing row group 94/262... ✅ 122880 → 106541 rows
# Processing row group 95/262... ✅ 122880 → 106607 rows
# Processing row group 96/262... ✅ 122880 → 106632 rows
# Processing row group 97/262... ✅ 122880 → 106577 rows
# Processing row group 98/262... ✅ 122880 → 106590 rows
# Processing row group 99/262... ✅ 122880 → 106665 rows
# Processing row group 100/262... ✅ 122880 → 106700 rows
# Processing row group 101/262... ✅ 122880 → 106711 rows
# Processing row group 102/262... ✅ 122880 → 106534 rows
# Processing row group 103/262... ✅ 122880 → 106502 rows
# Processing row group 104/262... ✅ 122880 → 106486 rows
# Processing row group 105/262... ✅ 122880 → 106583 rows
# Processing row group 106/262... ✅ 122880 → 106556 rows
# Processing row group 107/262... ✅ 122880 → 106591 rows
# Processing row group 108/262... ✅ 122880 → 106617 rows
# Processing row group 109/262... ✅ 122880 → 106815 rows
# Processing row group 110/262... ✅ 122880 → 106699 rows
# Processing row group 111/262... ✅ 122880 → 106477 rows
# Processing row group 112/262... ✅ 122880 → 106575 rows
# Processing row group 113/262... ✅ 122880 → 106544 rows
# Processing row group 114/262... ✅ 122880 → 106738 rows
# Processing row group 115/262... ✅ 122880 → 106589 rows
# Processing row group 116/262... ✅ 122880 → 106482 rows
# Processing row group 117/262... ✅ 122880 → 106741 rows
# Processing row group 118/262... ✅ 122880 → 106645 rows
# Processing row group 119/262... ✅ 122880 → 106820 rows
# Processing row group 120/262... ✅ 122880 → 106516 rows
# Processing row group 121/262... ✅ 122880 → 106560 rows
# Processing row group 122/262... ✅ 122880 → 106703 rows
# Processing row group 123/262... ✅ 122880 → 106702 rows
# Processing row group 124/262... ✅ 122880 → 106597 rows
# Processing row group 125/262... ✅ 122880 → 106684 rows
# Processing row group 126/262... ✅ 122880 → 106699 rows
# Processing row group 127/262... ✅ 122880 → 106694 rows
# Processing row group 128/262... ✅ 122880 → 106720 rows
# Processing row group 129/262... ✅ 122880 → 106654 rows
# Processing row group 130/262... ✅ 122880 → 106627 rows
# Processing row group 131/262... ✅ 122880 → 106467 rows
# Processing row group 132/262... ✅ 122880 → 106758 rows
# Processing row group 133/262... ✅ 122880 → 106569 rows
# Processing row group 134/262... ✅ 122880 → 106748 rows
# Processing row group 135/262... ✅ 122880 → 106828 rows
# Processing row group 136/262... ✅ 122880 → 106632 rows
# Processing row group 137/262... ✅ 122880 → 106764 rows
# Processing row group 138/262... ✅ 122880 → 106884 rows
# Processing row group 139/262... ✅ 122880 → 106659 rows
# Processing row group 140/262... ✅ 122880 → 106841 rows
# Processing row group 141/262... ✅ 122880 → 106600 rows
# Processing row group 142/262... ✅ 122880 → 106741 rows
# Processing row group 143/262... ✅ 122880 → 106598 rows
# Processing row group 144/262... ✅ 122880 → 106497 rows
# Processing row group 145/262... ✅ 122880 → 106694 rows
# Processing row group 146/262... ✅ 122880 → 106582 rows
# Processing row group 147/262... ✅ 122880 → 106672 rows
# Processing row group 148/262... ✅ 122880 → 106788 rows
# Processing row group 149/262... ✅ 122880 → 106908 rows
# Processing row group 150/262... ✅ 122880 → 106672 rows
# Processing row group 151/262... ✅ 122880 → 106665 rows
# Processing row group 152/262... ✅ 122880 → 106502 rows
# Processing row group 153/262... ✅ 122880 → 106661 rows
# Processing row group 154/262... ✅ 122880 → 106660 rows
# Processing row group 155/262... ✅ 122880 → 106552 rows
# Processing row group 156/262... ✅ 122880 → 106732 rows
# Processing row group 157/262... ✅ 122880 → 106678 rows
# Processing row group 158/262... ✅ 122880 → 106622 rows
# Processing row group 159/262... ✅ 122880 → 106653 rows
# Processing row group 160/262... ✅ 122880 → 106542 rows
# Processing row group 161/262... ✅ 122880 → 106725 rows
# Processing row group 162/262... ✅ 122880 → 106831 rows
# Processing row group 163/262... ✅ 122880 → 106631 rows
# Processing row group 164/262... ✅ 122880 → 106796 rows
# Processing row group 165/262... ✅ 122880 → 106696 rows
# Processing row group 166/262... ✅ 122880 → 106628 rows
# Processing row group 167/262... ✅ 122880 → 106582 rows
# Processing row group 168/262... ✅ 122880 → 106738 rows
# Processing row group 169/262... ✅ 122880 → 106611 rows
# Processing row group 170/262... ✅ 122880 → 106685 rows
# Processing row group 171/262... ✅ 122880 → 106678 rows
# Processing row group 172/262... ✅ 122880 → 106354 rows
# Processing row group 173/262... ✅ 122880 → 106903 rows
# Processing row group 174/262... ✅ 122880 → 106530 rows
# Processing row group 175/262... ✅ 122880 → 106536 rows
# Processing row group 176/262... ✅ 122880 → 106580 rows
# Processing row group 177/262... ✅ 122880 → 106860 rows
# Processing row group 178/262... ✅ 122880 → 106802 rows
# Processing row group 179/262... ✅ 122880 → 106802 rows
# Processing row group 180/262... ✅ 122880 → 106851 rows
# Processing row group 181/262... ✅ 122880 → 106815 rows
# Processing row group 182/262... ✅ 122880 → 106751 rows
# Processing row group 183/262... ✅ 122880 → 106803 rows
# Processing row group 184/262... ✅ 122880 → 106554 rows
# Processing row group 185/262... ✅ 122880 → 106678 rows
# Processing row group 186/262... ✅ 122880 → 106500 rows
# Processing row group 187/262... ✅ 122880 → 106652 rows
# Processing row group 188/262... ✅ 122880 → 106669 rows
# Processing row group 189/262... ✅ 122880 → 106789 rows
# Processing row group 190/262... ✅ 122880 → 106554 rows
# Processing row group 191/262... ✅ 122880 → 106801 rows
# Processing row group 192/262... ✅ 122880 → 106694 rows
# Processing row group 193/262... ✅ 122880 → 106398 rows
# Processing row group 194/262... ✅ 122880 → 106659 rows
# Processing row group 195/262... ✅ 122880 → 106690 rows
# Processing row group 196/262... ✅ 122880 → 106744 rows
# Processing row group 197/262... ✅ 122880 → 106605 rows
# Processing row group 198/262... ✅ 122880 → 106580 rows
# Processing row group 199/262... ✅ 122880 → 106761 rows
# Processing row group 200/262... ✅ 122880 → 106572 rows
# Processing row group 201/262... ✅ 122880 → 106861 rows
# Processing row group 202/262... ✅ 122880 → 106492 rows
# Processing row group 203/262... ✅ 122880 → 106630 rows
# Processing row group 204/262... ✅ 122880 → 106552 rows
# Processing row group 205/262... ✅ 122880 → 106455 rows
# Processing row group 206/262... ✅ 122880 → 106583 rows
# Processing row group 207/262... ✅ 122880 → 106755 rows
# Processing row group 208/262... ✅ 122880 → 106648 rows
# Processing row group 209/262... ✅ 122880 → 106875 rows
# Processing row group 210/262... ✅ 122880 → 106795 rows
# Processing row group 211/262... ✅ 122880 → 106519 rows
# Processing row group 212/262... ✅ 122880 → 106596 rows
# Processing row group 213/262... ✅ 122880 → 106693 rows
# Processing row group 214/262... ✅ 122880 → 106809 rows
# Processing row group 215/262... ✅ 122880 → 106737 rows
# Processing row group 216/262... ✅ 122880 → 106630 rows
# Processing row group 217/262... ✅ 122880 → 106604 rows
# Processing row group 218/262... ✅ 122880 → 106452 rows
# Processing row group 219/262... ✅ 122880 → 106638 rows
# Processing row group 220/262... ✅ 122880 → 106602 rows
# Processing row group 221/262... ✅ 122880 → 106873 rows
# Processing row group 222/262... ✅ 122880 → 106446 rows
# Processing row group 223/262... ✅ 122880 → 106727 rows
# Processing row group 224/262... ✅ 122880 → 106426 rows
# Processing row group 225/262... ✅ 122880 → 106398 rows
# Processing row group 226/262... ✅ 122880 → 106549 rows
# Processing row group 227/262... ✅ 122880 → 106707 rows
# Processing row group 228/262... ✅ 122880 → 106790 rows
# Processing row group 229/262... ✅ 122880 → 106537 rows
# Processing row group 230/262... ✅ 122880 → 106513 rows
# Processing row group 231/262... ✅ 122880 → 106770 rows
# Processing row group 232/262... ✅ 122880 → 106638 rows
# Processing row group 233/262... ✅ 122880 → 106806 rows
# Processing row group 234/262... ✅ 122880 → 106744 rows
# Processing row group 235/262... ✅ 122880 → 106699 rows
# Processing row group 236/262... ✅ 122880 → 106732 rows
# Processing row group 237/262... ✅ 122880 → 106548 rows
# Processing row group 238/262... ✅ 122880 → 106494 rows
# Processing row group 239/262... ✅ 122880 → 106597 rows
# Processing row group 240/262... ✅ 122880 → 106693 rows
# Processing row group 241/262... ✅ 122880 → 106708 rows
# Processing row group 242/262... ✅ 122880 → 106551 rows
# Processing row group 243/262... ✅ 122880 → 106481 rows
# Processing row group 244/262... ✅ 122880 → 106620 rows
# Processing row group 245/262... ✅ 122880 → 106586 rows
# Processing row group 246/262... ✅ 122880 → 106516 rows
# Processing row group 247/262... ✅ 122880 → 106781 rows
# Processing row group 248/262... ✅ 122880 → 106695 rows
# Processing row group 249/262... ✅ 122880 → 106687 rows
# Processing row group 250/262... ✅ 122880 → 106582 rows
# Processing row group 251/262... ✅ 122880 → 106484 rows
# Processing row group 252/262... ✅ 122880 → 106578 rows
# Processing row group 253/262... ✅ 122880 → 106620 rows
# Processing row group 254/262... ✅ 122880 → 106617 rows
# Processing row group 255/262... ✅ 122880 → 106932 rows
# Processing row group 256/262... ✅ 122880 → 106685 rows
# Processing row group 257/262... ✅ 122880 → 106637 rows
# Processing row group 258/262... ✅ 122880 → 106648 rows
# Processing row group 259/262... ✅ 122880 → 106797 rows
# Processing row group 260/262... ✅ 122880 → 106472 rows
# Processing row group 261/262... ✅ 122880 → 106671 rows
# Processing row group 262/262... ✅ 98619 → 85406 rows
#
# ============================================================
# ROW GROUP CLEANING SUMMARY:
# ============================================================
# Row groups: 262 processed
# Rows:       32,170,299 → 27,922,673 (86.8% kept)
# File size:  1.77 GB → 0.31 GB
# Reduction:  1.46 GB (82.5%)
# Columns:    9 → 2
# ============================================================
# {'original_rows': 32170299,
#  'final_rows': 27922673,
#  'original_size': 1902151733,
#  'final_size': 333805397,
#  'row_groups_processed': 262}
