# %%
import pandas as pd
import pyarrow.parquet as pq
from datetime import timedelta

# Load our processed data
processed_data_path = "/home/ale/Documents/uni/mp/data/posting_behaviour/processed/user_activity_analysis.parquet"
user_data = pd.read_parquet(processed_data_path)

print("Starting feature engineering for prediction model...")
print(f"Initial dataset shape: {user_data.shape}")
